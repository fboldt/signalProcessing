# %% [markdown]
# <a href="https://colab.research.google.com/github/fboldt/cwru-conv1d/blob/master/cwru_evaluation_byseverity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CWRU files.
#
# Associate each Matlab file name to a bearing condition in a Python dictionary.
# The dictionary keys identify the conditions.
#
# There are only four normal conditions, with loads of 0, 1, 2 and 3 hp.
# All conditions end with an underscore character followed by an algarism representing the load applied during the acquisitions.
# The remaining conditions follow the pattern:
#
#
# * First two characters represent the bearing location, i.e. drive end (DE) and fan end (FE).
# * The following two characters represent the failure location in the bearing, i.e. ball (BA), Inner Race (IR) and Outer Race (OR).
# * The next three algarisms indicate the severity of the failure, where 007 stands for 0.007 inches and 0021 for 0.021 inches.
# * For Outer Race failures, the character @ is followed by a number that indicates different load zones.

# %%
debug = False
# size of each segment
sample_size = 512
acquisitions = {}
# Normal
acquisitions["Normal_0"] = "97.mat"
acquisitions["Normal_1"] = "98.mat"
acquisitions["Normal_2"] = "99.mat"
acquisitions["Normal_3"] = "100.mat"
# DE Inner Race 0.007 inches
acquisitions["DEIR.007_0"] = "105.mat"
acquisitions["DEIR.007_1"] = "106.mat"
acquisitions["DEIR.007_2"] = "107.mat"
acquisitions["DEIR.007_3"] = "108.mat"
# DE Inner Race 0.014 inches
acquisitions["DEIR.014_0"] = "169.mat"
acquisitions["DEIR.014_1"] = "170.mat"
acquisitions["DEIR.014_2"] = "171.mat"
acquisitions["DEIR.014_3"] = "172.mat"
# DE Inner Race 0.021 inches
acquisitions["DEIR.021_0"] = "209.mat"
acquisitions["DEIR.021_1"] = "210.mat"
acquisitions["DEIR.021_2"] = "211.mat"
acquisitions["DEIR.021_3"] = "212.mat"
# DE Inner Race 0.028 inches
acquisitions["DEIR.028_0"] = "3001.mat"
acquisitions["DEIR.028_1"] = "3002.mat"
acquisitions["DEIR.028_2"] = "3003.mat"
acquisitions["DEIR.028_3"] = "3004.mat"
# FE Inner Race 0.007 inches
acquisitions["FEIR.007_0"] = "278.mat"
acquisitions["FEIR.007_1"] = "279.mat"
acquisitions["FEIR.007_2"] = "280.mat"
acquisitions["FEIR.007_3"] = "281.mat"
# FE Inner Race 0.014 inches
acquisitions["FEIR.014_0"] = "274.mat"
acquisitions["FEIR.014_1"] = "275.mat"
acquisitions["FEIR.014_2"] = "276.mat"
acquisitions["FEIR.014_3"] = "277.mat"
# FE Inner Race 0.021 inches
acquisitions["FEIR.021_0"] = "270.mat"
acquisitions["FEIR.021_1"] = "271.mat"
acquisitions["FEIR.021_2"] = "272.mat"
acquisitions["FEIR.021_3"] = "273.mat"
if not debug:
  # DE Ball 0.007 inches
  acquisitions["DEB.007_0"] = "118.mat"
  acquisitions["DEB.007_1"] = "119.mat"
  acquisitions["DEB.007_2"] = "120.mat"
  acquisitions["DEB.007_3"] = "121.mat"
  # DE Ball 0.014 inches
  acquisitions["DEB.014_0"] = "185.mat"
  acquisitions["DEB.014_1"] = "186.mat"
  acquisitions["DEB.014_2"] = "187.mat"
  acquisitions["DEB.014_3"] = "188.mat"
  # DE Ball 0.021 inches
  acquisitions["DEB.021_0"] = "222.mat"
  acquisitions["DEB.021_1"] = "223.mat"
  acquisitions["DEB.021_2"] = "224.mat"
  acquisitions["DEB.021_3"] = "225.mat"
  # DE Ball 0.028 inches
  acquisitions["DEB.028_0"] = "3005.mat"
  acquisitions["DEB.028_1"] = "3006.mat"
  acquisitions["DEB.028_2"] = "3007.mat"
  acquisitions["DEB.028_3"] = "3008.mat"
  # DE Outer race 0.007 inches centered @6:00
  acquisitions["DEOR.007@6_0"] = "130.mat"
  acquisitions["DEOR.007@6_1"] = "131.mat"
  acquisitions["DEOR.007@6_2"] = "132.mat"
  acquisitions["DEOR.007@6_3"] = "133.mat"
  # DE Outer race 0.014 inches centered @6:00
  acquisitions["DEOR.014@6_0"] = "197.mat"
  acquisitions["DEOR.014@6_1"] = "198.mat"
  acquisitions["DEOR.014@6_2"] = "199.mat"
  acquisitions["DEOR.014@6_3"] = "200.mat"
  # DE Outer race 0.021 inches centered @6:00
  acquisitions["DEOR.021@6_0"] = "234.mat"
  acquisitions["DEOR.021@6_1"] = "235.mat"
  acquisitions["DEOR.021@6_2"] = "236.mat"
  acquisitions["DEOR.021@6_3"] = "237.mat"
  # DE Outer race 0.007 inches centered @3:00
  acquisitions["DEOR.007@3_0"] = "144.mat"
  acquisitions["DEOR.007@3_1"] = "145.mat"
  acquisitions["DEOR.007@3_2"] = "146.mat"
  acquisitions["DEOR.007@3_3"] = "147.mat"
  # DE Outer race 0.021 inches centered @3:00
  acquisitions["DEOR.021@3_0"] = "246.mat"
  acquisitions["DEOR.021@3_1"] = "247.mat"
  acquisitions["DEOR.021@3_2"] = "248.mat"
  acquisitions["DEOR.021@3_3"] = "249.mat"
  # DE Outer race 0.007 inches centered @12:00
  acquisitions["DEOR.007@12_0"] = "156.mat"
  acquisitions["DEOR.007@12_1"] = "158.mat"
  acquisitions["DEOR.007@12_2"] = "159.mat"
  acquisitions["DEOR.007@12_3"] = "160.mat"
  # DE Outer race 0.021 inches centered @12:00
  acquisitions["DEOR.021@12_0"] = "258.mat"
  acquisitions["DEOR.021@12_1"] = "259.mat"
  acquisitions["DEOR.021@12_2"] = "260.mat"
  acquisitions["DEOR.021@12_3"] = "261.mat"
  # FE Ball 0.007 inches
  acquisitions["FEB.007_0"] = "282.mat"
  acquisitions["FEB.007_1"] = "283.mat"
  acquisitions["FEB.007_2"] = "284.mat"
  acquisitions["FEB.007_3"] = "285.mat"
  # FE Ball 0.014 inches
  acquisitions["FEB.014_0"] = "286.mat"
  acquisitions["FEB.014_1"] = "287.mat"
  acquisitions["FEB.014_2"] = "288.mat"
  acquisitions["FEB.014_3"] = "289.mat"
  # FE Ball 0.021 inches
  acquisitions["FEB.021_0"] = "290.mat"
  acquisitions["FEB.021_1"] = "291.mat"
  acquisitions["FEB.021_2"] = "292.mat"
  acquisitions["FEB.021_3"] = "293.mat"
  # FE Outer race 0.007 inches centered @6:00
  acquisitions["FEOR.007@6_0"] = "294.mat"
  acquisitions["FEOR.007@6_1"] = "295.mat"
  acquisitions["FEOR.007@6_2"] = "296.mat"
  acquisitions["FEOR.007@6_3"] = "297.mat"
  # FE Outer race 0.014 inches centered @6:00
  acquisitions["FEOR.014@6_0"] = "313.mat"
  # FE Outer race 0.021 inches centered @6:00
  acquisitions["FEOR.021@6_0"] = "315.mat"
  # FE Outer race 0.007 inches centered @3:00
  acquisitions["FEOR.007@3_0"] = "298.mat"
  acquisitions["FEOR.007@3_1"] = "299.mat"
  acquisitions["FEOR.007@3_2"] = "300.mat"
  acquisitions["FEOR.007@3_3"] = "301.mat"
  # FE Outer race 0.014 inches centered @3:00
  acquisitions["FEOR.014@3_0"] = "310.mat"
  acquisitions["FEOR.014@3_1"] = "309.mat"
  acquisitions["FEOR.014@3_2"] = "311.mat"
  acquisitions["FEOR.014@3_3"] = "312.mat"
  # FE Outer race 0.021 inches centered @3:00
  acquisitions["FEOR.021@3_1"] = "316.mat"
  acquisitions["FEOR.021@3_2"] = "317.mat"
  acquisitions["FEOR.021@3_3"] = "318.mat"
  # FE Outer race 0.007 inches centered @12:00
  acquisitions["FEOR.007@12_0"] = "302.mat"
  acquisitions["FEOR.007@12_1"] = "305.mat"
  acquisitions["FEOR.007@12_2"] = "306.mat"
  acquisitions["FEOR.007@12_3"] = "307.mat"

# %% [markdown]
# #Functions definitions

# %%
def get_labels_dict(acquisitions, separator='_', detectPosition=True):
  """Generate a dictionary linking the labels with values to keep consistence."""
  labels_dict = {}
  value = 0
  for key in acquisitions.keys():
    key = key.split('_')[0]
    key = key.split(separator)
    if key[0] == "Normal" or detectPosition:
      label = key[0]
    else:
      label = key[0][2:]
    if not label in labels_dict:
      labels_dict[label] = value
      value += 1
  return labels_dict

# %% [markdown]
# Convert Matlab file into tensors.

# %%
import scipy.io
import numpy as np
def acquisition2tensor(file_name, position=None, sample_size=sample_size):
  """
  Convert Matlab file into tensors.
  The file is divided in segments of sample_size values.
  """
  print(file_name, end=' ')
  matlab_file = scipy.io.loadmat(file_name)
  DE_samples = []
  FE_samples = []
  
  #signal segmentation
  signal_begin = 0
  if position == None:
    DE_time = [key for key in matlab_file if key.endswith("DE_time")][0] #Find the DRIVE END acquisition key name
    FE_time = [key for key in matlab_file if key.endswith("FE_time")][0] #Find the FAN END acquisition key name
    acquisition_size = max(len(matlab_file[DE_time]),len(matlab_file[FE_time]))
    while signal_begin + sample_size < acquisition_size:
      DE_samples.append([item for sublist in matlab_file[DE_time][signal_begin:signal_begin+sample_size] for item in sublist])
      FE_samples.append([item for sublist in matlab_file[FE_time][signal_begin:signal_begin+sample_size] for item in sublist])
      signal_begin += sample_size
    sample_tensor = np.stack([DE_samples,FE_samples],axis=2).astype('float32')
  elif position == 'DE':
    DE_time = [key for key in matlab_file if key.endswith("DE_time")][0] #Find the DRIVE END acquisition key name
    acquisition_size = len(matlab_file[DE_time])
    while signal_begin + sample_size < acquisition_size:
      DE_samples.append([item for sublist in matlab_file[DE_time][signal_begin:signal_begin+sample_size] for item in sublist])
      signal_begin += sample_size
    sample_tensor = np.stack([DE_samples],axis=2).astype('float32')
  elif position == 'FE':
    FE_time = [key for key in matlab_file if key.endswith("FE_time")][0] #Find the FAN END acquisition key name
    acquisition_size = len(matlab_file[FE_time])
    while signal_begin + sample_size < acquisition_size:
      FE_samples.append([item for sublist in matlab_file[FE_time][signal_begin:signal_begin+sample_size] for item in sublist])
      signal_begin += sample_size
    sample_tensor = np.stack([FE_samples],axis=2).astype('float32')
  return sample_tensor

# %% [markdown]
# Extract datasets from acquisitions.

# %%
def concatenate_datasets(xd,yd,xo,yo):
  """
  xd: destination patterns tensor
  yd: destination labels tensor
  xo: origin patterns tensor to be concateneted 
  yo: origin labels tensor to be concateneted 
  """
  if xd is None or yd is None:
    xd = xo
    yd = yo
  else:
    xd = np.concatenate((xd,xo))
    yd = np.concatenate((yd,yo))
  return xd,yd

import urllib.request
import os.path

def acquisitions_from_substr(substr, acquisitions, labels_dict, position=None,
                             url="http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/"):
  """
  Extract samples from all files with some load.
  """
  samples = None
  labels = None
  for key in acquisitions:
    if str(substr) in key:
      file_name = acquisitions[key]
      if not os.path.exists(file_name):
        urllib.request.urlretrieve(url+file_name, file_name)
      if substr[:2] == key[:2] and position == None:
        acquisition_samples = acquisition2tensor(file_name)
      elif position =='DE':
        acquisition_samples = acquisition2tensor(file_name, 'DE')
      elif position =='FE':
        acquisition_samples = acquisition2tensor(file_name, 'FE')
      else:
        acquisition_samples = acquisition2tensor(file_name, key[:2])
      for label in labels_dict.keys():
        if label in key:
          break
      acquisition_labels = np.ones(acquisition_samples.shape[0])*labels_dict[label]
      samples,labels = concatenate_datasets(samples,labels,acquisition_samples,acquisition_labels)
  print(substr)
  return samples,labels

# %% [markdown]
# Define function to plot the confusion matrices.

# %%
import itertools
from sklearn.metrics import confusion_matrix
from google.colab import files
from matplotlib import pyplot as plt


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Greys):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    #plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

# %% [markdown]
# Define f1-score macro averaged.

# %%
from keras import backend as K
def f1_score_macro(y_true,y_pred):
    def recall(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall
    def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #Downloading and Matlab files
# Extract samples.

# %%
labels_dict = get_labels_dict(acquisitions, '.', False)
print(labels_dict)

xn_0,yn_0 = None,None
xn,yn = acquisitions_from_substr('Normal_0',acquisitions,labels_dict,'DE')
xn_0,yn_0 = concatenate_datasets(xn_0,yn_0,xn,yn)
xn,yn = acquisitions_from_substr('Normal_0',acquisitions,labels_dict,'FE')
xn_0,yn_0 = concatenate_datasets(xn_0,yn_0,xn,yn)

xn_1,yn_1 = None,None
xn,yn = acquisitions_from_substr('Normal_1',acquisitions,labels_dict,'DE')
xn_1,yn_1 = concatenate_datasets(xn_1,yn_1,xn,yn)
xn,yn = acquisitions_from_substr('Normal_1',acquisitions,labels_dict,'FE')
xn_1,yn_1 = concatenate_datasets(xn_1,yn_1,xn,yn)

xn_2,yn_2 = None,None
xn,yn = acquisitions_from_substr('Normal_2',acquisitions,labels_dict,'DE')
xn_2,yn_2 = concatenate_datasets(xn_2,yn_2,xn,yn)
xn,yn = acquisitions_from_substr('Normal_2',acquisitions,labels_dict,'FE')
xn_2,yn_2 = concatenate_datasets(xn_2,yn_2,xn,yn)

xn_3,yn_3 = None,None
xn,yn = acquisitions_from_substr('Normal_3',acquisitions,labels_dict,'DE')
xn_3,yn_3 = concatenate_datasets(xn_3,yn_3,xn,yn)
xn,yn = acquisitions_from_substr('Normal_3',acquisitions,labels_dict,'FE')
xn_3,yn_3 = concatenate_datasets(xn_3,yn_3,xn,yn)


x007,y007 = acquisitions_from_substr('007',acquisitions,labels_dict)
x014,y014 = acquisitions_from_substr('014',acquisitions,labels_dict)
x021,y021 = acquisitions_from_substr('021',acquisitions,labels_dict)
x028,y028 = acquisitions_from_substr('028',acquisitions,labels_dict)
# Out:
# {'Normal': 0, 'IR': 1, 'B': 2, 'OR': 3}
# 97.mat Normal_0
# 97.mat Normal_0
# 98.mat Normal_1
# 98.mat Normal_1
# 99.mat Normal_2
# 99.mat Normal_2
# 100.mat Normal_3
# 100.mat Normal_3
# 105.mat 106.mat 107.mat 108.mat 278.mat 279.mat 280.mat 281.mat 118.mat 119.mat 120.mat 121.mat 130.mat 131.mat 132.mat 133.mat 144.mat 145.mat 146.mat 147.mat 156.mat 158.mat 159.mat 160.mat 282.mat 283.mat 284.mat 285.mat 294.mat 295.mat 296.mat 297.mat 298.mat 299.mat 300.mat 301.mat 302.mat 305.mat 306.mat 307.mat 007
# 169.mat 170.mat 171.mat 172.mat 274.mat 275.mat 276.mat 277.mat 185.mat 186.mat 187.mat 188.mat 197.mat 198.mat 199.mat 200.mat 286.mat 287.mat 288.mat 289.mat 313.mat 310.mat 309.mat 311.mat 312.mat 014
# 209.mat 210.mat 211.mat 212.mat 270.mat 271.mat 272.mat 273.mat 222.mat 223.mat 224.mat 225.mat 234.mat 235.mat 236.mat 237.mat 246.mat 247.mat 248.mat 249.mat 258.mat 259.mat 260.mat 261.mat 290.mat 291.mat 292.mat 293.mat 315.mat 316.mat 317.mat 318.mat 021
# 3001.mat 3002.mat 3003.mat 3004.mat 3005.mat 3006.mat 3007.mat 3008.mat 028

# %% [markdown]
# Count number of samples.

# %%
print("Label\t007\t014\t021\t028\ttotal")
for label,value in labels_dict.items():
  print(label, end='\t')
  tsamples = 0
  if label == 'Normal':
    print(4*'\t'+'...')
    for load in range(4):
      print(' '+str(load)+(load)*'\t', end='\t')
      print(list(eval('yn_'+str(load))).count(value))
  else:
    for severity in ['007','014','021','028']:
      tmp = eval('y'+str(severity))
      if tmp is not None:
        nsamples = list(tmp).count(value)
        print(nsamples, end='\t')
        tsamples += nsamples
      else:
        print('0', end='\t')
    print(tsamples)
# Out:
# Label	007	014	021	028	total
# Normal					...
#  0	952
#  1		1890
#  2			1890
#  3				1896
# IR	1900	1895	1894	946	6635
# B	1894	1900	1897	944	6635
# OR	5694	2131	3798	0	11623

# %% [markdown]
# #Feature Extraction Models

# %%
from sklearn.base import TransformerMixin
import numpy as np
import scipy.stats as stats

# roor mean square
def rms(x):
  x = np.array(x)
  return np.sqrt(np.mean(np.square(x)))
# square root amplitude
def sra(x):
  x = np.array(x)
  return np.mean(np.sqrt(np.absolute(x)))**2
# peak to peak value
def ppv(x):
  x = np.array(x)
  return np.max(x)-np.min(x)
# crest factor
def cf(x):
  x = np.array(x)
  return np.max(np.absolute(x))/rms(x)
# impact factor
def ifa(x):
  x = np.array(x)
  return np.max(np.absolute(x))/np.mean(np.absolute(x))
# margin factor
def mf(x):
  x = np.array(x)
  return np.max(np.absolute(x))/sra(x)
# shape factor
def sf(x):
  x = np.array(x)
  return rms(x)/np.mean(np.absolute(x))
# kurtosis factor
def kf(x):
  x = np.array(x)
  return stats.kurtosis(x)/(np.mean(x**2)**2)

class StatisticalTime(TransformerMixin):
  def __init__(self):
    pass
  def fit(self, X, y=None):
    return self
  def transform(self, X, y=None):
    if X.shape[2] == 1:
      return np.array([[rms(x), sra(x), stats.kurtosis(x), stats.skew(x), ppv(x), cf(x), ifa(x), mf(x), sf(x), kf(x)] for x in X[:,:,0]])
    de = np.array([[rms(x), sra(x), stats.kurtosis(x), stats.skew(x), ppv(x), cf(x), ifa(x), mf(x), sf(x), kf(x)] for x in X[:,:,0]])
    fe = np.array([[rms(x), sra(x), stats.kurtosis(x), stats.skew(x), ppv(x), cf(x), ifa(x), mf(x), sf(x), kf(x)] for x in X[:,:,1]])
    return np.concatenate((de,fe),axis=1)
  
class StatisticalFrequency(TransformerMixin):
  def __init__(self):
    pass
  def fit(self, X, y=None):
    return self
  def transform(self, X, y=None):
    if X.shape[2] == 1:
      sig = []
      for x in X[:,:,0]:
        fx = np.absolute(np.fft.fft(x))
        fc = np.mean(fx)
        sig.append([fc, rms(fx), rms(fx-fc)])
      return np.array(sig)
    de = []
    for x in X[:,:,0]:
      fx = np.absolute(np.fft.fft(x))
      fc = np.mean(fx)
      de.append([fc, rms(fx), rms(fx-fc)])
    de = np.array(de)
    fe = []
    for x in X[:,:,1]:
      fx = np.absolute(np.fft.fft(x))
      fc = np.mean(fx)
      fe.append([fc, rms(fx), rms(fx-fc)])
    fe = np.array(fe)
    return np.concatenate((de,fe),axis=1)

class Statistical(TransformerMixin):
  def __init__(self):
    pass
  def fit(self, X, y=None):
    return self
  def transform(self, X, y=None):
    st = StatisticalTime()
    stfeats = st.transform(X)
    sf = StatisticalFrequency()
    sffeats = sf.transform(X)
    return np.concatenate((stfeats,sffeats),axis=1)
   
import pywt
class WaveletPackage(TransformerMixin):
  def __init__(self):
    pass
  def fit(self, X, y=None):
    return self
  def transform(self, X, y=None):
    def Energy(coeffs, k):
      return np.sqrt(np.sum(np.array(coeffs[-k]) ** 2)) / len(coeffs[-k])
    def getEnergy(wp):
      coefs = np.asarray([n.data for n in wp.get_leaf_nodes(True)])
      return np.asarray([Energy(coefs,i) for i in range(2**wp.maxlevel)])
    if X.shape[2] == 1:
      return np.array([getEnergy(pywt.WaveletPacket(data=x, wavelet='db4', mode='symmetric', maxlevel=4)) for x in X[:,:,0]])
    de = np.array([getEnergy(pywt.WaveletPacket(data=x, wavelet='db4', mode='symmetric', maxlevel=4)) for x in X[:,:,0]])
    fe = np.array([getEnergy(pywt.WaveletPacket(data=x, wavelet='db4', mode='symmetric', maxlevel=4)) for x in X[:,:,1]])
    return np.concatenate((de,fe),axis=1)

class Heterogeneous(TransformerMixin):
  def __init__(self):
    pass
  def fit(self, X, y=None):
    return self
  def transform(self, X, y=None):
    st = StatisticalTime()
    stfeats = st.transform(X)
    sf = StatisticalFrequency()
    sffeats = sf.transform(X)
    wp = WaveletPackage()
    wpfeats = wp.transform(X)
    return np.concatenate((stfeats,sffeats,wpfeats),axis=1)

# %% [markdown]
# Define model architecture.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.neighbors import KNeighborsClassifier
knn = Pipeline([('FeatureExtraction', Heterogeneous()),
               ('scaler', StandardScaler()),
               ('RF', KNeighborsClassifier())])

from sklearn.ensemble import RandomForestClassifier
rf = Pipeline([('FeatureExtraction', Heterogeneous()),
               ('scaler', StandardScaler()),
               ('RF', RandomForestClassifier())])

from keras import layers
from keras import Input
from keras.models import Model
from keras.callbacks import EarlyStopping,ReduceLROnPlateau
from keras.utils import to_categorical
signal_input = Input(shape=(xn_0.shape[1],xn_0.shape[-1]), dtype='float32', name='signal')
x = layers.Conv1D(128, 256, activation='relu', name='conv1d_1')(signal_input)
x = layers.MaxPooling1D(256, name='max_pooling1d_1')(x)
x = layers.Flatten(name='flatten')(x)
condition_output = layers.Dense(len(labels_dict),activation='softmax',name='condition')(x)
conv1d = Model(signal_input, condition_output)
conv1d.summary()
validation_split=0.2

clfs = [("K-NNeighbors", knn),
        ("RandomForest", rf),
        ("ANN-Conv1d", conv1d)]
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0807 00:11:11.445624 139705454200704 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0807 00:11:11.480507 139705454200704 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0807 00:11:11.510973 139705454200704 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0807 00:11:11.538177 139705454200704 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# signal (InputLayer)          (None, 512, 1)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 257, 128)          32896
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# condition (Dense)            (None, 4)                 516
# =================================================================
# Total params: 33,412
# Trainable params: 33,412
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Perform experiments.

# %% [markdown]
# ##kfold Experiments

# %%
from sklearn.metrics import f1_score,accuracy_score
from sklearn.model_selection import RepeatedStratifiedKFold
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from sklearn.exceptions import ConvergenceWarning
warnings.simplefilter(action='ignore', category=ConvergenceWarning)
from sklearn.exceptions import UndefinedMetricWarning
warnings.simplefilter(action='ignore', category=UndefinedMetricWarning)

epochs = 3 if debug else 30
nrounds = 2 if debug else 5
results = {}
models = {}
severities = ['007','014','021','028']
X,y = None,None
for load in range(4):
  X,y = concatenate_datasets(X,y,eval('xn_'+str(load)),eval('yn_'+str(load)))
for severity in severities: 
  X,y = concatenate_datasets(X,y,eval('x'+str(severity)),eval('y'+str(severity)))
rskf = RepeatedStratifiedKFold(n_splits=len(severities), n_repeats=nrounds, random_state=36851234)
fold = 0
count_round = 0

#Confunsion Matrix Configuration
genconfmat = True
if genconfmat:
  class_names = []
  for label in labels_dict.keys():
    class_names.append(label)
  figprop = np.linspace(1,0.5,25)
  tam = len(class_names)*figprop[len(class_names)]

results['kfold'] = {}
models['kfold'] = {}
y_test_round = None
y_pred_round = {}

print("k-Fold")
for train_index, test_index in rskf.split(X, y):
  print("{}/{}".format(fold+1,rskf.get_n_splits()//nrounds), end=" x ")
  x_train, x_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]
  if y_test_round is None:
    y_test_round = np.copy(y_test)
  else:
    y_test_round = np.concatenate((y_test_round,y_test))
  j = count_round//(rskf.get_n_splits()//nrounds)
  count_round += 1
  print("{}/{}".format(j+1,nrounds))
  for clfname,model in clfs:
    print(clfname, end=":\t")
    if not clfname in results['kfold']:
      results['kfold'][clfname] = []
    if "ANN" in clfname:
      y_train_cat = to_categorical(y_train)
      model.compile(optimizer='rmsprop', loss='mean_squared_error', 
                    metrics=['accuracy',f1_score_macro])
      history = model.fit(x_train ,y_train_cat, epochs=epochs, 
                          validation_split=validation_split, 
                          callbacks=[EarlyStopping(patience=3),
                                     ReduceLROnPlateau()])
      y_pred = np.argmax(model.predict(x_test), axis=1)
    else:
      history = model.fit(x_train ,y_train)
      y_pred = model.predict(x_test)
    if not clfname in y_pred_round:
      y_pred_round[clfname] = None
    if y_pred_round[clfname] is None:
      y_pred_round[clfname] = np.copy(y_pred)
    else:
      y_pred_round[clfname] = np.concatenate((y_pred_round[clfname],y_pred))
    if not clfname+str(fold) in models['kfold']:
      models['kfold'][clfname+str(fold)] = model
    results['kfold'][clfname].append([accuracy_score(y_test,y_pred),f1_score(y_test,y_pred,average='macro')])
    print(results['kfold'][clfname][-1])
    if genconfmat:
      cnf_matrix = confusion_matrix(y_test, y_pred)
      print(cnf_matrix)
      plt.figure(figsize=(tam,tam))
      plot_confusion_matrix(cnf_matrix, classes=class_names, title=clfname+' - Fold '+str(fold+1)+' - Round '+str(j+1), normalize=False)
      plt.savefig('cnfmatrix_kfold'+clfname+str(fold)+'round'+str(j)+'.png')
      plt.show()
  if fold >= (rskf.get_n_splits()//nrounds)-1:
    fold = 0
    for clfname,model in clfs:
      if genconfmat:
        cnf_matrix = confusion_matrix(y_test_round, y_pred_round[clfname])
        print(cnf_matrix)
        plt.figure(figsize=(tam,tam))
        plot_confusion_matrix(cnf_matrix, classes=class_names, title=clfname+' - Round '+str(j+1), normalize=False)
        plt.savefig('cnfmatrix_kfold'+clfname+'_round'+str(j+1)+'.png')
        plt.show()
      y_pred_round[clfname] = None
    y_test_round = None
  else:
    fold += 1
# Out:
# k-Fold
# 1/4 x 1/5
# K-NNeighbors:	[0.9753838345387641, 0.9747956535237838]
# [[1657    0    0    0]
#  [   0 1616   22   21]
#  [   5   42 1575   37]
#  [   0   35   32 2839]]
# Confusion matrix, without normalization
# RandomForest:	[0.9827433066869686, 0.9828792194664391]
# [[1657    0    0    0]
#  [   0 1631   10   18]
#  [   0   22 1610   27]
#  [   0   26   33 2847]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18912 samples, validate on 4728 samples
# Epoch 1/30
# 18912/18912 [==============================] - 3s 164us/step - loss: 1.9922e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2578 - val_acc: 0.4492 - val_f1_score_macro: 0.4477
# Epoch 2/30
# 18912/18912 [==============================] - 3s 143us/step - loss: 2.6449e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2601 - val_acc: 0.4469 - val_f1_score_macro: 0.4458
# Epoch 3/30
# 18912/18912 [==============================] - 3s 143us/step - loss: 2.6447e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2603 - val_acc: 0.4440 - val_f1_score_macro: 0.4434
# Epoch 4/30
# 18912/18912 [==============================] - 3s 140us/step - loss: 2.6445e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2596 - val_acc: 0.4478 - val_f1_score_macro: 0.4468
# [0.886308844055323, 0.8932515778016988]
# [[1657    0    0    0]
#  [   0 1585    0   74]
#  [   0  115 1415  129]
#  [   0  460  118 2328]]
# Confusion matrix, without normalization
# 2/4 x 1/5
# K-NNeighbors:	[0.974114960030453, 0.9734480338011089]
# [[1657    0    0    0]
#  [   0 1627   16   16]
#  [   5   52 1555   47]
#  [   0   39   29 2838]]
# Confusion matrix, without normalization
# RandomForest:	[0.9822357568836442, 0.9823982280106963]
# [[1657    0    0    0]
#  [   0 1633    9   17]
#  [   1   21 1595   42]
#  [   0   18   32 2856]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18912 samples, validate on 4728 samples
# Epoch 1/30
# 18912/18912 [==============================] - 3s 175us/step - loss: 2.6447e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2619 - val_acc: 0.4442 - val_f1_score_macro: 0.4433
# Epoch 2/30
# 18912/18912 [==============================] - 3s 150us/step - loss: 2.6444e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2627 - val_acc: 0.4420 - val_f1_score_macro: 0.4415
# Epoch 3/30
# 18912/18912 [==============================] - 3s 145us/step - loss: 2.6444e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2629 - val_acc: 0.4423 - val_f1_score_macro: 0.4411
# Epoch 4/30
# 18912/18912 [==============================] - 3s 139us/step - loss: 2.6443e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2629 - val_acc: 0.4423 - val_f1_score_macro: 0.4412
# [0.8918918918918919, 0.8983395398170094]
# [[1657    0    0    0]
#  [   0 1587    1   71]
#  [   0  119 1422  118]
#  [   0  446   97 2363]]
# Confusion matrix, without normalization
# 3/4 x 1/5
# K-NNeighbors:	[0.9732267478746351, 0.9727799224030003]
# [[1657    0    0    0]
#  [   0 1627   14   18]
#  [   5   48 1551   55]
#  [   0   34   37 2835]]
# Confusion matrix, without normalization
# RandomForest:	[0.9823626443344753, 0.9828529606820117]
# [[1657    0    0    0]
#  [   0 1631    6   22]
#  [   0   15 1603   41]
#  [   0   19   36 2851]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18912 samples, validate on 4728 samples
# Epoch 1/30
# 18912/18912 [==============================] - 3s 167us/step - loss: 2.6443e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2630 - val_acc: 0.4416 - val_f1_score_macro: 0.4398
# Epoch 2/30
# 18912/18912 [==============================] - 3s 138us/step - loss: 2.6442e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2646 - val_acc: 0.4380 - val_f1_score_macro: 0.4372
# Epoch 3/30
# 18912/18912 [==============================] - 3s 143us/step - loss: 2.6442e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2649 - val_acc: 0.4378 - val_f1_score_macro: 0.4372
# Epoch 4/30
# 18912/18912 [==============================] - 3s 142us/step - loss: 2.6442e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2630 - val_acc: 0.4414 - val_f1_score_macro: 0.4401
# [0.8922725542443852, 0.898568299937397]
# [[1657    0    0    0]
#  [   0 1602    1   56]
#  [   0  112 1398  149]
#  [   0  444   87 2375]]
# Confusion matrix, without normalization
# 4/4 x 1/5
# K-NNeighbors:	[0.9723280020309724, 0.9715054303592797]
# [[1657    0    0    0]
#  [   0 1632   20    6]
#  [   4   56 1539   59]
#  [   0   34   39 2832]]
# Confusion matrix, without normalization
# RandomForest:	[0.9810865701954811, 0.9812781497851367]
# [[1657    0    0    0]
#  [   0 1631    9   18]
#  [   0   25 1606   27]
#  [   0   26   44 2835]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18914 samples, validate on 4729 samples
# Epoch 1/30
# 18914/18914 [==============================] - 3s 172us/step - loss: 3.1530e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2595 - val_acc: 0.4500 - val_f1_score_macro: 0.4488
# Epoch 2/30
# 18914/18914 [==============================] - 3s 139us/step - loss: 2.9195e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2597 - val_acc: 0.4485 - val_f1_score_macro: 0.4475
# Epoch 3/30
# 18914/18914 [==============================] - 3s 139us/step - loss: 2.7261e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2592 - val_acc: 0.4496 - val_f1_score_macro: 0.4487
# Epoch 4/30
# 18914/18914 [==============================] - 3s 139us/step - loss: 2.5590e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2587 - val_acc: 0.4508 - val_f1_score_macro: 0.4499
# Epoch 5/30
# 18914/18914 [==============================] - 3s 142us/step - loss: 2.4043e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2597 - val_acc: 0.4489 - val_f1_score_macro: 0.4475
# Epoch 6/30
# 18914/18914 [==============================] - 3s 145us/step - loss: 2.2738e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2602 - val_acc: 0.4481 - val_f1_score_macro: 0.4470
# Epoch 7/30
# 18914/18914 [==============================] - 3s 140us/step - loss: 2.1600e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2604 - val_acc: 0.4481 - val_f1_score_macro: 0.4467
# [0.8848692561563849, 0.8921291354807751]
# [[1657    0    0    0]
#  [   0 1598    0   60]
#  [   0  114 1396  148]
#  [   0  488   97 2320]]
# Confusion matrix, without normalization
# [[ 6628     0     0     0]
#  [    0  6502    72    61]
#  [   19   198  6220   198]
#  [    0   142   137 11344]]
# Confusion matrix, without normalization
# [[ 6628     0     0     0]
#  [    0  6526    34    75]
#  [    1    83  6414   137]
#  [    0    89   145 11389]]
# Confusion matrix, without normalization
# [[6628    0    0    0]
#  [   0 6372    2  261]
#  [   0  460 5631  544]
#  [   0 1838  399 9386]]
# Confusion matrix, without normalization
# 1/4 x 2/5
# K-NNeighbors:	[0.9765258215962441, 0.9760531025293483]
# [[1657    0    0    0]
#  [   0 1627   19   13]
#  [   6   39 1580   34]
#  [   0   44   30 2832]]
# Confusion matrix, without normalization
# RandomForest:	[0.983123969039462, 0.9833586744938285]
# [[1657    0    0    0]
#  [   0 1640    8   11]
#  [   0   20 1606   33]
#  [   0   31   30 2845]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18912 samples, validate on 4728 samples
# Epoch 1/30
# 18912/18912 [==============================] - 3s 171us/step - loss: 2.6440e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2626 - val_acc: 0.4431 - val_f1_score_macro: 0.4421
# Epoch 2/30
# 18912/18912 [==============================] - 3s 140us/step - loss: 2.6440e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2640 - val_acc: 0.4389 - val_f1_score_macro: 0.4381
# Epoch 3/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 2.6440e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2642 - val_acc: 0.4389 - val_f1_score_macro: 0.4384
# Epoch 4/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 2.6440e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2636 - val_acc: 0.4393 - val_f1_score_macro: 0.4384
# [0.8903692424819185, 0.8970350869525442]
# [[1657    0    0    0]
#  [   0 1600    2   57]
#  [   0  115 1411  133]
#  [   0  463   94 2349]]
# Confusion matrix, without normalization
# 2/4 x 2/5
# K-NNeighbors:	[0.9755107219895952, 0.9748136228986537]
# [[1657    0    0    0]
#  [   0 1630   16   13]
#  [   2   53 1558   46]
#  [   0   31   32 2843]]
# Confusion matrix, without normalization
# RandomForest:	[0.9810937698261641, 0.9810586879168941]
# [[1657    0    0    0]
#  [   0 1630   12   17]
#  [   0   28 1594   37]
#  [   0   26   29 2851]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18912 samples, validate on 4728 samples
# Epoch 1/30
# 18912/18912 [==============================] - 3s 170us/step - loss: 1.8054e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2593 - val_acc: 0.4499 - val_f1_score_macro: 0.4488
# Epoch 2/30
# 18912/18912 [==============================] - 3s 140us/step - loss: 1.7250e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2597 - val_acc: 0.4492 - val_f1_score_macro: 0.4486
# Epoch 3/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 1.6543e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2595 - val_acc: 0.4497 - val_f1_score_macro: 0.4491
# Epoch 4/30
# 18912/18912 [==============================] - 3s 140us/step - loss: 1.5945e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2599 - val_acc: 0.4492 - val_f1_score_macro: 0.4488
# [0.884151757391194, 0.8908729828505269]
# [[1657    0    0    0]
#  [   0 1594    0   65]
#  [   0  115 1378  166]
#  [   0  457  110 2339]]
# Confusion matrix, without normalization
# 3/4 x 2/5
# K-NNeighbors:	[0.9742418474812841, 0.973991807101108]
# [[1657    0    0    0]
#  [   0 1631   16   12]
#  [   4   41 1567   47]
#  [   0   42   41 2823]]
# Confusion matrix, without normalization
# RandomForest:	[0.9819819819819819, 0.9822786320392086]
# [[1657    0    0    0]
#  [   0 1640    7   12]
#  [   0   21 1598   40]
#  [   0   29   33 2844]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18912 samples, validate on 4728 samples
# Epoch 1/30
# 18912/18912 [==============================] - 3s 175us/step - loss: 2.6440e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2657 - val_acc: 0.4359 - val_f1_score_macro: 0.4353
# Epoch 2/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 2.6440e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2642 - val_acc: 0.4404 - val_f1_score_macro: 0.4397
# Epoch 3/30
# 18912/18912 [==============================] - 3s 142us/step - loss: 2.6440e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2650 - val_acc: 0.4368 - val_f1_score_macro: 0.4363
# Epoch 4/30
# 18912/18912 [==============================] - 3s 139us/step - loss: 2.6440e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2647 - val_acc: 0.4395 - val_f1_score_macro: 0.4389
# Epoch 5/30
# 18912/18912 [==============================] - 3s 140us/step - loss: 2.6440e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2656 - val_acc: 0.4357 - val_f1_score_macro: 0.4360
# [0.8929069914985408, 0.8994242018361827]
# [[1657    0    0    0]
#  [   0 1602    1   56]
#  [   0  118 1425  116]
#  [   0  457   96 2353]]
# Confusion matrix, without normalization
# 4/4 x 2/5
# K-NNeighbors:	[0.971947194719472, 0.9712973191212758]
# [[1657    0    0    0]
#  [   0 1631   10   17]
#  [   7   59 1544   48]
#  [   0   30   50 2825]]
# Confusion matrix, without normalization
# RandomForest:	[0.9796902767199797, 0.9799101612517329]
# [[1657    0    0    0]
#  [   0 1628    7   23]
#  [   0   28 1592   38]
#  [   0   28   36 2841]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18914 samples, validate on 4729 samples
# Epoch 1/30
# 18914/18914 [==============================] - 3s 175us/step - loss: 2.6437e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2609 - val_acc: 0.4468 - val_f1_score_macro: 0.4463
# Epoch 2/30
# 18914/18914 [==============================] - 3s 144us/step - loss: 2.6437e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2610 - val_acc: 0.4468 - val_f1_score_macro: 0.4461
# Epoch 3/30
# 18914/18914 [==============================] - 3s 141us/step - loss: 2.6437e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2604 - val_acc: 0.4487 - val_f1_score_macro: 0.4479
# Epoch 4/30
# 18914/18914 [==============================] - 3s 142us/step - loss: 2.6437e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2607 - val_acc: 0.4475 - val_f1_score_macro: 0.4464
# Epoch 5/30
# 18914/18914 [==============================] - 3s 140us/step - loss: 2.6437e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2607 - val_acc: 0.4479 - val_f1_score_macro: 0.4469
# Epoch 6/30
# 18914/18914 [==============================] - 3s 143us/step - loss: 2.6437e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2608 - val_acc: 0.4475 - val_f1_score_macro: 0.4468
# [0.8865194211728865, 0.8941349998844076]
# [[1657    0    0    0]
#  [   0 1589    1   68]
#  [   0  105 1429  124]
#  [   0  495  101 2309]]
# Confusion matrix, without normalization
# [[ 6628     0     0     0]
#  [    0  6519    61    55]
#  [   19   192  6249   175]
#  [    0   147   153 11323]]
# Confusion matrix, without normalization
# [[ 6628     0     0     0]
#  [    0  6538    34    63]
#  [    0    97  6390   148]
#  [    0   114   128 11381]]
# Confusion matrix, without normalization
# [[6628    0    0    0]
#  [   0 6385    4  246]
#  [   0  453 5643  539]
#  [   0 1872  401 9350]]
# Confusion matrix, without normalization
# 1/4 x 3/5
# K-NNeighbors:	[0.9751300596371019, 0.9748235960084752]
# [[1657    0    0    0]
#  [   0 1635   14   10]
#  [   5   42 1567   45]
#  [   0   47   33 2826]]
# Confusion matrix, without normalization
# RandomForest:	[0.9805862200228398, 0.9809240834181996]
# [[1657    0    0    0]
#  [   0 1631   11   17]
#  [   0   20 1612   27]
#  [   0   35   43 2828]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18912 samples, validate on 4728 samples
# Epoch 1/30
# 18912/18912 [==============================] - 3s 177us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2647 - val_acc: 0.4393 - val_f1_score_macro: 0.4386
# Epoch 2/30
# 18912/18912 [==============================] - 3s 142us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2647 - val_acc: 0.4389 - val_f1_score_macro: 0.4382
# Epoch 3/30
# 18912/18912 [==============================] - 3s 139us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2649 - val_acc: 0.4389 - val_f1_score_macro: 0.4382
# Epoch 4/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2649 - val_acc: 0.4389 - val_f1_score_macro: 0.4384
# [0.8911305671869052, 0.8976875996518008]
# [[1657    0    0    0]
#  [   0 1615    0   44]
#  [   0  118 1406  135]
#  [   0  465   96 2345]]
# Confusion matrix, without normalization
# 2/4 x 3/5
# K-NNeighbors:	[0.9728460855221419, 0.9720579692318273]
# [[1657    0    0    0]
#  [   0 1609   31   19]
#  [   4   45 1564   46]
#  [   0   35   34 2837]]
# Confusion matrix, without normalization
# RandomForest:	[0.9807131074736709, 0.9807387344385208]
# [[1657    0    0    0]
#  [   0 1624   14   21]
#  [   2   23 1599   35]
#  [   0   29   28 2849]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18912 samples, validate on 4728 samples
# Epoch 1/30
# 18912/18912 [==============================] - 3s 181us/step - loss: 1.0126e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2582 - val_acc: 0.4522 - val_f1_score_macro: 0.4514
# Epoch 2/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 9.8711e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2587 - val_acc: 0.4514 - val_f1_score_macro: 0.4509
# Epoch 3/30
# 18912/18912 [==============================] - 3s 143us/step - loss: 9.6263e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2584 - val_acc: 0.4522 - val_f1_score_macro: 0.4519
# Epoch 4/30
# 18912/18912 [==============================] - 3s 140us/step - loss: 9.4329e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2586 - val_acc: 0.4518 - val_f1_score_macro: 0.4513
# [0.8840248699403629, 0.8911072071402155]
# [[1657    0    0    0]
#  [   0 1588    1   70]
#  [   0  119 1407  133]
#  [   0  473  118 2315]]
# Confusion matrix, without normalization
# 3/4 x 3/5
# K-NNeighbors:	[0.9742418474812841, 0.9738646401349946]
# [[1657    0    0    0]
#  [   0 1633   11   15]
#  [   6   46 1554   53]
#  [   0   37   35 2834]]
# Confusion matrix, without normalization
# RandomForest:	[0.9814744321786575, 0.9816305127144458]
# [[1657    0    0    0]
#  [   0 1638    7   14]
#  [   0   27 1600   32]
#  [   0   32   34 2840]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18912 samples, validate on 4728 samples
# Epoch 1/30
# 18912/18912 [==============================] - 3s 179us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2614 - val_acc: 0.4475 - val_f1_score_macro: 0.4467
# Epoch 2/30
# 18912/18912 [==============================] - 3s 142us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2616 - val_acc: 0.4467 - val_f1_score_macro: 0.4463
# Epoch 3/30
# 18912/18912 [==============================] - 3s 138us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2621 - val_acc: 0.4450 - val_f1_score_macro: 0.4444
# Epoch 4/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2617 - val_acc: 0.4463 - val_f1_score_macro: 0.4457
# [0.886308844055323, 0.8936792776240468]
# [[1657    0    0    0]
#  [   0 1590    3   66]
#  [   0  107 1413  139]
#  [   0  488   93 2325]]
# Confusion matrix, without normalization
# 4/4 x 3/5
# K-NNeighbors:	[0.9728357451129729, 0.9721677054528082]
# [[1657    0    0    0]
#  [   0 1621   15   22]
#  [   4   59 1562   33]
#  [   0   46   35 2824]]
# Confusion matrix, without normalization
# RandomForest:	[0.9828636709824828, 0.9829315532188488]
# [[1657    0    0    0]
#  [   0 1628   12   18]
#  [   2   19 1602   35]
#  [   0   29   20 2856]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18914 samples, validate on 4729 samples
# Epoch 1/30
# 18914/18914 [==============================] - 3s 181us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2657 - val_acc: 0.4388 - val_f1_score_macro: 0.4387
# Epoch 2/30
# 18914/18914 [==============================] - 3s 142us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2666 - val_acc: 0.4369 - val_f1_score_macro: 0.4368
# Epoch 3/30
# 18914/18914 [==============================] - 3s 142us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2663 - val_acc: 0.4371 - val_f1_score_macro: 0.4368
# Epoch 4/30
# 18914/18914 [==============================] - 3s 142us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2670 - val_acc: 0.4362 - val_f1_score_macro: 0.4358
# [0.8924854023863925, 0.8991175837487249]
# [[1657    0    0    0]
#  [   0 1598    0   60]
#  [   0  107 1418  133]
#  [   0  452   95 2358]]
# Confusion matrix, without normalization
# [[ 6628     0     0     0]
#  [    0  6498    71    66]
#  [   19   192  6247   177]
#  [    0   165   137 11321]]
# Confusion matrix, without normalization
# [[ 6628     0     0     0]
#  [    0  6521    44    70]
#  [    4    89  6413   129]
#  [    0   125   125 11373]]
# Confusion matrix, without normalization
# [[6628    0    0    0]
#  [   0 6391    4  240]
#  [   0  451 5644  540]
#  [   0 1878  402 9343]]
# Confusion matrix, without normalization
# 1/4 x 4/5
# K-NNeighbors:	[0.9733536353254663, 0.9726518956030046]
# [[1657    0    0    0]
#  [   0 1628   21   10]
#  [   5   52 1565   37]
#  [   0   42   43 2821]]
# Confusion matrix, without normalization
# RandomForest:	[0.9818550945311508, 0.9819363384188453]
# [[1657    0    0    0]
#  [   0 1635    9   15]
#  [   0   27 1606   26]
#  [   0   35   31 2840]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18912 samples, validate on 4728 samples
# Epoch 1/30
# 18912/18912 [==============================] - 3s 183us/step - loss: 8.4621e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2594 - val_acc: 0.4505 - val_f1_score_macro: 0.4503
# Epoch 2/30
# 18912/18912 [==============================] - 3s 143us/step - loss: 8.2907e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2598 - val_acc: 0.4503 - val_f1_score_macro: 0.4501
# Epoch 3/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 8.1389e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2595 - val_acc: 0.4505 - val_f1_score_macro: 0.4502
# Epoch 4/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 7.9811e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2599 - val_acc: 0.4499 - val_f1_score_macro: 0.4496
# [0.8842786448420251, 0.8910360708757231]
# [[1657    0    0    0]
#  [   0 1607    0   52]
#  [   0  117 1389  153]
#  [   0  463  127 2316]]
# Confusion matrix, without normalization
# 2/4 x 4/5
# K-NNeighbors:	[0.9751300596371019, 0.9749608876433541]
# [[1657    0    0    0]
#  [   0 1639   12    8]
#  [   4   40 1564   51]
#  [   0   42   39 2825]]
# Confusion matrix, without normalization
# RandomForest:	[0.980966882375333, 0.9811878851207625]
# [[1657    0    0    0]
#  [   0 1637   13    9]
#  [   2   18 1601   38]
#  [   0   28   42 2836]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18912 samples, validate on 4728 samples
# Epoch 1/30
# 18912/18912 [==============================] - 4s 185us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2646 - val_acc: 0.4416 - val_f1_score_macro: 0.4412
# Epoch 2/30
# 18912/18912 [==============================] - 3s 142us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2649 - val_acc: 0.4406 - val_f1_score_macro: 0.4402
# Epoch 3/30
# 18912/18912 [==============================] - 3s 139us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2644 - val_acc: 0.4418 - val_f1_score_macro: 0.4414
# Epoch 4/30
# 18912/18912 [==============================] - 3s 143us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2648 - val_acc: 0.4404 - val_f1_score_macro: 0.4401
# Epoch 5/30
# 18912/18912 [==============================] - 3s 143us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2647 - val_acc: 0.4404 - val_f1_score_macro: 0.4399
# Epoch 6/30
# 18912/18912 [==============================] - 3s 142us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2644 - val_acc: 0.4420 - val_f1_score_macro: 0.4416
# Epoch 7/30
# 18912/18912 [==============================] - 3s 140us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2648 - val_acc: 0.4412 - val_f1_score_macro: 0.4408
# Epoch 8/30
# 18912/18912 [==============================] - 3s 143us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2647 - val_acc: 0.4410 - val_f1_score_macro: 0.4408
# Epoch 9/30
# 18912/18912 [==============================] - 3s 142us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2649 - val_acc: 0.4406 - val_f1_score_macro: 0.4402
# [0.889861692678594, 0.8967585704690919]
# [[1657    0    0    0]
#  [   0 1591    4   64]
#  [   0  113 1420  126]
#  [   0  472   89 2345]]
# Confusion matrix, without normalization
# 3/4 x 4/5
# K-NNeighbors:	[0.9746225098337774, 0.9744434029547956]
# [[1657    0    0    0]
#  [   0 1633   10   16]
#  [   6   41 1562   50]
#  [   0   43   34 2829]]
# Confusion matrix, without normalization
# RandomForest:	[0.9816013196294886, 0.9817600850550469]
# [[1657    0    0    0]
#  [   0 1632    5   22]
#  [   0   28 1596   35]
#  [   0   29   26 2851]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18912 samples, validate on 4728 samples
# Epoch 1/30
# 18912/18912 [==============================] - 4s 185us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2625 - val_acc: 0.4442 - val_f1_score_macro: 0.4438
# Epoch 2/30
# 18912/18912 [==============================] - 3s 148us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2622 - val_acc: 0.4452 - val_f1_score_macro: 0.4449
# Epoch 3/30
# 18912/18912 [==============================] - 3s 147us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2627 - val_acc: 0.4440 - val_f1_score_macro: 0.4436
# Epoch 4/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2627 - val_acc: 0.4440 - val_f1_score_macro: 0.4436
# Epoch 5/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2623 - val_acc: 0.4448 - val_f1_score_macro: 0.4446
# [0.8879583809161274, 0.8949376535651462]
# [[1657    0    0    0]
#  [   0 1601    0   58]
#  [   0  120 1413  126]
#  [   0  478  101 2327]]
# Confusion matrix, without normalization
# 4/4 x 4/5
# K-NNeighbors:	[0.9733434881949733, 0.9723861280413183]
# [[1657    0    0    0]
#  [   0 1620   19   19]
#  [   8   55 1547   48]
#  [   1   31   29 2844]]
# Confusion matrix, without normalization
# RandomForest:	[0.9823559279004823, 0.9823688465473654]
# [[1657    0    0    0]
#  [   0 1635    8   15]
#  [   0   29 1606   23]
#  [   0   32   32 2841]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18914 samples, validate on 4729 samples
# Epoch 1/30
# 18914/18914 [==============================] - 4s 188us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2659 - val_acc: 0.4377 - val_f1_score_macro: 0.4369
# Epoch 2/30
# 18914/18914 [==============================] - 3s 142us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2658 - val_acc: 0.4384 - val_f1_score_macro: 0.4375
# Epoch 3/30
# 18914/18914 [==============================] - 3s 142us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2663 - val_acc: 0.4369 - val_f1_score_macro: 0.4363
# Epoch 4/30
# 18914/18914 [==============================] - 3s 142us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2661 - val_acc: 0.4373 - val_f1_score_macro: 0.4365
# Epoch 5/30
# 18914/18914 [==============================] - 3s 141us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2661 - val_acc: 0.4375 - val_f1_score_macro: 0.4369
# [0.8924854023863925, 0.89957675572262]
# [[1657    0    0    0]
#  [   0 1593    0   65]
#  [   0   96 1427  135]
#  [   0  466   85 2354]]
# Confusion matrix, without normalization
# [[ 6628     0     0     0]
#  [    0  6520    62    53]
#  [   23   188  6238   186]
#  [    1   158   145 11319]]
# Confusion matrix, without normalization
# [[ 6628     0     0     0]
#  [    0  6539    35    61]
#  [    2   102  6409   122]
#  [    0   124   131 11368]]
# Confusion matrix, without normalization
# [[6628    0    0    0]
#  [   0 6392    4  239]
#  [   0  446 5649  540]
#  [   0 1879  402 9342]]
# Confusion matrix, without normalization
# 1/4 x 5/5
# K-NNeighbors:	[0.9733536353254663, 0.9730084554962832]
# [[1657    0    0    0]
#  [   0 1624   21   14]
#  [   1   43 1560   55]
#  [   0   37   39 2830]]
# Confusion matrix, without normalization
# RandomForest:	[0.9810937698261641, 0.9810942816147507]
# [[1657    0    0    0]
#  [   0 1631   11   17]
#  [   0   28 1595   36]
#  [   0   25   32 2849]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18912 samples, validate on 4728 samples
# Epoch 1/30
# 18912/18912 [==============================] - 4s 189us/step - loss: 6.0755e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2673 - val_acc: 0.4349 - val_f1_score_macro: 0.4349
# Epoch 2/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 5.9886e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2670 - val_acc: 0.4359 - val_f1_score_macro: 0.4359
# Epoch 3/30
# 18912/18912 [==============================] - 3s 140us/step - loss: 5.9045e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2675 - val_acc: 0.4338 - val_f1_score_macro: 0.4339
# Epoch 4/30
# 18912/18912 [==============================] - 3s 143us/step - loss: 5.8236e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2672 - val_acc: 0.4349 - val_f1_score_macro: 0.4345
# Epoch 5/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 5.7366e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.2678 - val_acc: 0.4338 - val_f1_score_macro: 0.4338
# [0.8929069914985408, 0.9004002078689068]
# [[1657    0    0    0]
#  [   0 1609    0   50]
#  [   0   94 1455  110]
#  [   0  492   98 2316]]
# Confusion matrix, without normalization
# 2/4 x 5/5
# K-NNeighbors:	[0.9724654231696486, 0.971703685855846]
# [[1657    0    0    0]
#  [   0 1629   16   14]
#  [   7   55 1542   55]
#  [   0   39   31 2836]]
# Confusion matrix, without normalization
# RandomForest:	[0.983123969039462, 0.983123139560587]
# [[1657    0    0    0]
#  [   0 1627   11   21]
#  [   0   24 1605   30]
#  [   0   30   17 2859]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18912 samples, validate on 4728 samples
# Epoch 1/30
# 18912/18912 [==============================] - 4s 197us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2617 - val_acc: 0.4475 - val_f1_score_macro: 0.4472
# Epoch 2/30
# 18912/18912 [==============================] - 3s 148us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2620 - val_acc: 0.4469 - val_f1_score_macro: 0.4464
# Epoch 3/30
# 18912/18912 [==============================] - 3s 142us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2620 - val_acc: 0.4465 - val_f1_score_macro: 0.4460
# Epoch 4/30
# 18912/18912 [==============================] - 3s 143us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2618 - val_acc: 0.4473 - val_f1_score_macro: 0.4468
# [0.8854206318995052, 0.8919510095333387]
# [[1657    0    0    0]
#  [   0 1604    2   53]
#  [   0  121 1376  162]
#  [   0  463  102 2341]]
# Confusion matrix, without normalization
# 3/4 x 5/5
# K-NNeighbors:	[0.9746225098337774, 0.9741704927405925]
# [[1657    0    0    0]
#  [   0 1633   16   10]
#  [   4   47 1568   40]
#  [   0   38   45 2823]]
# Confusion matrix, without normalization
# RandomForest:	[0.9824895317853064, 0.9828580676730082]
# [[1657    0    0    0]
#  [   0 1634    8   17]
#  [   0   18 1619   22]
#  [   0   35   38 2833]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18912 samples, validate on 4728 samples
# Epoch 1/30
# 18912/18912 [==============================] - 4s 193us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2660 - val_acc: 0.4378 - val_f1_score_macro: 0.4374
# Epoch 2/30
# 18912/18912 [==============================] - 3s 144us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2661 - val_acc: 0.4370 - val_f1_score_macro: 0.4367
# Epoch 3/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2661 - val_acc: 0.4376 - val_f1_score_macro: 0.4372
# Epoch 4/30
# 18912/18912 [==============================] - 3s 142us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2659 - val_acc: 0.4376 - val_f1_score_macro: 0.4372
# Epoch 5/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2659 - val_acc: 0.4376 - val_f1_score_macro: 0.4372
# Epoch 6/30
# 18912/18912 [==============================] - 3s 142us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2665 - val_acc: 0.4368 - val_f1_score_macro: 0.4365
# Epoch 7/30
# 18912/18912 [==============================] - 3s 141us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2658 - val_acc: 0.4380 - val_f1_score_macro: 0.4376
# Epoch 8/30
# 18912/18912 [==============================] - 3s 144us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2660 - val_acc: 0.4374 - val_f1_score_macro: 0.4369
# Epoch 9/30
# 18912/18912 [==============================] - 3s 146us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2660 - val_acc: 0.4374 - val_f1_score_macro: 0.4372
# Epoch 10/30
# 18912/18912 [==============================] - 3s 143us/step - loss: 2.6439e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2659 - val_acc: 0.4378 - val_f1_score_macro: 0.4374
# [0.8912574546377363, 0.8978459606964427]
# [[1657    0    0    0]
#  [   0 1594    2   63]
#  [   0  114 1413  132]
#  [   0  456   90 2360]]
# Confusion matrix, without normalization
# 4/4 x 5/5
# K-NNeighbors:	[0.976897689768977, 0.9766358989500241]
# [[1657    0    0    0]
#  [   0 1630   15   13]
#  [   3   38 1576   41]
#  [   0   42   30 2833]]
# Confusion matrix, without normalization
# RandomForest:	[0.9837522213759837, 0.984332899512707]
# [[1657    0    0    0]
#  [   0 1633    7   18]
#  [   0    9 1618   31]
#  [   0   31   32 2842]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18914 samples, validate on 4729 samples
# Epoch 1/30
# 18914/18914 [==============================] - 4s 194us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2597 - val_acc: 0.4510 - val_f1_score_macro: 0.4501
# Epoch 2/30
# 18914/18914 [==============================] - 3s 143us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2596 - val_acc: 0.4513 - val_f1_score_macro: 0.4505
# Epoch 3/30
# 18914/18914 [==============================] - 3s 141us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2597 - val_acc: 0.4502 - val_f1_score_macro: 0.4493
# Epoch 4/30
# 18914/18914 [==============================] - 3s 142us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2596 - val_acc: 0.4502 - val_f1_score_macro: 0.4492
# Epoch 5/30
# 18914/18914 [==============================] - 3s 143us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2597 - val_acc: 0.4506 - val_f1_score_macro: 0.4499
# Epoch 6/30
# 18914/18914 [==============================] - 3s 142us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2596 - val_acc: 0.4513 - val_f1_score_macro: 0.4505
# Epoch 7/30
# 18914/18914 [==============================] - 3s 142us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2597 - val_acc: 0.4506 - val_f1_score_macro: 0.4499
# Epoch 8/30
# 18914/18914 [==============================] - 3s 141us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2596 - val_acc: 0.4504 - val_f1_score_macro: 0.4495
# Epoch 9/30
# 18914/18914 [==============================] - 3s 142us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2595 - val_acc: 0.4506 - val_f1_score_macro: 0.4497
# Epoch 10/30
# 18914/18914 [==============================] - 3s 142us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2596 - val_acc: 0.4504 - val_f1_score_macro: 0.4495
# Epoch 11/30
# 18914/18914 [==============================] - 3s 143us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2595 - val_acc: 0.4506 - val_f1_score_macro: 0.4497
# Epoch 12/30
# 18914/18914 [==============================] - 3s 142us/step - loss: 2.6436e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2597 - val_acc: 0.4508 - val_f1_score_macro: 0.4500
# [0.8838537699923839, 0.8910554193198148]
# [[1657    0    0    0]
#  [   0 1590    0   68]
#  [   0  118 1404  136]
#  [   0  480  113 2312]]
# Confusion matrix, without normalization
# [[ 6628     0     0     0]
#  [    0  6516    68    51]
#  [   15   183  6246   191]
#  [    0   156   145 11322]]
# Confusion matrix, without normalization
# [[ 6628     0     0     0]
#  [    0  6525    37    73]
#  [    0    79  6437   119]
#  [    0   121   119 11383]]
# Confusion matrix, without normalization
# [[6628    0    0    0]
#  [   0 6397    4  234]
#  [   0  447 5648  540]
#  [   0 1891  403 9329]]
# Confusion matrix, without normalization

# %% [markdown]
# ##byseverity Experiments

# %%
results['byseverity'] = {}
models['byseverity'] = {}
y_test_round = None
y_pred_round = {}

print("By Severity")

for j in range(nrounds):
  for i,fold in enumerate(severities):
    print("{}".format(fold), end=" x ")
    x_test,y_test = eval('xn_'+str(i)),eval('yn_'+str(i))
    x_test,y_test = concatenate_datasets(x_test,y_test,eval('x'+str(fold)),eval('y'+str(fold)))
    if y_test_round is None:
      y_test_round = np.copy(y_test)
    else:
      y_test_round = np.concatenate((y_test_round,y_test))
    x_train,y_train = None,None  
    for ni in list(range(0,4)):
      if ni != i:
        x_train,y_train = concatenate_datasets(x_train,y_train,eval('xn_'+str(ni)),eval('yn_'+str(ni)))
    for tfold in severities[:i]+severities[i+1:]:
      x_train,y_train = concatenate_datasets(x_train,y_train,eval('x'+str(tfold)),eval('y'+str(tfold)))

    print("{}/{}".format(j+1,nrounds))
    for clfname,model in clfs:
      print(clfname, end=":\t")
      if not clfname in results['byseverity']:
        results['byseverity'][clfname] = []
      if "ANN" in clfname:
        y_train_cat = to_categorical(y_train)
        model.compile(optimizer='rmsprop', loss='mean_squared_error', 
                      metrics=['accuracy',f1_score_macro])
        history = model.fit(x_train ,y_train_cat, epochs=epochs, 
                            validation_split=validation_split, 
                            callbacks=[EarlyStopping(patience=3),
                                       ReduceLROnPlateau()])
        y_pred = np.argmax(model.predict(x_test), axis=1)
      else:
        history = model.fit(x_train ,y_train)
        y_pred = model.predict(x_test)
      if not clfname in y_pred_round:
        y_pred_round[clfname] = None
      if y_pred_round[clfname] is None:
        y_pred_round[clfname] = np.copy(y_pred)
      else:
        y_pred_round[clfname] = np.concatenate((y_pred_round[clfname],y_pred))
      if not clfname+str(fold) in models['byseverity']:
        models['byseverity'][clfname+str(fold)] = model
      results['byseverity'][clfname].append([accuracy_score(y_test,y_pred),f1_score(y_test,y_pred,average='macro')])
      print(results['byseverity'][clfname][-1])
      if genconfmat:
        cnf_matrix = confusion_matrix(y_test, y_pred)
        print(cnf_matrix)
        plt.figure(figsize=(tam,tam))
        plot_confusion_matrix(cnf_matrix, classes=class_names, title=clfname+' - Fold '+str(fold)+' - Round '+str(j+1), normalize=False)
        plt.savefig('cnfmatrix_byseverity'+clfname+str(fold)+'round'+str(j)+'.png')
        plt.show()
  for clfname,model in clfs:
    if genconfmat:
      cnf_matrix = confusion_matrix(y_test_round, y_pred_round[clfname])
      print(cnf_matrix)
      plt.figure(figsize=(tam,tam))
      plot_confusion_matrix(cnf_matrix, classes=class_names, title=clfname+' - Round '+str(j+1), normalize=False)
      plt.savefig('cnfmatrix_kfold'+clfname+'_round'+str(j+1)+'.png')
      plt.show()
    y_pred_round[clfname] = None
  y_test_round = None
# Out:
# By Severity
# 007 x 1/5
# K-NNeighbors:	[0.5728927203065134, 0.6340583389954915]
# [[ 952    0    0    0]
#  [   0  752    1 1147]
#  [  13   69 1765   47]
#  [   1  936 2245 2512]]
# Confusion matrix, without normalization
# RandomForest:	[0.5217432950191571, 0.5644203796332148]
# [[ 952    0    0    0]
#  [   0  239   45 1616]
#  [   2   57 1683  152]
#  [   0 1169 1952 2573]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 16864 samples, validate on 4217 samples
# Epoch 1/30
# 16864/16864 [==============================] - 3s 206us/step - loss: 0.0019 - acc: 0.9954 - f1_score_macro: 0.9955 - val_loss: 0.3267 - val_acc: 0.3128 - val_f1_score_macro: 0.3126
# Epoch 2/30
# 16864/16864 [==============================] - 2s 144us/step - loss: 8.7990e-05 - acc: 0.9998 - f1_score_macro: 0.9998 - val_loss: 0.3204 - val_acc: 0.3251 - val_f1_score_macro: 0.3240
# Epoch 3/30
# 16864/16864 [==============================] - 2s 142us/step - loss: 1.9550e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.3065 - val_acc: 0.3562 - val_f1_score_macro: 0.3550
# Epoch 4/30
# 16864/16864 [==============================] - 2s 141us/step - loss: 3.0880e-07 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3262 - val_acc: 0.3123 - val_f1_score_macro: 0.3102
# Epoch 5/30
# 16864/16864 [==============================] - 2s 141us/step - loss: 9.0830e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3207 - val_acc: 0.3277 - val_f1_score_macro: 0.3268
# Epoch 6/30
# 16864/16864 [==============================] - 2s 143us/step - loss: 4.6673e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3200 - val_acc: 0.3280 - val_f1_score_macro: 0.3274
# [0.9992337164750957, 0.9992090422374295]
# [[ 952    0    0    0]
#  [   0 1898    0    2]
#  [   0    2 1889    3]
#  [   0    1    0 5693]]
# Confusion matrix, without normalization
# 014 x 1/5
# K-NNeighbors:	[0.4732599795291709, 0.4253133750548309]
# [[1890    0    0    0]
#  [   6   31  165 1693]
#  [ 176  231  414 1079]
#  [   0  364  403 1364]]
# Confusion matrix, without normalization
# RandomForest:	[0.5269959058341863, 0.5000494498083343]
# [[1890    0    0    0]
#  [   0   49  224 1622]
#  [  10  237 1100  553]
#  [   0  370  681 1080]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18964 samples, validate on 4741 samples
# Epoch 1/30
# 18964/18964 [==============================] - 4s 204us/step - loss: 1.3157e-04 - acc: 0.9997 - f1_score_macro: 0.9997 - val_loss: 0.2712 - val_acc: 0.4339 - val_f1_score_macro: 0.4338
# Epoch 2/30
# 18964/18964 [==============================] - 3s 144us/step - loss: 3.5086e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2650 - val_acc: 0.4495 - val_f1_score_macro: 0.4487
# Epoch 3/30
# 18964/18964 [==============================] - 3s 142us/step - loss: 2.6401e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2710 - val_acc: 0.4326 - val_f1_score_macro: 0.4328
# Epoch 4/30
# 18964/18964 [==============================] - 3s 141us/step - loss: 2.6370e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2701 - val_acc: 0.4372 - val_f1_score_macro: 0.4369
# Epoch 5/30
# 18964/18964 [==============================] - 3s 141us/step - loss: 2.6368e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2686 - val_acc: 0.4400 - val_f1_score_macro: 0.4401
# [1.0, 1.0]
# [[1890    0    0    0]
#  [   0 1895    0    0]
#  [   0    0 1900    0]
#  [   0    0    0 2131]]
# Confusion matrix, without normalization
# 021 x 1/5
# K-NNeighbors:	[0.5248443928684461, 0.541617687679397]
# [[1890    0    0    0]
#  [   0  431  527  936]
#  [   0   92  885  920]
#  [   2 1627  400 1769]]
# Confusion matrix, without normalization
# RandomForest:	[0.5203080493722967, 0.5196803268796205]
# [[1890    0    0    0]
#  [   0   27  147 1720]
#  [   0   24 1041  832]
#  [   0 1369  455 1974]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 17633 samples, validate on 4409 samples
# Epoch 1/30
# 17633/17633 [==============================] - 4s 207us/step - loss: 2.8372e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1423 - val_acc: 0.7124 - val_f1_score_macro: 0.7124
# Epoch 2/30
# 17633/17633 [==============================] - 3s 142us/step - loss: 2.8284e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1398 - val_acc: 0.7176 - val_f1_score_macro: 0.7176
# Epoch 3/30
# 17633/17633 [==============================] - 2s 141us/step - loss: 2.8360e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1365 - val_acc: 0.7237 - val_f1_score_macro: 0.7237
# Epoch 4/30
# 17633/17633 [==============================] - 3s 143us/step - loss: 2.8359e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1346 - val_acc: 0.7283 - val_f1_score_macro: 0.7283
# Epoch 5/30
# 17633/17633 [==============================] - 3s 143us/step - loss: 2.8359e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1333 - val_acc: 0.7310 - val_f1_score_macro: 0.7310
# Epoch 6/30
# 17633/17633 [==============================] - 3s 143us/step - loss: 2.8359e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1327 - val_acc: 0.7317 - val_f1_score_macro: 0.7317
# Epoch 7/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8358e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1310 - val_acc: 0.7346 - val_f1_score_macro: 0.7346
# Epoch 8/30
# 17633/17633 [==============================] - 3s 142us/step - loss: 2.8358e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1306 - val_acc: 0.7358 - val_f1_score_macro: 0.7358
# Epoch 9/30
# 17633/17633 [==============================] - 3s 144us/step - loss: 2.8358e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1295 - val_acc: 0.7376 - val_f1_score_macro: 0.7376
# Epoch 10/30
# 17633/17633 [==============================] - 3s 143us/step - loss: 2.8358e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1294 - val_acc: 0.7378 - val_f1_score_macro: 0.7378
# Epoch 11/30
# 17633/17633 [==============================] - 2s 141us/step - loss: 2.8358e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1293 - val_acc: 0.7376 - val_f1_score_macro: 0.7376
# Epoch 12/30
# 17633/17633 [==============================] - 3s 142us/step - loss: 2.8358e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1281 - val_acc: 0.7401 - val_f1_score_macro: 0.7401
# Epoch 13/30
# 17633/17633 [==============================] - 3s 144us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1272 - val_acc: 0.7412 - val_f1_score_macro: 0.7412
# Epoch 14/30
# 17633/17633 [==============================] - 3s 143us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1277 - val_acc: 0.7408 - val_f1_score_macro: 0.7408
# Epoch 15/30
# 17633/17633 [==============================] - 3s 142us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1268 - val_acc: 0.7421 - val_f1_score_macro: 0.7421
# Epoch 16/30
# 17633/17633 [==============================] - 2s 141us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1261 - val_acc: 0.7439 - val_f1_score_macro: 0.7439
# Epoch 17/30
# 17633/17633 [==============================] - 3s 142us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1263 - val_acc: 0.7435 - val_f1_score_macro: 0.7435
# Epoch 18/30
# 17633/17633 [==============================] - 3s 143us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1257 - val_acc: 0.7451 - val_f1_score_macro: 0.7451
# Epoch 19/30
# 17633/17633 [==============================] - 2s 141us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1251 - val_acc: 0.7462 - val_f1_score_macro: 0.7462
# Epoch 20/30
# 17633/17633 [==============================] - 2s 141us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1255 - val_acc: 0.7455 - val_f1_score_macro: 0.7455
# Epoch 21/30
# 17633/17633 [==============================] - 3s 145us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1246 - val_acc: 0.7476 - val_f1_score_macro: 0.7476
# Epoch 22/30
# 17633/17633 [==============================] - 3s 144us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1241 - val_acc: 0.7480 - val_f1_score_macro: 0.7480
# Epoch 23/30
# 17633/17633 [==============================] - 2s 141us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1241 - val_acc: 0.7478 - val_f1_score_macro: 0.7478
# Epoch 24/30
# 17633/17633 [==============================] - 2s 140us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1240 - val_acc: 0.7485 - val_f1_score_macro: 0.7485
# Epoch 25/30
# 17633/17633 [==============================] - 2s 142us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1234 - val_acc: 0.7498 - val_f1_score_macro: 0.7498
# Epoch 26/30
# 17633/17633 [==============================] - 3s 142us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1238 - val_acc: 0.7489 - val_f1_score_macro: 0.7489
# Epoch 27/30
# 17633/17633 [==============================] - 2s 142us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1232 - val_acc: 0.7498 - val_f1_score_macro: 0.7498
# Epoch 28/30
# 17633/17633 [==============================] - 3s 142us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1229 - val_acc: 0.7510 - val_f1_score_macro: 0.7510
# Epoch 29/30
# 17633/17633 [==============================] - 3s 142us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1231 - val_acc: 0.7505 - val_f1_score_macro: 0.7505
# Epoch 30/30
# 17633/17633 [==============================] - 3s 142us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1223 - val_acc: 0.7519 - val_f1_score_macro: 0.7519
# [0.8398565249498893, 0.8468104177761868]
# [[1890    0    0    0]
#  [   0 1894    0    0]
#  [   0  137 1341  419]
#  [   0  636  326 2836]]
# Confusion matrix, without normalization
# 028 x 1/5
# K-NNeighbors:	[0.503433703116746, 0.2556811807760061]
# [[1895    0    1    0]
#  [   0   11    0  935]
#  [   0    0    0  944]
#  [   0    0    0    0]]
# Confusion matrix, without normalization
# RandomForest:	[0.5068674062334918, 0.26186790505675955]
# [[1896    0    0    0]
#  [   0   23    0  923]
#  [   0    0    0  944]
#  [   0    0    0    0]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 22188 samples, validate on 5547 samples
# Epoch 1/30
# 22188/22188 [==============================] - 4s 199us/step - loss: 2.2539e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1264 - val_acc: 0.7272 - val_f1_score_macro: 0.7266
# Epoch 2/30
# 22188/22188 [==============================] - 3s 145us/step - loss: 2.2536e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1257 - val_acc: 0.7298 - val_f1_score_macro: 0.7290
# Epoch 3/30
# 22188/22188 [==============================] - 3s 146us/step - loss: 2.2536e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1258 - val_acc: 0.7292 - val_f1_score_macro: 0.7282
# Epoch 4/30
# 22188/22188 [==============================] - 3s 145us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1259 - val_acc: 0.7287 - val_f1_score_macro: 0.7280
# Epoch 5/30
# 22188/22188 [==============================] - 3s 152us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1262 - val_acc: 0.7274 - val_f1_score_macro: 0.7272
# [0.7033808769149498, 0.5043314586739696]
# [[1896    0    0    0]
#  [   0  262    0  684]
#  [   0  428  505   11]
#  [   0    0    0    0]]
# Confusion matrix, without normalization
# [[6627    0    1    0]
#  [   6 1225  693 4711]
#  [ 189  392 3064 2990]
#  [   3 2927 3048 5645]]
# Confusion matrix, without normalization
# [[6628    0    0    0]
#  [   0  338  416 5881]
#  [  12  318 3824 2481]
#  [   0 2908 3088 5627]]
# Confusion matrix, without normalization
# [[ 6628     0     0     0]
#  [    0  5949     0   686]
#  [    0   567  5635   433]
#  [    0   637   326 10660]]
# Confusion matrix, without normalization
# 007 x 2/5
# K-NNeighbors:	[0.5728927203065134, 0.6340583389954915]
# [[ 952    0    0    0]
#  [   0  752    1 1147]
#  [  13   69 1765   47]
#  [   1  936 2245 2512]]
# Confusion matrix, without normalization
# RandomForest:	[0.5560344827586207, 0.5830558595993853]
# [[ 952    0    0    0]
#  [   0  253    5 1642]
#  [   2   66 1708  118]
#  [   0  753 2049 2892]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 16864 samples, validate on 4217 samples
# Epoch 1/30
# 16864/16864 [==============================] - 4s 215us/step - loss: 2.3114e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.3089 - val_acc: 0.3550 - val_f1_score_macro: 0.3548
# Epoch 2/30
# 16864/16864 [==============================] - 2s 145us/step - loss: 5.0682e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3106 - val_acc: 0.3486 - val_f1_score_macro: 0.3469
# Epoch 3/30
# 16864/16864 [==============================] - 2s 145us/step - loss: 1.9608e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3112 - val_acc: 0.3481 - val_f1_score_macro: 0.3469
# Epoch 4/30
# 16864/16864 [==============================] - 2s 146us/step - loss: 1.5944e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3112 - val_acc: 0.3498 - val_f1_score_macro: 0.3488
# [0.9999042145593869, 0.9998682125192271]
# [[ 952    0    0    0]
#  [   0 1900    0    0]
#  [   0    1 1893    0]
#  [   0    0    0 5694]]
# Confusion matrix, without normalization
# 014 x 2/5
# K-NNeighbors:	[0.4732599795291709, 0.4253133750548309]
# [[1890    0    0    0]
#  [   6   31  165 1693]
#  [ 176  231  414 1079]
#  [   0  364  403 1364]]
# Confusion matrix, without normalization
# RandomForest:	[0.5216223132036848, 0.4916497083765317]
# [[1890    0    0    0]
#  [   0   27  304 1564]
#  [  27  245 1089  539]
#  [   0  384  676 1071]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18964 samples, validate on 4741 samples
# Epoch 1/30
# 18964/18964 [==============================] - 4s 211us/step - loss: 2.6368e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2723 - val_acc: 0.4318 - val_f1_score_macro: 0.4314
# Epoch 2/30
# 18964/18964 [==============================] - 3s 145us/step - loss: 2.6367e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2713 - val_acc: 0.4343 - val_f1_score_macro: 0.4344
# Epoch 3/30
# 18964/18964 [==============================] - 3s 144us/step - loss: 2.6367e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2711 - val_acc: 0.4339 - val_f1_score_macro: 0.4340
# Epoch 4/30
# 18964/18964 [==============================] - 3s 145us/step - loss: 2.6367e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2694 - val_acc: 0.4385 - val_f1_score_macro: 0.4386
# Epoch 5/30
# 18964/18964 [==============================] - 3s 144us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2703 - val_acc: 0.4358 - val_f1_score_macro: 0.4357
# Epoch 6/30
# 18964/18964 [==============================] - 3s 147us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2701 - val_acc: 0.4356 - val_f1_score_macro: 0.4353
# Epoch 7/30
# 18964/18964 [==============================] - 3s 147us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2693 - val_acc: 0.4391 - val_f1_score_macro: 0.4390
# Epoch 8/30
# 18964/18964 [==============================] - 3s 146us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2684 - val_acc: 0.4406 - val_f1_score_macro: 0.4405
# Epoch 9/30
# 18964/18964 [==============================] - 3s 143us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2688 - val_acc: 0.4406 - val_f1_score_macro: 0.4403
# Epoch 10/30
# 18964/18964 [==============================] - 3s 145us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2684 - val_acc: 0.4404 - val_f1_score_macro: 0.4406
# Epoch 11/30
# 18964/18964 [==============================] - 3s 146us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2686 - val_acc: 0.4402 - val_f1_score_macro: 0.4399
# Epoch 12/30
# 18964/18964 [==============================] - 3s 145us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2682 - val_acc: 0.4408 - val_f1_score_macro: 0.4412
# Epoch 13/30
# 18964/18964 [==============================] - 3s 146us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2686 - val_acc: 0.4400 - val_f1_score_macro: 0.4402
# Epoch 14/30
# 18964/18964 [==============================] - 3s 145us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2679 - val_acc: 0.4413 - val_f1_score_macro: 0.4412
# Epoch 15/30
# 18964/18964 [==============================] - 3s 143us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2680 - val_acc: 0.4408 - val_f1_score_macro: 0.4412
# Epoch 16/30
# 18964/18964 [==============================] - 3s 145us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2679 - val_acc: 0.4408 - val_f1_score_macro: 0.4413
# Epoch 17/30
# 18964/18964 [==============================] - 3s 146us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2677 - val_acc: 0.4421 - val_f1_score_macro: 0.4419
# Epoch 18/30
# 18964/18964 [==============================] - 3s 147us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2677 - val_acc: 0.4423 - val_f1_score_macro: 0.4419
# Epoch 19/30
# 18964/18964 [==============================] - 3s 144us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2677 - val_acc: 0.4419 - val_f1_score_macro: 0.4419
# Epoch 20/30
# 18964/18964 [==============================] - 3s 144us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2674 - val_acc: 0.4427 - val_f1_score_macro: 0.4427
# Epoch 21/30
# 18964/18964 [==============================] - 3s 144us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2676 - val_acc: 0.4421 - val_f1_score_macro: 0.4420
# Epoch 22/30
# 18964/18964 [==============================] - 3s 146us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2674 - val_acc: 0.4421 - val_f1_score_macro: 0.4422
# Epoch 23/30
# 18964/18964 [==============================] - 3s 147us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2674 - val_acc: 0.4421 - val_f1_score_macro: 0.4422
# Epoch 24/30
# 18964/18964 [==============================] - 3s 146us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2675 - val_acc: 0.4419 - val_f1_score_macro: 0.4418
# Epoch 25/30
# 18964/18964 [==============================] - 3s 148us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2675 - val_acc: 0.4419 - val_f1_score_macro: 0.4420
# Epoch 26/30
# 18964/18964 [==============================] - 3s 145us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2672 - val_acc: 0.4425 - val_f1_score_macro: 0.4424
# Epoch 27/30
# 18964/18964 [==============================] - 3s 145us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2676 - val_acc: 0.4421 - val_f1_score_macro: 0.4419
# Epoch 28/30
# 18964/18964 [==============================] - 3s 146us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2673 - val_acc: 0.4425 - val_f1_score_macro: 0.4425
# Epoch 29/30
# 18964/18964 [==============================] - 3s 145us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2672 - val_acc: 0.4429 - val_f1_score_macro: 0.4426
# Epoch 30/30
# 18964/18964 [==============================] - 3s 145us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2673 - val_acc: 0.4425 - val_f1_score_macro: 0.4426
# [1.0, 1.0]
# [[1890    0    0    0]
#  [   0 1895    0    0]
#  [   0    0 1900    0]
#  [   0    0    0 2131]]
# Confusion matrix, without normalization
# 021 x 2/5
# K-NNeighbors:	[0.5248443928684461, 0.541617687679397]
# [[1890    0    0    0]
#  [   0  431  527  936]
#  [   0   92  885  920]
#  [   2 1627  400 1769]]
# Confusion matrix, without normalization
# RandomForest:	[0.5554383373773605, 0.5478050191589958]
# [[1890    0    0    0]
#  [   0   25  142 1727]
#  [   0   28 1237  632]
#  [   0 1238  447 2113]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 17633 samples, validate on 4409 samples
# Epoch 1/30
# 17633/17633 [==============================] - 4s 225us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1396 - val_acc: 0.7190 - val_f1_score_macro: 0.7190
# Epoch 2/30
# 17633/17633 [==============================] - 3s 153us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1381 - val_acc: 0.7213 - val_f1_score_macro: 0.7211
# Epoch 3/30
# 17633/17633 [==============================] - 3s 156us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1379 - val_acc: 0.7215 - val_f1_score_macro: 0.7215
# Epoch 4/30
# 17633/17633 [==============================] - 3s 154us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1365 - val_acc: 0.7247 - val_f1_score_macro: 0.7247
# Epoch 5/30
# 17633/17633 [==============================] - 3s 149us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1364 - val_acc: 0.7253 - val_f1_score_macro: 0.7254
# Epoch 6/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1358 - val_acc: 0.7262 - val_f1_score_macro: 0.7262
# Epoch 7/30
# 17633/17633 [==============================] - 3s 144us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1353 - val_acc: 0.7271 - val_f1_score_macro: 0.7271
# Epoch 8/30
# 17633/17633 [==============================] - 3s 149us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1347 - val_acc: 0.7278 - val_f1_score_macro: 0.7278
# Epoch 9/30
# 17633/17633 [==============================] - 3s 144us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1345 - val_acc: 0.7281 - val_f1_score_macro: 0.7281
# Epoch 10/30
# 17633/17633 [==============================] - 3s 148us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1342 - val_acc: 0.7287 - val_f1_score_macro: 0.7287
# Epoch 11/30
# 17633/17633 [==============================] - 3s 145us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1337 - val_acc: 0.7301 - val_f1_score_macro: 0.7301
# Epoch 12/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1335 - val_acc: 0.7303 - val_f1_score_macro: 0.7303
# Epoch 13/30
# 17633/17633 [==============================] - 3s 145us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1332 - val_acc: 0.7310 - val_f1_score_macro: 0.7310
# Epoch 14/30
# 17633/17633 [==============================] - 3s 148us/step - loss: 2.8357e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1329 - val_acc: 0.7312 - val_f1_score_macro: 0.7312
# Epoch 15/30
# 17633/17633 [==============================] - 3s 145us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1328 - val_acc: 0.7317 - val_f1_score_macro: 0.7317
# Epoch 16/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1325 - val_acc: 0.7324 - val_f1_score_macro: 0.7324
# Epoch 17/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1323 - val_acc: 0.7324 - val_f1_score_macro: 0.7324
# Epoch 18/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1321 - val_acc: 0.7326 - val_f1_score_macro: 0.7326
# Epoch 19/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1317 - val_acc: 0.7333 - val_f1_score_macro: 0.7333
# Epoch 20/30
# 17633/17633 [==============================] - 3s 150us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1314 - val_acc: 0.7340 - val_f1_score_macro: 0.7340
# Epoch 21/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1317 - val_acc: 0.7330 - val_f1_score_macro: 0.7330
# Epoch 22/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1312 - val_acc: 0.7342 - val_f1_score_macro: 0.7342
# Epoch 23/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1313 - val_acc: 0.7340 - val_f1_score_macro: 0.7340
# Epoch 24/30
# 17633/17633 [==============================] - 3s 144us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1308 - val_acc: 0.7346 - val_f1_score_macro: 0.7346
# Epoch 25/30
# 17633/17633 [==============================] - 3s 145us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1307 - val_acc: 0.7353 - val_f1_score_macro: 0.7353
# Epoch 26/30
# 17633/17633 [==============================] - 3s 144us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1307 - val_acc: 0.7355 - val_f1_score_macro: 0.7355
# Epoch 27/30
# 17633/17633 [==============================] - 3s 145us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1307 - val_acc: 0.7353 - val_f1_score_macro: 0.7353
# Epoch 28/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1306 - val_acc: 0.7353 - val_f1_score_macro: 0.7353
# Epoch 29/30
# 17633/17633 [==============================] - 3s 145us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1299 - val_acc: 0.7374 - val_f1_score_macro: 0.7374
# Epoch 30/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1303 - val_acc: 0.7367 - val_f1_score_macro: 0.7367
# [0.8439708830045364, 0.849934699394102]
# [[1890    0    0    0]
#  [   0 1894    0    0]
#  [   0  149 1337  411]
#  [   0  595  324 2879]]
# Confusion matrix, without normalization
# 028 x 2/5
# K-NNeighbors:	[0.503433703116746, 0.2556811807760061]
# [[1895    0    1    0]
#  [   0   11    0  935]
#  [   0    0    0  944]
#  [   0    0    0    0]]
# Confusion matrix, without normalization
# RandomForest:	[0.4989434759640782, 0.2504600862619915]
# [[1887    0    9    0]
#  [   0    2    0  944]
#  [   0    0    0  944]
#  [   0    0    0    0]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 22188 samples, validate on 5547 samples
# Epoch 1/30
# 22188/22188 [==============================] - 5s 204us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1232 - val_acc: 0.7343 - val_f1_score_macro: 0.7333
# Epoch 2/30
# 22188/22188 [==============================] - 3s 145us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1231 - val_acc: 0.7345 - val_f1_score_macro: 0.7334
# Epoch 3/30
# 22188/22188 [==============================] - 3s 145us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1231 - val_acc: 0.7343 - val_f1_score_macro: 0.7332
# Epoch 4/30
# 22188/22188 [==============================] - 3s 147us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1231 - val_acc: 0.7343 - val_f1_score_macro: 0.7332
# Epoch 5/30
# 22188/22188 [==============================] - 3s 144us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1231 - val_acc: 0.7343 - val_f1_score_macro: 0.7332
# [0.6933438985736925, 0.49454672367158187]
# [[1896    0    0    0]
#  [   0  213    0  733]
#  [   0  411  516   17]
#  [   0    0    0    0]]
# Confusion matrix, without normalization
# [[6627    0    1    0]
#  [   6 1225  693 4711]
#  [ 189  392 3064 2990]
#  [   3 2927 3048 5645]]
# Confusion matrix, without normalization
# [[6619    0    9    0]
#  [   0  307  451 5877]
#  [  29  339 4034 2233]
#  [   0 2375 3172 6076]]
# Confusion matrix, without normalization
# [[ 6628     0     0     0]
#  [    0  5902     0   733]
#  [    0   561  5646   428]
#  [    0   595   324 10704]]
# Confusion matrix, without normalization
# 007 x 3/5
# K-NNeighbors:	[0.5728927203065134, 0.6340583389954915]
# [[ 952    0    0    0]
#  [   0  752    1 1147]
#  [  13   69 1765   47]
#  [   1  936 2245 2512]]
# Confusion matrix, without normalization
# RandomForest:	[0.5261494252873563, 0.5550285198841423]
# [[ 952    0    0    0]
#  [   0  109    0 1791]
#  [   2   54 1725  113]
#  [   0 1103 1884 2707]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 16864 samples, validate on 4217 samples
# Epoch 1/30
# 16864/16864 [==============================] - 4s 226us/step - loss: 2.9970e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3061 - val_acc: 0.3588 - val_f1_score_macro: 0.3575
# Epoch 2/30
# 16864/16864 [==============================] - 2s 145us/step - loss: 1.1963e-09 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3058 - val_acc: 0.3609 - val_f1_score_macro: 0.3602
# Epoch 3/30
# 16864/16864 [==============================] - 2s 144us/step - loss: 9.2613e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3056 - val_acc: 0.3621 - val_f1_score_macro: 0.3610
# Epoch 4/30
# 16864/16864 [==============================] - 2s 144us/step - loss: 8.0777e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3054 - val_acc: 0.3628 - val_f1_score_macro: 0.3619
# Epoch 5/30
# 16864/16864 [==============================] - 2s 146us/step - loss: 7.2414e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3058 - val_acc: 0.3619 - val_f1_score_macro: 0.3605
# Epoch 6/30
# 16864/16864 [==============================] - 2s 146us/step - loss: 6.6309e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3056 - val_acc: 0.3614 - val_f1_score_macro: 0.3608
# Epoch 7/30
# 16864/16864 [==============================] - 2s 145us/step - loss: 6.1994e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3060 - val_acc: 0.3602 - val_f1_score_macro: 0.3594
# [0.9999042145593869, 0.9998682125192271]
# [[ 952    0    0    0]
#  [   0 1900    0    0]
#  [   0    1 1893    0]
#  [   0    0    0 5694]]
# Confusion matrix, without normalization
# 014 x 3/5
# K-NNeighbors:	[0.4732599795291709, 0.4253133750548309]
# [[1890    0    0    0]
#  [   6   31  165 1693]
#  [ 176  231  414 1079]
#  [   0  364  403 1364]]
# Confusion matrix, without normalization
# RandomForest:	[0.5656345957011258, 0.532582176296474]
# [[1890    0    0    0]
#  [   0   43  256 1596]
#  [   9  252 1246  393]
#  [   0  372  517 1242]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18964 samples, validate on 4741 samples
# Epoch 1/30
# 18964/18964 [==============================] - 4s 221us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2691 - val_acc: 0.4391 - val_f1_score_macro: 0.4380
# Epoch 2/30
# 18964/18964 [==============================] - 3s 145us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2689 - val_acc: 0.4387 - val_f1_score_macro: 0.4376
# Epoch 3/30
# 18964/18964 [==============================] - 3s 147us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2688 - val_acc: 0.4398 - val_f1_score_macro: 0.4388
# Epoch 4/30
# 18964/18964 [==============================] - 3s 147us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2685 - val_acc: 0.4404 - val_f1_score_macro: 0.4395
# Epoch 5/30
# 18964/18964 [==============================] - 3s 148us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2683 - val_acc: 0.4406 - val_f1_score_macro: 0.4403
# Epoch 6/30
# 18964/18964 [==============================] - 3s 148us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2681 - val_acc: 0.4413 - val_f1_score_macro: 0.4407
# Epoch 7/30
# 18964/18964 [==============================] - 3s 146us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2680 - val_acc: 0.4410 - val_f1_score_macro: 0.4405
# Epoch 8/30
# 18964/18964 [==============================] - 3s 146us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2677 - val_acc: 0.4419 - val_f1_score_macro: 0.4412
# Epoch 9/30
# 18964/18964 [==============================] - 3s 145us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2677 - val_acc: 0.4415 - val_f1_score_macro: 0.4410
# Epoch 10/30
# 18964/18964 [==============================] - 3s 146us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2676 - val_acc: 0.4417 - val_f1_score_macro: 0.4416
# Epoch 11/30
# 18964/18964 [==============================] - 3s 145us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2675 - val_acc: 0.4423 - val_f1_score_macro: 0.4420
# Epoch 12/30
# 18964/18964 [==============================] - 3s 147us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2673 - val_acc: 0.4427 - val_f1_score_macro: 0.4422
# Epoch 13/30
# 18964/18964 [==============================] - 3s 146us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2676 - val_acc: 0.4419 - val_f1_score_macro: 0.4416
# Epoch 14/30
# 18964/18964 [==============================] - 3s 149us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2675 - val_acc: 0.4425 - val_f1_score_macro: 0.4424
# Epoch 15/30
# 18964/18964 [==============================] - 3s 146us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2674 - val_acc: 0.4429 - val_f1_score_macro: 0.4428
# [1.0, 1.0]
# [[1890    0    0    0]
#  [   0 1895    0    0]
#  [   0    0 1900    0]
#  [   0    0    0 2131]]
# Confusion matrix, without normalization
# 021 x 3/5
# K-NNeighbors:	[0.5248443928684461, 0.541617687679397]
# [[1890    0    0    0]
#  [   0  431  527  936]
#  [   0   92  885  920]
#  [   2 1627  400 1769]]
# Confusion matrix, without normalization
# RandomForest:	[0.5106023842177445, 0.5197960786245089]
# [[1890    0    0    0]
#  [   0   31  239 1624]
#  [   0   22 1118  757]
#  [   0 1587  410 1801]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 17633 samples, validate on 4409 samples
# Epoch 1/30
# 17633/17633 [==============================] - 4s 227us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1365 - val_acc: 0.7240 - val_f1_score_macro: 0.7240
# Epoch 2/30
# 17633/17633 [==============================] - 3s 148us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1359 - val_acc: 0.7253 - val_f1_score_macro: 0.7253
# Epoch 3/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1359 - val_acc: 0.7258 - val_f1_score_macro: 0.7258
# Epoch 4/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1354 - val_acc: 0.7267 - val_f1_score_macro: 0.7267
# Epoch 5/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1352 - val_acc: 0.7274 - val_f1_score_macro: 0.7274
# Epoch 6/30
# 17633/17633 [==============================] - 3s 150us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1348 - val_acc: 0.7285 - val_f1_score_macro: 0.7285
# Epoch 7/30
# 17633/17633 [==============================] - 3s 149us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1346 - val_acc: 0.7283 - val_f1_score_macro: 0.7283
# Epoch 8/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1344 - val_acc: 0.7290 - val_f1_score_macro: 0.7288
# Epoch 9/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1341 - val_acc: 0.7294 - val_f1_score_macro: 0.7294
# Epoch 10/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1338 - val_acc: 0.7294 - val_f1_score_macro: 0.7294
# Epoch 11/30
# 17633/17633 [==============================] - 3s 151us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1336 - val_acc: 0.7301 - val_f1_score_macro: 0.7302
# Epoch 12/30
# 17633/17633 [==============================] - 3s 152us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1333 - val_acc: 0.7310 - val_f1_score_macro: 0.7309
# Epoch 13/30
# 17633/17633 [==============================] - 3s 152us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1332 - val_acc: 0.7310 - val_f1_score_macro: 0.7310
# Epoch 14/30
# 17633/17633 [==============================] - 3s 145us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1331 - val_acc: 0.7321 - val_f1_score_macro: 0.7320
# Epoch 15/30
# 17633/17633 [==============================] - 3s 148us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1329 - val_acc: 0.7324 - val_f1_score_macro: 0.7324
# Epoch 16/30
# 17633/17633 [==============================] - 3s 144us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1327 - val_acc: 0.7326 - val_f1_score_macro: 0.7326
# Epoch 17/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1326 - val_acc: 0.7330 - val_f1_score_macro: 0.7330
# Epoch 18/30
# 17633/17633 [==============================] - 3s 144us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1324 - val_acc: 0.7333 - val_f1_score_macro: 0.7333
# Epoch 19/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1322 - val_acc: 0.7335 - val_f1_score_macro: 0.7335
# Epoch 20/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1321 - val_acc: 0.7335 - val_f1_score_macro: 0.7335
# Epoch 21/30
# 17633/17633 [==============================] - 3s 145us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1319 - val_acc: 0.7337 - val_f1_score_macro: 0.7337
# Epoch 22/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1318 - val_acc: 0.7342 - val_f1_score_macro: 0.7342
# Epoch 23/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1317 - val_acc: 0.7342 - val_f1_score_macro: 0.7342
# Epoch 24/30
# 17633/17633 [==============================] - 3s 148us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1316 - val_acc: 0.7344 - val_f1_score_macro: 0.7344
# Epoch 25/30
# 17633/17633 [==============================] - 3s 148us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1315 - val_acc: 0.7346 - val_f1_score_macro: 0.7346
# Epoch 26/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1314 - val_acc: 0.7349 - val_f1_score_macro: 0.7349
# Epoch 27/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1312 - val_acc: 0.7349 - val_f1_score_macro: 0.7349
# Epoch 28/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1312 - val_acc: 0.7351 - val_f1_score_macro: 0.7351
# Epoch 29/30
# 17633/17633 [==============================] - 3s 145us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1311 - val_acc: 0.7351 - val_f1_score_macro: 0.7351
# Epoch 30/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1312 - val_acc: 0.7351 - val_f1_score_macro: 0.7351
# [0.8443928684460386, 0.8502910844033126]
# [[1890    0    0    0]
#  [   0 1894    0    0]
#  [   0  152 1339  406]
#  [   0  593  324 2881]]
# Confusion matrix, without normalization
# 028 x 3/5
# K-NNeighbors:	[0.503433703116746, 0.2556811807760061]
# [[1895    0    1    0]
#  [   0   11    0  935]
#  [   0    0    0  944]
#  [   0    0    0    0]]
# Confusion matrix, without normalization
# RandomForest:	[0.5161119915478077, 0.2788844621513944]
# [[1896    0    0    0]
#  [   0   58    0  888]
#  [   0    0    0  944]
#  [   0    0    0    0]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 22188 samples, validate on 5547 samples
# Epoch 1/30
# 22188/22188 [==============================] - 5s 216us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1233 - val_acc: 0.7348 - val_f1_score_macro: 0.7334
# Epoch 2/30
# 22188/22188 [==============================] - 3s 146us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1232 - val_acc: 0.7350 - val_f1_score_macro: 0.7336
# Epoch 3/30
# 22188/22188 [==============================] - 3s 147us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1232 - val_acc: 0.7352 - val_f1_score_macro: 0.7339
# Epoch 4/30
# 22188/22188 [==============================] - 3s 149us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1231 - val_acc: 0.7357 - val_f1_score_macro: 0.7342
# Epoch 5/30
# 22188/22188 [==============================] - 3s 148us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1231 - val_acc: 0.7361 - val_f1_score_macro: 0.7346
# Epoch 6/30
# 22188/22188 [==============================] - 3s 149us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1232 - val_acc: 0.7357 - val_f1_score_macro: 0.7344
# Epoch 7/30
# 22188/22188 [==============================] - 3s 147us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1232 - val_acc: 0.7350 - val_f1_score_macro: 0.7339
# Epoch 8/30
# 22188/22188 [==============================] - 3s 146us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1232 - val_acc: 0.7350 - val_f1_score_macro: 0.7339
# [0.6920232435287903, 0.4931153555532462]
# [[1896    0    0    0]
#  [   0  200    0  746]
#  [   0  401  524   19]
#  [   0    0    0    0]]
# Confusion matrix, without normalization
# [[6627    0    1    0]
#  [   6 1225  693 4711]
#  [ 189  392 3064 2990]
#  [   3 2927 3048 5645]]
# Confusion matrix, without normalization
# [[6628    0    0    0]
#  [   0  241  495 5899]
#  [  11  328 4089 2207]
#  [   0 3062 2811 5750]]
# Confusion matrix, without normalization
# [[ 6628     0     0     0]
#  [    0  5889     0   746]
#  [    0   554  5656   425]
#  [    0   593   324 10706]]
# Confusion matrix, without normalization
# 007 x 4/5
# K-NNeighbors:	[0.5728927203065134, 0.6340583389954915]
# [[ 952    0    0    0]
#  [   0  752    1 1147]
#  [  13   69 1765   47]
#  [   1  936 2245 2512]]
# Confusion matrix, without normalization
# RandomForest:	[0.4921455938697318, 0.5304275130263245]
# [[ 952    0    0    0]
#  [   0  109   18 1773]
#  [   2   63 1541  288]
#  [   0 1124 2034 2536]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 16864 samples, validate on 4217 samples
# Epoch 1/30
# 16864/16864 [==============================] - 4s 231us/step - loss: 8.1605e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3027 - val_acc: 0.3678 - val_f1_score_macro: 0.3666
# Epoch 2/30
# 16864/16864 [==============================] - 2s 146us/step - loss: 6.0859e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3031 - val_acc: 0.3664 - val_f1_score_macro: 0.3652
# Epoch 3/30
# 16864/16864 [==============================] - 2s 145us/step - loss: 5.3839e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3035 - val_acc: 0.3654 - val_f1_score_macro: 0.3642
# Epoch 4/30
# 16864/16864 [==============================] - 2s 146us/step - loss: 4.8849e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3039 - val_acc: 0.3638 - val_f1_score_macro: 0.3628
# [0.9999042145593869, 0.9998682125192271]
# [[ 952    0    0    0]
#  [   0 1900    0    0]
#  [   0    1 1893    0]
#  [   0    0    0 5694]]
# Confusion matrix, without normalization
# 014 x 4/5
# K-NNeighbors:	[0.4732599795291709, 0.4253133750548309]
# [[1890    0    0    0]
#  [   6   31  165 1693]
#  [ 176  231  414 1079]
#  [   0  364  403 1364]]
# Confusion matrix, without normalization
# RandomForest:	[0.5093398157625384, 0.48060249249279385]
# [[1890    0    0    0]
#  [   0   36  236 1623]
#  [  35  241 1133  491]
#  [   0  327  882  922]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18964 samples, validate on 4741 samples
# Epoch 1/30
# 18964/18964 [==============================] - 4s 232us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2661 - val_acc: 0.4455 - val_f1_score_macro: 0.4446
# Epoch 2/30
# 18964/18964 [==============================] - 3s 148us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2658 - val_acc: 0.4459 - val_f1_score_macro: 0.4450
# Epoch 3/30
# 18964/18964 [==============================] - 3s 147us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2658 - val_acc: 0.4465 - val_f1_score_macro: 0.4459
# Epoch 4/30
# 18964/18964 [==============================] - 3s 147us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2659 - val_acc: 0.4457 - val_f1_score_macro: 0.4451
# Epoch 5/30
# 18964/18964 [==============================] - 3s 153us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2658 - val_acc: 0.4461 - val_f1_score_macro: 0.4457
# Epoch 6/30
# 18964/18964 [==============================] - 3s 151us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2660 - val_acc: 0.4457 - val_f1_score_macro: 0.4452
# [1.0, 1.0]
# [[1890    0    0    0]
#  [   0 1895    0    0]
#  [   0    0 1900    0]
#  [   0    0    0 2131]]
# Confusion matrix, without normalization
# 021 x 4/5
# K-NNeighbors:	[0.5248443928684461, 0.541617687679397]
# [[1890    0    0    0]
#  [   0  431  527  936]
#  [   0   92  885  920]
#  [   2 1627  400 1769]]
# Confusion matrix, without normalization
# RandomForest:	[0.5539613883321025, 0.5322269187297431]
# [[1890    0    0    0]
#  [   0    9  128 1757]
#  [   0   38 1098  761]
#  [   0  987  557 2254]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 17633 samples, validate on 4409 samples
# Epoch 1/30
# 17633/17633 [==============================] - 4s 240us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1338 - val_acc: 0.7303 - val_f1_score_macro: 0.7303
# Epoch 2/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1337 - val_acc: 0.7301 - val_f1_score_macro: 0.7301
# Epoch 3/30
# 17633/17633 [==============================] - 3s 148us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1335 - val_acc: 0.7299 - val_f1_score_macro: 0.7299
# Epoch 4/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1333 - val_acc: 0.7306 - val_f1_score_macro: 0.7304
# Epoch 5/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1332 - val_acc: 0.7308 - val_f1_score_macro: 0.7308
# Epoch 6/30
# 17633/17633 [==============================] - 3s 148us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1330 - val_acc: 0.7315 - val_f1_score_macro: 0.7315
# Epoch 7/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1328 - val_acc: 0.7321 - val_f1_score_macro: 0.7321
# ...
# Epoch 6/30
# 22188/22188 [==============================] - 3s 149us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1234 - val_acc: 0.7352 - val_f1_score_macro: 0.7341
# Epoch 7/30
# 22188/22188 [==============================] - 3s 148us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1233 - val_acc: 0.7355 - val_f1_score_macro: 0.7344
# Epoch 8/30
# 22188/22188 [==============================] - 3s 149us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1233 - val_acc: 0.7355 - val_f1_score_macro: 0.7344
# Epoch 9/30
# 22188/22188 [==============================] - 3s 150us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1233 - val_acc: 0.7355 - val_f1_score_macro: 0.7344
# Epoch 10/30
# 22188/22188 [==============================] - 3s 149us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1233 - val_acc: 0.7357 - val_f1_score_macro: 0.7344
# Epoch 11/30
# 22188/22188 [==============================] - 3s 147us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1233 - val_acc: 0.7357 - val_f1_score_macro: 0.7344
# Epoch 12/30
# 22188/22188 [==============================] - 3s 148us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1233 - val_acc: 0.7357 - val_f1_score_macro: 0.7345
# Epoch 13/30
# 22188/22188 [==============================] - 3s 146us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1233 - val_acc: 0.7357 - val_f1_score_macro: 0.7345
# [0.6944004226096143, 0.4955622963711942]
# [[1896    0    0    0]
#  [   0  205    0  741]
#  [   0  397  528   19]
#  [   0    0    0    0]]
# Confusion matrix, without normalization
# [[6627    0    1    0]
#  [   6 1225  693 4711]
#  [ 189  392 3064 2990]
#  [   3 2927 3048 5645]]
# Confusion matrix, without normalization
# [[6628    0    0    0]
#  [   0  162  382 6091]
#  [  37  342 3772 2484]
#  [   0 2438 3473 5712]]
# Confusion matrix, without normalization
# [[ 6628     0     0     0]
#  [    0  5894     0   741]
#  [    0   547  5666   422]
#  [    0   594   323 10706]]
# Confusion matrix, without normalization
# 007 x 5/5
# K-NNeighbors:	[0.5728927203065134, 0.6340583389954915]
# [[ 952    0    0    0]
#  [   0  752    1 1147]
#  [  13   69 1765   47]
#  [   1  936 2245 2512]]
# Confusion matrix, without normalization
# RandomForest:	[0.5341954022988505, 0.5636191592816533]
# [[ 952    0    0    0]
#  [   0  139    3 1758]
#  [   2   59 1618  215]
#  [   0 1172 1654 2868]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 16864 samples, validate on 4217 samples
# Epoch 1/30
# 16864/16864 [==============================] - 4s 245us/step - loss: 5.6732e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3023 - val_acc: 0.3695 - val_f1_score_macro: 0.3684
# Epoch 2/30
# 16864/16864 [==============================] - 2s 147us/step - loss: 4.5308e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3023 - val_acc: 0.3692 - val_f1_score_macro: 0.3681
# Epoch 3/30
# 16864/16864 [==============================] - 3s 149us/step - loss: 4.1370e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3020 - val_acc: 0.3692 - val_f1_score_macro: 0.3681
# Epoch 4/30
# 16864/16864 [==============================] - 2s 148us/step - loss: 3.8502e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3024 - val_acc: 0.3685 - val_f1_score_macro: 0.3676
# Epoch 5/30
# 16864/16864 [==============================] - 3s 152us/step - loss: 3.6069e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3025 - val_acc: 0.3683 - val_f1_score_macro: 0.3673
# Epoch 6/30
# 16864/16864 [==============================] - 3s 148us/step - loss: 3.4160e-10 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.3025 - val_acc: 0.3687 - val_f1_score_macro: 0.3676
# [0.9999042145593869, 0.9998682125192271]
# [[ 952    0    0    0]
#  [   0 1900    0    0]
#  [   0    1 1893    0]
#  [   0    0    0 5694]]
# Confusion matrix, without normalization
# 014 x 5/5
# K-NNeighbors:	[0.4732599795291709, 0.4253133750548309]
# [[1890    0    0    0]
#  [   6   31  165 1693]
#  [ 176  231  414 1079]
#  [   0  364  403 1364]]
# Confusion matrix, without normalization
# RandomForest:	[0.512410440122825, 0.48139251435903657]
# [[1890    0    0    0]
#  [   0    5  250 1640]
#  [  16  242 1143  499]
#  [   0  349  815  967]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 18964 samples, validate on 4741 samples
# Epoch 1/30
# 18964/18964 [==============================] - 4s 237us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2663 - val_acc: 0.4457 - val_f1_score_macro: 0.4442
# Epoch 2/30
# 18964/18964 [==============================] - 3s 148us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2657 - val_acc: 0.4474 - val_f1_score_macro: 0.4460
# Epoch 3/30
# 18964/18964 [==============================] - 3s 146us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2655 - val_acc: 0.4467 - val_f1_score_macro: 0.4456
# Epoch 4/30
# 18964/18964 [==============================] - 3s 148us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2655 - val_acc: 0.4470 - val_f1_score_macro: 0.4459
# Epoch 5/30
# 18964/18964 [==============================] - 3s 148us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2654 - val_acc: 0.4470 - val_f1_score_macro: 0.4455
# Epoch 6/30
# 18964/18964 [==============================] - 3s 150us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2655 - val_acc: 0.4467 - val_f1_score_macro: 0.4455
# Epoch 7/30
# 18964/18964 [==============================] - 3s 146us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2653 - val_acc: 0.4472 - val_f1_score_macro: 0.4465
# Epoch 8/30
# 18964/18964 [==============================] - 3s 146us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2655 - val_acc: 0.4463 - val_f1_score_macro: 0.4456
# Epoch 9/30
# 18964/18964 [==============================] - 3s 149us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2656 - val_acc: 0.4463 - val_f1_score_macro: 0.4457
# Epoch 10/30
# 18964/18964 [==============================] - 3s 149us/step - loss: 2.6366e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.2655 - val_acc: 0.4470 - val_f1_score_macro: 0.4461
# [1.0, 1.0]
# [[1890    0    0    0]
#  [   0 1895    0    0]
#  [   0    0 1900    0]
#  [   0    0    0 2131]]
# Confusion matrix, without normalization
# 021 x 5/5
# K-NNeighbors:	[0.5248443928684461, 0.541617687679397]
# [[1890    0    0    0]
#  [   0  431  527  936]
#  [   0   92  885  920]
#  [   2 1627  400 1769]]
# Confusion matrix, without normalization
# RandomForest:	[0.5491085557548264, 0.5360086668859387]
# [[1890    0    0    0]
#  [   0   23  171 1700]
#  [   0   20 1072  805]
#  [   0 1194  384 2220]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 17633 samples, validate on 4409 samples
# Epoch 1/30
# 17633/17633 [==============================] - 5s 259us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1331 - val_acc: 0.7315 - val_f1_score_macro: 0.7315
# Epoch 2/30
# 17633/17633 [==============================] - 3s 157us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1331 - val_acc: 0.7310 - val_f1_score_macro: 0.7310
# Epoch 3/30
# 17633/17633 [==============================] - 3s 159us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1331 - val_acc: 0.7310 - val_f1_score_macro: 0.7310
# Epoch 4/30
# 17633/17633 [==============================] - 3s 152us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1330 - val_acc: 0.7310 - val_f1_score_macro: 0.7310
# Epoch 5/30
# 17633/17633 [==============================] - 3s 150us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1329 - val_acc: 0.7317 - val_f1_score_macro: 0.7317
# Epoch 6/30
# 17633/17633 [==============================] - 3s 150us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1328 - val_acc: 0.7321 - val_f1_score_macro: 0.7321
# Epoch 7/30
# 17633/17633 [==============================] - 3s 149us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1326 - val_acc: 0.7328 - val_f1_score_macro: 0.7328
# Epoch 8/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1325 - val_acc: 0.7330 - val_f1_score_macro: 0.7330
# Epoch 9/30
# 17633/17633 [==============================] - 3s 150us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1324 - val_acc: 0.7330 - val_f1_score_macro: 0.7330
# Epoch 10/30
# 17633/17633 [==============================] - 3s 150us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1323 - val_acc: 0.7330 - val_f1_score_macro: 0.7330
# Epoch 11/30
# 17633/17633 [==============================] - 3s 152us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1321 - val_acc: 0.7335 - val_f1_score_macro: 0.7335
# Epoch 12/30
# 17633/17633 [==============================] - 3s 150us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1321 - val_acc: 0.7337 - val_f1_score_macro: 0.7337
# Epoch 13/30
# 17633/17633 [==============================] - 3s 149us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1320 - val_acc: 0.7340 - val_f1_score_macro: 0.7340
# Epoch 14/30
# 17633/17633 [==============================] - 3s 148us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1319 - val_acc: 0.7340 - val_f1_score_macro: 0.7340
# Epoch 15/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1318 - val_acc: 0.7340 - val_f1_score_macro: 0.7340
# Epoch 16/30
# 17633/17633 [==============================] - 3s 149us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1317 - val_acc: 0.7342 - val_f1_score_macro: 0.7342
# Epoch 17/30
# 17633/17633 [==============================] - 3s 148us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1316 - val_acc: 0.7342 - val_f1_score_macro: 0.7342
# Epoch 18/30
# 17633/17633 [==============================] - 3s 145us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1315 - val_acc: 0.7346 - val_f1_score_macro: 0.7346
# Epoch 19/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1314 - val_acc: 0.7346 - val_f1_score_macro: 0.7346
# Epoch 20/30
# 17633/17633 [==============================] - 3s 150us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1313 - val_acc: 0.7349 - val_f1_score_macro: 0.7349
# Epoch 21/30
# 17633/17633 [==============================] - 3s 149us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1313 - val_acc: 0.7346 - val_f1_score_macro: 0.7346
# Epoch 22/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1312 - val_acc: 0.7346 - val_f1_score_macro: 0.7346
# Epoch 23/30
# 17633/17633 [==============================] - 3s 148us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1311 - val_acc: 0.7353 - val_f1_score_macro: 0.7353
# Epoch 24/30
# 17633/17633 [==============================] - 3s 147us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1310 - val_acc: 0.7353 - val_f1_score_macro: 0.7353
# Epoch 25/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1309 - val_acc: 0.7353 - val_f1_score_macro: 0.7353
# Epoch 26/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1308 - val_acc: 0.7353 - val_f1_score_macro: 0.7353
# Epoch 27/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1308 - val_acc: 0.7353 - val_f1_score_macro: 0.7353
# Epoch 28/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1307 - val_acc: 0.7353 - val_f1_score_macro: 0.7353
# Epoch 29/30
# 17633/17633 [==============================] - 3s 150us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1307 - val_acc: 0.7355 - val_f1_score_macro: 0.7355
# Epoch 30/30
# 17633/17633 [==============================] - 3s 146us/step - loss: 2.8356e-05 - acc: 0.9999 - f1_score_macro: 0.9999 - val_loss: 0.1306 - val_acc: 0.7358 - val_f1_score_macro: 0.7358
# [0.8449203502479165, 0.8509940086983658]
# [[1890    0    0    0]
#  [   0 1894    0    0]
#  [   0  147 1345  405]
#  [   0  595  323 2880]]
# Confusion matrix, without normalization
# 028 x 5/5
# K-NNeighbors:	[0.503433703116746, 0.2556811807760061]
# [[1895    0    1    0]
#  [   0   11    0  935]
#  [   0    0    0  944]
#  [   0    0    0    0]]
# Confusion matrix, without normalization
# RandomForest:	[0.5013206550449023, 0.2519733370365227]
# [[1894    0    2    0]
#  [   0    4    0  942]
#  [   0    0    0  944]
#  [   0    0    0    0]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Train on 22188 samples, validate on 5547 samples
# Epoch 1/30
# 22188/22188 [==============================] - 5s 224us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1235 - val_acc: 0.7352 - val_f1_score_macro: 0.7344
# Epoch 2/30
# 22188/22188 [==============================] - 3s 152us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1234 - val_acc: 0.7357 - val_f1_score_macro: 0.7346
# Epoch 3/30
# 22188/22188 [==============================] - 3s 148us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1234 - val_acc: 0.7357 - val_f1_score_macro: 0.7346
# Epoch 4/30
# 22188/22188 [==============================] - 3s 146us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1234 - val_acc: 0.7357 - val_f1_score_macro: 0.7346
# Epoch 5/30
# 22188/22188 [==============================] - 3s 150us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1234 - val_acc: 0.7359 - val_f1_score_macro: 0.7347
# Epoch 6/30
# 22188/22188 [==============================] - 3s 149us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1234 - val_acc: 0.7363 - val_f1_score_macro: 0.7351
# Epoch 7/30
# 22188/22188 [==============================] - 3s 149us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1234 - val_acc: 0.7359 - val_f1_score_macro: 0.7347
# Epoch 8/30
# 22188/22188 [==============================] - 3s 150us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1234 - val_acc: 0.7359 - val_f1_score_macro: 0.7347
# Epoch 9/30
# 22188/22188 [==============================] - 3s 147us/step - loss: 2.2535e-05 - acc: 1.0000 - f1_score_macro: 1.0000 - val_loss: 0.1234 - val_acc: 0.7357 - val_f1_score_macro: 0.7345
# [0.6928156365557316, 0.49385122684511684]
# [[1896    0    0    0]
#  [   0  198    0  748]
#  [   0  396  529   19]
#  [   0    0    0    0]]
# Confusion matrix, without normalization
# [[6627    0    1    0]
#  [   6 1225  693 4711]
#  [ 189  392 3064 2990]
#  [   3 2927 3048 5645]]
# Confusion matrix, without normalization
# [[6626    0    2    0]
#  [   0  171  424 6040]
#  [  18  321 3833 2463]
#  [   0 2715 2853 6055]]
# Confusion matrix, without normalization
# [[ 6628     0     0     0]
#  [    0  5887     0   748]
#  [    0   544  5667   424]
#  [    0   595   323 10705]]
# Confusion matrix, without normalization

# %% [markdown]
# #Results Summary

# %%
for evaluation in results.keys():
  print("\n"+30*"#"+"\n"+evaluation+"\n"+30*"#")
  for clfname,model in clfs:
    print("\n\t"+clfname+" Results\nFold\tAccuracy\tF1-Score")
    for i,r in enumerate(results[evaluation][clfname]):
      print("{}\t".format(i+1),end="")
      print(r)
    print("Average\tAccuracy\tF1-Score\n\t",end="")
    print(np.mean(results[evaluation][clfname],axis=0))
    print("StdDev\tAccuracy\tF1-Score\n\t",end="")
    print(np.std(results[evaluation][clfname],axis=0))
# Out:
# ##############################
# kfold
# ##############################
#
# 	K-NNeighbors Results
# Fold	Accuracy	F1-Score
# 1	[0.9753838345387641, 0.9747956535237838]
# 2	[0.974114960030453, 0.9734480338011089]
# 3	[0.9732267478746351, 0.9727799224030003]
# 4	[0.9723280020309724, 0.9715054303592797]
# 5	[0.9765258215962441, 0.9760531025293483]
# 6	[0.9755107219895952, 0.9748136228986537]
# 7	[0.9742418474812841, 0.973991807101108]
# 8	[0.971947194719472, 0.9712973191212758]
# 9	[0.9751300596371019, 0.9748235960084752]
# 10	[0.9728460855221419, 0.9720579692318273]
# 11	[0.9742418474812841, 0.9738646401349946]
# 12	[0.9728357451129729, 0.9721677054528082]
# 13	[0.9733536353254663, 0.9726518956030046]
# 14	[0.9751300596371019, 0.9749608876433541]
# 15	[0.9746225098337774, 0.9744434029547956]
# 16	[0.9733434881949733, 0.9723861280413183]
# 17	[0.9733536353254663, 0.9730084554962832]
# 18	[0.9724654231696486, 0.971703685855846]
# 19	[0.9746225098337774, 0.9741704927405925]
# 20	[0.976897689768977, 0.9766358989500241]
# Average	Accuracy	F1-Score
# 	[0.97410609 0.97357798]
# StdDev	Accuracy	F1-Score
# 	[0.00134395 0.00148104]
#
# 	RandomForest Results
# Fold	Accuracy	F1-Score
# 1	[0.9827433066869686, 0.9828792194664391]
# 2	[0.9822357568836442, 0.9823982280106963]
# 3	[0.9823626443344753, 0.9828529606820117]
# 4	[0.9810865701954811, 0.9812781497851367]
# 5	[0.983123969039462, 0.9833586744938285]
# 6	[0.9810937698261641, 0.9810586879168941]
# 7	[0.9819819819819819, 0.9822786320392086]
# 8	[0.9796902767199797, 0.9799101612517329]
# 9	[0.9805862200228398, 0.9809240834181996]
# 10	[0.9807131074736709, 0.9807387344385208]
# 11	[0.9814744321786575, 0.9816305127144458]
# 12	[0.9828636709824828, 0.9829315532188488]
# 13	[0.9818550945311508, 0.9819363384188453]
# 14	[0.980966882375333, 0.9811878851207625]
# 15	[0.9816013196294886, 0.9817600850550469]
# 16	[0.9823559279004823, 0.9823688465473654]
# 17	[0.9810937698261641, 0.9810942816147507]
# 18	[0.983123969039462, 0.983123139560587]
# 19	[0.9824895317853064, 0.9828580676730082]
# 20	[0.9837522213759837, 0.984332899512707]
# Average	Accuracy	F1-Score
# 	[0.98185972 0.98204506]
# StdDev	Accuracy	F1-Score
# 	[0.00100114 0.00105326]
#
# 	ANN-Conv1d Results
# Fold	Accuracy	F1-Score
# 1	[0.886308844055323, 0.8932515778016988]
# 2	[0.8918918918918919, 0.8983395398170094]
# 3	[0.8922725542443852, 0.898568299937397]
# 4	[0.8848692561563849, 0.8921291354807751]
# 5	[0.8903692424819185, 0.8970350869525442]
# 6	[0.884151757391194, 0.8908729828505269]
# 7	[0.8929069914985408, 0.8994242018361827]
# 8	[0.8865194211728865, 0.8941349998844076]
# 9	[0.8911305671869052, 0.8976875996518008]
# 10	[0.8840248699403629, 0.8911072071402155]
# 11	[0.886308844055323, 0.8936792776240468]
# 12	[0.8924854023863925, 0.8991175837487249]
# 13	[0.8842786448420251, 0.8910360708757231]
# 14	[0.889861692678594, 0.8967585704690919]
# 15	[0.8879583809161274, 0.8949376535651462]
# 16	[0.8924854023863925, 0.89957675572262]
# 17	[0.8929069914985408, 0.9004002078689068]
# 18	[0.8854206318995052, 0.8919510095333387]
# 19	[0.8912574546377363, 0.8978459606964427]
# 20	[0.8838537699923839, 0.8910554193198148]
# Average	Accuracy	F1-Score
# 	[0.88856313 0.89544546]
# StdDev	Accuracy	F1-Score
# 	[0.00339826 0.00328375]
#
# ##############################
# byseverity
# ##############################
#
# 	K-NNeighbors Results
# Fold	Accuracy	F1-Score
# 1	[0.5728927203065134, 0.6340583389954915]
# 2	[0.4732599795291709, 0.4253133750548309]
# 3	[0.5248443928684461, 0.541617687679397]
# 4	[0.503433703116746, 0.2556811807760061]
# 5	[0.5728927203065134, 0.6340583389954915]
# 6	[0.4732599795291709, 0.4253133750548309]
# 7	[0.5248443928684461, 0.541617687679397]
# 8	[0.503433703116746, 0.2556811807760061]
# 9	[0.5728927203065134, 0.6340583389954915]
# 10	[0.4732599795291709, 0.4253133750548309]
# 11	[0.5248443928684461, 0.541617687679397]
# 12	[0.503433703116746, 0.2556811807760061]
# 13	[0.5728927203065134, 0.6340583389954915]
# 14	[0.4732599795291709, 0.4253133750548309]
# 15	[0.5248443928684461, 0.541617687679397]
# 16	[0.503433703116746, 0.2556811807760061]
# 17	[0.5728927203065134, 0.6340583389954915]
# 18	[0.4732599795291709, 0.4253133750548309]
# 19	[0.5248443928684461, 0.541617687679397]
# 20	[0.503433703116746, 0.2556811807760061]
# Average	Accuracy	F1-Score
# 	[0.5186077  0.46416765]
# StdDev	Accuracy	F1-Score
# 	[0.03630574 0.14127776]
#
# 	RandomForest Results
# Fold	Accuracy	F1-Score
# 1	[0.5217432950191571, 0.5644203796332148]
# 2	[0.5269959058341863, 0.5000494498083343]
# 3	[0.5203080493722967, 0.5196803268796205]
# 4	[0.5068674062334918, 0.26186790505675955]
# 5	[0.5560344827586207, 0.5830558595993853]
# 6	[0.5216223132036848, 0.4916497083765317]
# 7	[0.5554383373773605, 0.5478050191589958]
# 8	[0.4989434759640782, 0.2504600862619915]
# 9	[0.5261494252873563, 0.5550285198841423]
# 10	[0.5656345957011258, 0.532582176296474]
# 11	[0.5106023842177445, 0.5197960786245089]
# 12	[0.5161119915478077, 0.2788844621513944]
# 13	[0.4921455938697318, 0.5304275130263245]
# 14	[0.5093398157625384, 0.48060249249279385]
# 15	[0.5539613883321025, 0.5322269187297431]
# 16	[0.502905441098785, 0.25419287211740044]
# 17	[0.5341954022988505, 0.5636191592816533]
# 18	[0.512410440122825, 0.48139251435903657]
# 19	[0.5491085557548264, 0.5360086668859387]
# 20	[0.5013206550449023, 0.2519733370365227]
# Average	Accuracy	F1-Score
# 	[0.52409195 0.46178617]
# StdDev	Accuracy	F1-Score
# 	[0.02110004 0.11977161]
#
# 	ANN-Conv1d Results
# Fold	Accuracy	F1-Score
# 1	[0.9992337164750957, 0.9992090422374295]
# 2	[1.0, 1.0]
# 3	[0.8398565249498893, 0.8468104177761868]
# 4	[0.7033808769149498, 0.5043314586739696]
# 5	[0.9999042145593869, 0.9998682125192271]
# 6	[1.0, 1.0]
# 7	[0.8439708830045364, 0.849934699394102]
# 8	[0.6933438985736925, 0.49454672367158187]
# 9	[0.9999042145593869, 0.9998682125192271]
# 10	[1.0, 1.0]
# 11	[0.8443928684460386, 0.8502910844033126]
# 12	[0.6920232435287903, 0.4931153555532462]
# 13	[0.9999042145593869, 0.9998682125192271]
# 14	[1.0, 1.0]
# 15	[0.845025846608292, 0.8510471794352739]
# 16	[0.6944004226096143, 0.4955622963711942]
# 17	[0.9999042145593869, 0.9998682125192271]
# 18	[1.0, 1.0]
# 19	[0.8449203502479165, 0.8509940086983658]
# 20	[0.6928156365557316, 0.49385122684511684]
# Average	Accuracy	F1-Score
# 	[0.88464906 0.83645832]
# StdDev	Accuracy	F1-Score
# 	[0.12664497 0.20574481]
