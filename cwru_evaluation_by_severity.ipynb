# %% [markdown]
# <a href="https://colab.research.google.com/github/fboldt/SignalProcessing/blob/master/cwru_evaluation_by_severity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CWRU files.
#
# Associate each Matlab file name to a bearing condition in a Python dictionary.
# The dictionary keys identify the conditions.
#
# There are only four normal conditions, with loads of 0, 1, 2 and 3 hp.
# All conditions end with an underscore character followed by an algarism representing the load applied during the acquisitions.
# The remaining conditions follow the pattern:
#
#
# * First two characters represent the bearing location, i.e. drive end (DE) and fan end (FE).
# * The following two characters represent the failure location in the bearing, i.e. ball (BA), Inner Race (IR) and Outer Race (OR).
# * The next three algarisms indicate the severity of the failure, where 007 stands for 0.007 inches and 0021 for 0.021 inches.
# * For Outer Race failures, the character @ is followed by a number that indicates different load zones.

# %%
debug = False
# size of each segment
sample_size = 4096
if not debug:
  sample_size = 512
acquisitions = {}
# Normal
acquisitions["Normal_0"] = "97.mat"
acquisitions["Normal_1"] = "98.mat"
acquisitions["Normal_2"] = "99.mat"
acquisitions["Normal_3"] = "100.mat"
# DE Inner Race 0.007 inches
acquisitions["DEIR.007_0"] = "105.mat"
acquisitions["DEIR.007_1"] = "106.mat"
acquisitions["DEIR.007_2"] = "107.mat"
acquisitions["DEIR.007_3"] = "108.mat"
# DE Ball 0.007 inches
acquisitions["DEB.007_0"] = "118.mat"
acquisitions["DEB.007_1"] = "119.mat"
acquisitions["DEB.007_2"] = "120.mat"
acquisitions["DEB.007_3"] = "121.mat"
# DE Outer race 0.007 inches centered @6:00
acquisitions["DEOR.007@6_0"] = "130.mat"
acquisitions["DEOR.007@6_1"] = "131.mat"
acquisitions["DEOR.007@6_2"] = "132.mat"
acquisitions["DEOR.007@6_3"] = "133.mat"
if not debug:
  # DE Outer race 0.007 inches centered @3:00
  acquisitions["DEOR.007@3_0"] = "144.mat"
  acquisitions["DEOR.007@3_1"] = "145.mat"
  acquisitions["DEOR.007@3_2"] = "146.mat"
  acquisitions["DEOR.007@3_3"] = "147.mat"
  # DE Outer race 0.007 inches centered @12:00
  acquisitions["DEOR.007@12_0"] = "156.mat"
  acquisitions["DEOR.007@12_1"] = "158.mat"
  acquisitions["DEOR.007@12_2"] = "159.mat"
  acquisitions["DEOR.007@12_3"] = "160.mat"
# DE Inner Race 0.014 inches
acquisitions["DEIR.014_0"] = "169.mat"
acquisitions["DEIR.014_1"] = "170.mat"
acquisitions["DEIR.014_2"] = "171.mat"
acquisitions["DEIR.014_3"] = "172.mat"
# DE Ball 0.014 inches
acquisitions["DEB.014_0"] = "185.mat"
acquisitions["DEB.014_1"] = "186.mat"
acquisitions["DEB.014_2"] = "187.mat"
acquisitions["DEB.014_3"] = "188.mat"
# DE Outer race 0.014 inches centered @6:00
acquisitions["DEOR.014@6_0"] = "197.mat"
acquisitions["DEOR.014@6_1"] = "198.mat"
acquisitions["DEOR.014@6_2"] = "199.mat"
acquisitions["DEOR.014@6_3"] = "200.mat"
# DE Ball 0.021 inches
acquisitions["DEB.021_0"] = "222.mat"
acquisitions["DEB.021_1"] = "223.mat"
acquisitions["DEB.021_2"] = "224.mat"
acquisitions["DEB.021_3"] = "225.mat"
# FE Inner Race 0.021 inches
acquisitions["FEIR.021_0"] = "270.mat"
acquisitions["FEIR.021_1"] = "271.mat"
acquisitions["FEIR.021_2"] = "272.mat"
acquisitions["FEIR.021_3"] = "273.mat"
if not debug:
  # FE Inner Race 0.014 inches
  acquisitions["FEIR.014_0"] = "274.mat"
  acquisitions["FEIR.014_1"] = "275.mat"
  acquisitions["FEIR.014_2"] = "276.mat"
  acquisitions["FEIR.014_3"] = "277.mat"
  # FE Ball 0.007 inches
  acquisitions["FEB.007_0"] = "282.mat"
  acquisitions["FEB.007_1"] = "283.mat"
  acquisitions["FEB.007_2"] = "284.mat"
  acquisitions["FEB.007_3"] = "285.mat"
  # DE Inner Race 0.021 inches
  acquisitions["DEIR.021_0"] = "209.mat"
  acquisitions["DEIR.021_1"] = "210.mat"
  acquisitions["DEIR.021_2"] = "211.mat"
  acquisitions["DEIR.021_3"] = "212.mat"
# DE Outer race 0.021 inches centered @6:00
acquisitions["DEOR.021@6_0"] = "234.mat"
acquisitions["DEOR.021@6_1"] = "235.mat"
acquisitions["DEOR.021@6_2"] = "236.mat"
acquisitions["DEOR.021@6_3"] = "237.mat"
if not debug:
  # DE Outer race 0.021 inches centered @3:00
  acquisitions["DEOR.021@3_0"] = "246.mat"
  acquisitions["DEOR.021@3_1"] = "247.mat"
  acquisitions["DEOR.021@3_2"] = "248.mat"
  acquisitions["DEOR.021@3_3"] = "249.mat"
  # DE Outer race 0.021 inches centered @12:00
  acquisitions["DEOR.021@12_0"] = "258.mat"
  acquisitions["DEOR.021@12_1"] = "259.mat"
  acquisitions["DEOR.021@12_2"] = "260.mat"
  acquisitions["DEOR.021@12_3"] = "261.mat"
  # FE Inner Race 0.007 inches
  acquisitions["FEIR.007_0"] = "278.mat"
  acquisitions["FEIR.007_1"] = "279.mat"
  acquisitions["FEIR.007_2"] = "280.mat"
  acquisitions["FEIR.007_3"] = "281.mat"
  # FE Ball 0.014 inches
  acquisitions["FEB.014_0"] = "286.mat"
  acquisitions["FEB.014_1"] = "287.mat"
  acquisitions["FEB.014_2"] = "288.mat"
  acquisitions["FEB.014_3"] = "289.mat"
  # FE Ball 0.021 inches
  acquisitions["FEB.021_0"] = "290.mat"
  acquisitions["FEB.021_1"] = "291.mat"
  acquisitions["FEB.021_2"] = "292.mat"
  acquisitions["FEB.021_3"] = "293.mat"
  # FE Outer race 0.007 inches centered @6:00
  acquisitions["FEOR.007@6_0"] = "294.mat"
  acquisitions["FEOR.007@6_1"] = "295.mat"
  acquisitions["FEOR.007@6_2"] = "296.mat"
  acquisitions["FEOR.007@6_3"] = "297.mat"
  # FE Outer race 0.007 inches centered @3:00
  acquisitions["FEOR.007@3_0"] = "298.mat"
  acquisitions["FEOR.007@3_1"] = "299.mat"
  acquisitions["FEOR.007@3_2"] = "300.mat"
  acquisitions["FEOR.007@3_3"] = "301.mat"
  # FE Outer race 0.007 inches centered @12:00
  acquisitions["FEOR.007@12_0"] = "302.mat"
  acquisitions["FEOR.007@12_1"] = "305.mat"
  acquisitions["FEOR.007@12_2"] = "306.mat"
  acquisitions["FEOR.007@12_3"] = "307.mat"
  # FE Outer race 0.014 inches centered @3:00
  acquisitions["FEOR.014@3_0"] = "310.mat"
  acquisitions["FEOR.014@3_1"] = "309.mat"
  acquisitions["FEOR.014@3_2"] = "311.mat"
  acquisitions["FEOR.014@3_3"] = "312.mat"
  # FE Outer race 0.014 inches centered @6:00
  acquisitions["FEOR.014@6_0"] = "313.mat"
  # FE Outer race 0.021 inches centered @6:00
  acquisitions["FEOR.021@6_0"] = "315.mat"
  # FE Outer race 0.021 inches centered @3:00
  acquisitions["FEOR.021@3_1"] = "316.mat"
  acquisitions["FEOR.021@3_2"] = "317.mat"
  acquisitions["FEOR.021@3_3"] = "318.mat"
# DE Inner Race 0.028 inches
acquisitions["DEIR.028_0"] = "3001.mat"
acquisitions["DEIR.028_1"] = "3002.mat"
acquisitions["DEIR.028_2"] = "3003.mat"
acquisitions["DEIR.028_3"] = "3004.mat"
# DE Ball 0.028 inches
acquisitions["DEB.028_0"] = "3005.mat"
acquisitions["DEB.028_1"] = "3006.mat"
acquisitions["DEB.028_2"] = "3007.mat"
acquisitions["DEB.028_3"] = "3008.mat"

# %% [markdown]
# #Functions definition

# %% [markdown]
# ##Split signals in many segments

# %%
def get_labels_dict(acquisitions, separator='_', detectPosition=True):
  """Generate a dictionary linking the labels with values to keep consistence."""
  labels_dict = {}
  value = 0
  for key in acquisitions.keys():
    key = key.split('_')[0]
    key = key.split(separator)
    if key[0] == "Normal" or detectPosition:
      label = key[0]
    else:
      label = key[0][2:]
    if not label in labels_dict:
      labels_dict[label] = value
      value += 1
  return labels_dict

# %% [markdown]
# ##Convert Matlab file into tensors

# %%
import scipy.io
import numpy as np
def acquisition2tensor(file_name, position=None, sample_size=sample_size):
  """
  Convert Matlab file into tensors.
  The file is divided in segments of sample_size values.
  """
  print(file_name, end=' ')
  matlab_file = scipy.io.loadmat(file_name)
  DE_samples = []
  FE_samples = []
  
  #signal segmentation
  signal_begin = 0
  if position == None:
    DE_time = [key for key in matlab_file if key.endswith("DE_time")][0] #Find the DRIVE END acquisition key name
    FE_time = [key for key in matlab_file if key.endswith("FE_time")][0] #Find the FAN END acquisition key name
    acquisition_size = max(len(matlab_file[DE_time]),len(matlab_file[FE_time]))
    while signal_begin + sample_size < acquisition_size:
      DE_samples.append([item for sublist in matlab_file[DE_time][signal_begin:signal_begin+sample_size] for item in sublist])
      FE_samples.append([item for sublist in matlab_file[FE_time][signal_begin:signal_begin+sample_size] for item in sublist])
      signal_begin += sample_size
    sample_tensor = np.stack([DE_samples,FE_samples],axis=2).astype('float32')
  elif position == 'DE':
    DE_time = [key for key in matlab_file if key.endswith("DE_time")][0] #Find the DRIVE END acquisition key name
    acquisition_size = len(matlab_file[DE_time])
    while signal_begin + sample_size < acquisition_size:
      DE_samples.append([item for sublist in matlab_file[DE_time][signal_begin:signal_begin+sample_size] for item in sublist])
      signal_begin += sample_size
    sample_tensor = np.stack([DE_samples],axis=2).astype('float32')
  elif position == 'FE':
    FE_time = [key for key in matlab_file if key.endswith("FE_time")][0] #Find the FAN END acquisition key name
    acquisition_size = len(matlab_file[FE_time])
    while signal_begin + sample_size < acquisition_size:
      FE_samples.append([item for sublist in matlab_file[FE_time][signal_begin:signal_begin+sample_size] for item in sublist])
      signal_begin += sample_size
    sample_tensor = np.stack([FE_samples],axis=2).astype('float32')
  return sample_tensor

# %% [markdown]
# ##Concatenate datasets

# %%
def concatenate_datasets(xd,yd,xo,yo):
  """
  xd: destination patterns tensor
  yd: destination labels tensor
  xo: origin patterns tensor to be concateneted 
  yo: origin labels tensor to be concateneted 
  """
  if xd is None or yd is None:
    xd = xo
    yd = yo
  else:
    xd = np.concatenate((xd,xo))
    yd = np.concatenate((yd,yo))
  return xd,yd

# %% [markdown]
# ##Extract datasets from acquisitions

# %%
import urllib.request
import os.path

def acquisitions_from_substr(substr, acquisitions, labels_dict, position=None,
                             url="http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/"):
  """
  Extract samples from all files with some load.
  """
  samples = None
  labels = None
  for key in acquisitions:
    if str(substr) in key:
      file_name = acquisitions[key]
      if not os.path.exists(file_name):
        urllib.request.urlretrieve(url+file_name, file_name)
      if substr[:2] == key[:2] and position == None:
        acquisition_samples = acquisition2tensor(file_name)
      elif 'Normal' in key and position == None:
        de = acquisition2tensor(file_name, 'DE')
        fe = acquisition2tensor(file_name, 'FE')
        acquisition_samples = np.concatenate((de,fe))
      elif position =='DE':
        acquisition_samples = acquisition2tensor(file_name, 'DE')
      elif position =='FE':
        acquisition_samples = acquisition2tensor(file_name, 'FE')
      else:
        acquisition_samples = acquisition2tensor(file_name, key[:2])
      for label in labels_dict.keys():
        if label in key:
          break
      acquisition_labels = np.ones(acquisition_samples.shape[0])*labels_dict[label]
      samples,labels = concatenate_datasets(samples,labels,acquisition_samples,acquisition_labels)
  print(substr)
  return samples,labels

# %% [markdown]
# ##Define function to plot the confusion matrices

# %%
import itertools
from sklearn.metrics import confusion_matrix
from google.colab import files
from matplotlib import pyplot as plt
import copy


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Greys):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
        
    #print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    #plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    #plt.yticks(tick_marks, classes)
    locs, labels = plt.yticks()
    labels=[]
    for i in range(len(locs)):
      if i%2==0:
        labels.append('')
      else:
        labels.append(classes[i//2])
    plt.yticks(locs,labels)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(i, j, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

# %% [markdown]
# #Downloading Matlab files
# Extract samples.

# %%
labels_dict = get_labels_dict(acquisitions, '.', False)
print(labels_dict)
def normal_indenpendent_position_acquisitions(load,acquisitions,labels_dict):
  x,y = None,None
  for position in ['DE','FE']:
    xn,yn = acquisitions_from_substr('Normal_'+str(load),acquisitions,labels_dict,position)
    x,y = concatenate_datasets(x,y,xn,yn)
  return x,y

xn_0,yn_0 = normal_indenpendent_position_acquisitions(0,acquisitions,labels_dict)
xn_1,yn_1 = normal_indenpendent_position_acquisitions(1,acquisitions,labels_dict)
xn_2,yn_2 = normal_indenpendent_position_acquisitions(2,acquisitions,labels_dict)
xn_3,yn_3 = normal_indenpendent_position_acquisitions(3,acquisitions,labels_dict)

x007,y007 = acquisitions_from_substr('007',acquisitions,labels_dict)
x014,y014 = acquisitions_from_substr('014',acquisitions,labels_dict)
x021,y021 = acquisitions_from_substr('021',acquisitions,labels_dict)
x028,y028 = acquisitions_from_substr('028',acquisitions,labels_dict)

severities = ['007','014','021','028']
# Out:
# {'Normal': 0, 'IR': 1, 'B': 2, 'OR': 3}
# 97.mat Normal_0
# 97.mat Normal_0
# 98.mat Normal_1
# 98.mat Normal_1
# 99.mat Normal_2
# 99.mat Normal_2
# 100.mat Normal_3
# 100.mat Normal_3
# 105.mat 106.mat 107.mat 108.mat 118.mat 119.mat 120.mat 121.mat 130.mat 131.mat 132.mat 133.mat 144.mat 145.mat 146.mat 147.mat 156.mat 158.mat 159.mat 160.mat 282.mat 283.mat 284.mat 285.mat 278.mat 279.mat 280.mat 281.mat 294.mat 295.mat 296.mat 297.mat 298.mat 299.mat 300.mat 301.mat 302.mat 305.mat 306.mat 307.mat 007
# 169.mat 170.mat 171.mat 172.mat 185.mat 186.mat 187.mat 188.mat 197.mat 198.mat 199.mat 200.mat 274.mat 275.mat 276.mat 277.mat 286.mat 287.mat 288.mat 289.mat 310.mat 309.mat 311.mat 312.mat 313.mat 014
# 222.mat 223.mat 224.mat 225.mat 270.mat 271.mat 272.mat 273.mat 209.mat 210.mat 211.mat 212.mat 234.mat 235.mat 236.mat 237.mat 246.mat 247.mat 248.mat 249.mat 258.mat 259.mat 260.mat 261.mat 290.mat 291.mat 292.mat 293.mat 315.mat 316.mat 317.mat 318.mat 021
# 3001.mat 3002.mat 3003.mat 3004.mat 3005.mat 3006.mat 3007.mat 3008.mat 028

# %% [markdown]
# ##Count number of samples

# %%
print("Label", end='\t')
for s in severities:
  print(s, end='\t')
print("total")
mat = np.zeros((4,4))
i = 0
for label,value in labels_dict.items():
  print(label, end='\t')
  tsamples = 0
  if label == 'Normal':
    print(4*'\t'+'...')
    for load in range(4):
      print(' '+str((load+len(severities)+1)%4)+(load)*'\t', end='\t')
      mat[i][load] = list(eval('yn_'+str((load+len(severities)+1)%4))).count(value)
      print(int(mat[i][load]))
  else:
    for j,severity in enumerate(['007','014','021','028']):
      tmp = eval('y'+str(severity))
      if tmp is not None:
        nsamples = list(tmp).count(value)
        mat[i][j] = nsamples
        print(nsamples, end='\t')
        tsamples += nsamples
      else:
        print('0', end='\t')
    print(tsamples)
  i+=1
total = np.sum(mat,axis=0)
print("Total:", end='\t')
for i in range(len(total)):
  print(int(total[i]), end='\t')
print(int(np.sum(total)))
# Out:
# Label	007	014	021	028	total
# Normal					...
#  1	1890
#  2		1890
#  3			1896
#  0				952
# IR	1900	1895	1894	946	6635
# B	1894	1900	1897	944	6635
# OR	5694	2131	3798	0	11623
# Total:	11378	7816	9485	2842	31521

# %% [markdown]
# #Feature Extraction Models
# Necessary for K-NN and Random Forest.

# %% [markdown]
# ##Statistical functions

# %%
from sklearn.base import TransformerMixin
import numpy as np
import scipy.stats as stats

# roor mean square
def rms(x):
  x = np.array(x)
  return np.sqrt(np.mean(np.square(x)))
# square root amplitude
def sra(x):
  x = np.array(x)
  return np.mean(np.sqrt(np.absolute(x)))**2
# peak to peak value
def ppv(x):
  x = np.array(x)
  return np.max(x)-np.min(x)
# crest factor
def cf(x):
  x = np.array(x)
  return np.max(np.absolute(x))/rms(x)
# impact factor
def ifa(x):
  x = np.array(x)
  return np.max(np.absolute(x))/np.mean(np.absolute(x))
# margin factor
def mf(x):
  x = np.array(x)
  return np.max(np.absolute(x))/sra(x)
# shape factor
def sf(x):
  x = np.array(x)
  return rms(x)/np.mean(np.absolute(x))
# kurtosis factor
def kf(x):
  x = np.array(x)
  return stats.kurtosis(x)/(np.mean(x**2)**2)

# %% [markdown]
# ## Statistical Features from Time Domain

# %%
class StatisticalTime(TransformerMixin):
  def __init__(self):
    pass
  def fit(self, X, y=None):
    return self
  def transform(self, X, y=None):
    if X.shape[2] == 1:
      return np.array([[rms(x), sra(x), stats.kurtosis(x), stats.skew(x), ppv(x), cf(x), ifa(x), mf(x), sf(x), kf(x)] for x in X[:,:,0]])
    de = np.array([[rms(x), sra(x), stats.kurtosis(x), stats.skew(x), ppv(x), cf(x), ifa(x), mf(x), sf(x), kf(x)] for x in X[:,:,0]])
    fe = np.array([[rms(x), sra(x), stats.kurtosis(x), stats.skew(x), ppv(x), cf(x), ifa(x), mf(x), sf(x), kf(x)] for x in X[:,:,1]])
    return np.concatenate((de,fe),axis=1)

# %% [markdown]
# ## Statistical Features from Frequency Domain

# %%
class StatisticalFrequency(TransformerMixin):
  def __init__(self):
    pass
  def fit(self, X, y=None):
    return self
  def transform(self, X, y=None):
    if X.shape[2] == 1:
      sig = []
      for x in X[:,:,0]:
        fx = np.absolute(np.fft.fft(x))
        fc = np.mean(fx)
        sig.append([fc, rms(fx), rms(fx-fc)])
      return np.array(sig)
    de = []
    for x in X[:,:,0]:
      fx = np.absolute(np.fft.fft(x))
      fc = np.mean(fx)
      de.append([fc, rms(fx), rms(fx-fc)])
    de = np.array(de)
    fe = []
    for x in X[:,:,1]:
      fx = np.absolute(np.fft.fft(x))
      fc = np.mean(fx)
      fe.append([fc, rms(fx), rms(fx-fc)])
    fe = np.array(fe)
    return np.concatenate((de,fe),axis=1)

# %% [markdown]
# ##Statistical Features

# %%
class Statistical(TransformerMixin):
  def __init__(self):
    pass
  def fit(self, X, y=None):
    return self
  def transform(self, X, y=None):
    st = StatisticalTime()
    stfeats = st.transform(X)
    sf = StatisticalFrequency()
    sffeats = sf.transform(X)
    return np.concatenate((stfeats,sffeats),axis=1)

# %% [markdown]
# ##Wavelet Package Features

# %%
import pywt
class WaveletPackage(TransformerMixin):
  def __init__(self):
    pass
  def fit(self, X, y=None):
    return self
  def transform(self, X, y=None):
    def Energy(coeffs, k):
      return np.sqrt(np.sum(np.array(coeffs[-k]) ** 2)) / len(coeffs[-k])
    def getEnergy(wp):
      coefs = np.asarray([n.data for n in wp.get_leaf_nodes(True)])
      return np.asarray([Energy(coefs,i) for i in range(2**wp.maxlevel)])
    if X.shape[2] == 1:
      return np.array([getEnergy(pywt.WaveletPacket(data=x, wavelet='db4', mode='symmetric', maxlevel=4)) for x in X[:,:,0]])
    de = np.array([getEnergy(pywt.WaveletPacket(data=x, wavelet='db4', mode='symmetric', maxlevel=4)) for x in X[:,:,0]])
    fe = np.array([getEnergy(pywt.WaveletPacket(data=x, wavelet='db4', mode='symmetric', maxlevel=4)) for x in X[:,:,1]])
    return np.concatenate((de,fe),axis=1)

# %% [markdown]
# ##Heterogeneus Features

# %%
class Heterogeneous(TransformerMixin):
  def __init__(self):
    pass
  def fit(self, X, y=None):
    return self
  def transform(self, X, y=None):
    st = StatisticalTime()
    stfeats = st.transform(X)
    sf = StatisticalFrequency()
    sffeats = sf.transform(X)
    wp = WaveletPackage()
    wpfeats = wp.transform(X)
    return np.concatenate((stfeats,sffeats,wpfeats),axis=1)

# %% [markdown]
# #Define classification models

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ##K-NN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = Pipeline([('FeatureExtraction', Heterogeneous()),
                ('scaler', StandardScaler()),
                ('KNN', KNeighborsClassifier())])

# %% [markdown]
# ##Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedShuffleSplit

lmf = list(range(1,20))
lmf.append(None)
param_dist = {"rf__n_estimators": list(range(5,500,5)),
              "rf__max_features": lmf}
rfpl = Pipeline([('FeatureExtraction', Heterogeneous()),
                 ('scaler', StandardScaler()),
                 ('rf', RandomForestClassifier())])
rf = RandomizedSearchCV(rfpl, param_dist, n_iter=20, 
                        cv=StratifiedShuffleSplit(n_splits=1, test_size=0.3), verbose=3)

# %% [markdown]
# ##Artificial Neural Network - Conv1D

# %% [markdown]
# ###F1-Score for Keras

# %%
from tensorflow.keras import backend as K
def f1_score_macro(y_true,y_pred):
    def recall(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall
    def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ###3D standard scaler

# %%
import numpy as np
from sklearn.base import TransformerMixin
from sklearn.preprocessing import StandardScaler
class NDStandardScaler(TransformerMixin):
    def __init__(self):
        self._scaler = StandardScaler(copy=True)
        self._orig_shape = None
    def fit(self, X, y=None):
        X = np.array(X)
        # Save the original shape to reshape the flattened X later
        # back to its original shape
        if len(X.shape) > 1:
            self._orig_shape = X.shape[1:]
        X = self._flatten(X)
        self._scaler.fit(X)
        return self
    def transform(self, X, y=None):
        X = np.array(X)
        X = self._flatten(X)
        X = self._scaler.transform(X)
        X = self._reshape(X)
        return X
    def _flatten(self, X):
        # Reshape X to <= 2 dimensions
        if len(X.shape) > 2:
            n_dims = np.prod(self._orig_shape)
            X = X.reshape(-1, n_dims)
        return X
    def _reshape(self, X):
        # Reshape X back to it's original shape
        if len(X.shape) >= 2:
            X = X.reshape(-1, *self._orig_shape)
        return X

# %% [markdown]
# ###Neural Netword Architecture Definition
# Wrapped in a sklearn classifier

# %%
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical

from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.utils import shuffle
class ANNConv1D(BaseEstimator, ClassifierMixin):
  def __init__(self, n_filters=4, kernel_size=7, n_hidden_layers=1, pooling=2):
    self.n_filters = n_filters
    self.kernel_size = kernel_size
    self.n_hidden_layers = n_hidden_layers
    self.pooling = pooling
  def fit(self, X, y=None):
    y_cat = to_categorical(y)
    self.model = Sequential()
    self.model.add(layers.InputLayer(input_shape=(X.shape[1],X.shape[-1])))
    sample_length = X.shape[1]
    for layer in range(self.n_hidden_layers):
      sample_length = sample_length//self.pooling
      if sample_length<self.kernel_size:
        break
      self.model.add(layers.Conv1D(self.n_filters, self.kernel_size, activation='relu'))
      self.model.add(layers.MaxPooling1D(self.pooling))
    self.model.add(layers.Flatten())
    self.model.add(layers.Dense(len(labels_dict), activation='softmax'))
    print(self.model.summary())
    self.model.compile(optimizer='rmsprop',
                       loss='mean_squared_error', 
                       metrics=['accuracy',f1_score_macro])
    self.history = self.model.fit(X ,y_cat, epochs=100, 
                                  validation_split=0.15,
                                  callbacks=[EarlyStopping(patience=5),
                                             ReduceLROnPlateau()],
                                  verbose=0
                                  )
    return self
  def predict(self, X, y=None):
    return np.argmax(self.model.predict(X), axis=1)

# %% [markdown]
# ###Conv1D pipeline

# %%
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import RandomizedSearchCV
nnpl = Pipeline([('std_scaler', NDStandardScaler()),
                 ('ann', ANNConv1D())])
param_dist = {"ann__n_filters": list(range(32,129,32)),
              "ann__kernel_size": list(range(16,65,16)),
              "ann__n_hidden_layers": list(range(3,6)),
              "ann__pooling": list(range(2,9,2))}
conv1d = RandomizedSearchCV(nnpl, param_dist, n_iter=20,
                            cv=StratifiedShuffleSplit(n_splits=1, test_size=0.3), verbose=3)

# %% [markdown]
# ##Siamese model
# On going work...

# %%
def get_siamese_model(input_shape):
    """
        Model architecture based on the one provided in: http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
    """
    left_input = Input(input_shape)
    right_input = Input(input_shape)
    model = Sequential()
    model.add(Conv2D(64, (10,10), activation='relu', input_shape=input_shape,
                   kernel_initializer=initialize_weights, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(128, (7,7), activation='relu',
                     kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(128, (4,4), activation='relu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(256, (4,4), activation='relu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(Flatten())
    model.add(Dense(4096, activation='sigmoid',
                   kernel_regularizer=l2(1e-3),
                   kernel_initializer=initialize_weights,bias_initializer=initialize_bias))
    encoded_l = model(left_input)
    encoded_r = model(right_input)
    L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    L1_distance = L1_layer([encoded_l, encoded_r])
    prediction = Dense(1,activation='sigmoid',bias_initializer=initialize_bias)(L1_distance)
    siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)
    return siamese_net

# %% [markdown]
# ##List of classification methods

# %%
clfs = [
        ("RandomForest", rf),
        ("ANN-Conv1d", conv1d),
]
if not debug:
  clfs = [
          ("K-NNeighbors", knn),
          ("RandomForest", rf),
          ("ANN-Conv1d", conv1d),
         ]
#clfs = [("ANN-Conv1d", conv1d)]

# %% [markdown]
# #Perform experiments
# Common configurations for the three experiments.

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import f1_score,accuracy_score
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from sklearn.exceptions import ConvergenceWarning
warnings.simplefilter(action='ignore', category=ConvergenceWarning)
from sklearn.exceptions import UndefinedMetricWarning
warnings.simplefilter(action='ignore', category=UndefinedMetricWarning)
#Confunsion Matrix Configuration
genconfmat = True
if genconfmat:
  class_names = []
  for label in labels_dict.keys():
    class_names.append(label)
  figprop = np.linspace(1,0.5,25)
  tamconfmat = len(class_names)*figprop[len(class_names)]

results = {}
models = {}
nrounds = 1

# %% [markdown]
# ##kfold Experiments
# Usually seen in the literature.

# %%
X,y = None,None
for load in range(4):
  X,y = concatenate_datasets(X,y,eval('xn_'+str(load)),eval('yn_'+str(load)))
for severity in severities: 
  X,y = concatenate_datasets(X,y,eval('x'+str(severity)),eval('y'+str(severity)))
rskf = RepeatedStratifiedKFold(n_splits=len(severities), n_repeats=nrounds,
                                random_state=36851234)
fold = 0
count_round = 0

results['kfold'] = {}
models['kfold'] = {}
y_test_round = None
y_pred_round = {}

print("k-Fold")
for train_index, test_index in rskf.split(X, y):
  print("{}/{}".format(fold+1,rskf.get_n_splits()//nrounds), end=" x ")
  x_train, x_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]
  if y_test_round is None:
    y_test_round = np.copy(y_test)
  else:
    y_test_round = np.concatenate((y_test_round,y_test))
  j = count_round//(rskf.get_n_splits()//nrounds)
  count_round += 1
  print("{}/{}".format(j+1,nrounds))
  for clfname,model in clfs:
    print(clfname, end=":\t")
    if not clfname in results['kfold']:
      results['kfold'][clfname] = []
    history = model.fit(x_train ,y_train)
    if(hasattr(model,'best_params_')):
      print(model.best_params_)
    y_pred = model.predict(x_test)
    if not clfname in y_pred_round:
      y_pred_round[clfname] = None
    if y_pred_round[clfname] is None:
      y_pred_round[clfname] = np.copy(y_pred)
    else:
      y_pred_round[clfname] = np.concatenate((y_pred_round[clfname],y_pred))
    if not clfname+str(fold) in models['kfold']:
      models['kfold'][clfname+str(fold)] = model
    results['kfold'][clfname].append([accuracy_score(y_test,y_pred),f1_score(y_test,y_pred,average='macro')])
    print(results['kfold'][clfname][-1])
    if genconfmat:
      cnf_matrix = confusion_matrix(y_test, y_pred)
      print(cnf_matrix)
      plt.figure(figsize=(tamconfmat,tamconfmat))
      plot_confusion_matrix(cnf_matrix, classes=class_names, title=clfname+' - Fold '+str(fold+1)+' - Round '+str(j+1), normalize=False)
      plt.savefig('cnfmatrix_kfold'+clfname+str(fold)+'round'+str(j)+'.png')
      plt.show()
  if debug:
    break
  if fold >= (rskf.get_n_splits()//nrounds)-1:
    fold = 0
    for clfname,model in clfs:
      print([accuracy_score(y_test_round, y_pred_round[clfname]),
              f1_score(y_test_round, y_pred_round[clfname],average='macro')])
      if genconfmat:
        cnf_matrix = confusion_matrix(y_test_round, y_pred_round[clfname])
        print(cnf_matrix)
        plt.figure(figsize=(tamconfmat,tamconfmat))
        plot_confusion_matrix(cnf_matrix, classes=class_names, title=clfname+' - Round '+str(j+1), normalize=False)
        plt.savefig('cnfmatrix_kfold'+clfname+'_round'+str(j+1)+'.png')        
        plt.show()
      y_pred_round[clfname] = None
    y_test_round = None
  else:
    fold += 1
# Out:
# k-Fold
# 1/4 x 1/1
# K-NNeighbors:	[0.9748762847354396, 0.9743713107647791]
# [[1657    0    0    0]
#  [   0 1618   22   19]
#  [   5   41 1575   38]
#  [   0   43   30 2833]]
# Confusion matrix, without normalization
# RandomForest:	Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV] rf__n_estimators=140, rf__max_features=17 .......................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  rf__n_estimators=140, rf__max_features=17, score=0.987, total=  54.2s
# [CV] rf__n_estimators=100, rf__max_features=5 ........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   54.2s remaining:    0.0s
# [CV]  rf__n_estimators=100, rf__max_features=5, score=0.986, total=  33.9s
# [CV] rf__n_estimators=135, rf__max_features=13 .......................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.5min remaining:    0.0s
# [CV]  rf__n_estimators=135, rf__max_features=13, score=0.987, total=  47.7s
# [CV] rf__n_estimators=30, rf__max_features=18 ........................
# [CV]  rf__n_estimators=30, rf__max_features=18, score=0.986, total=  34.1s
# [CV] rf__n_estimators=75, rf__max_features=10 ........................
# [CV]  rf__n_estimators=75, rf__max_features=10, score=0.985, total=  36.3s
# [CV] rf__n_estimators=445, rf__max_features=11 .......................
# [CV]  rf__n_estimators=445, rf__max_features=11, score=0.987, total= 1.4min
# [CV] rf__n_estimators=170, rf__max_features=16 .......................
# [CV]  rf__n_estimators=170, rf__max_features=16, score=0.987, total=  57.9s
# [CV] rf__n_estimators=485, rf__max_features=4 ........................
# [CV]  rf__n_estimators=485, rf__max_features=4, score=0.987, total=  50.1s
# [CV] rf__n_estimators=210, rf__max_features=13 .......................
# [CV]  rf__n_estimators=210, rf__max_features=13, score=0.987, total=  58.2s
# [CV] rf__n_estimators=360, rf__max_features=10 .......................
# [CV]  rf__n_estimators=360, rf__max_features=10, score=0.988, total= 1.1min
# [CV] rf__n_estimators=70, rf__max_features=None ......................
# [CV]  rf__n_estimators=70, rf__max_features=None, score=0.983, total=  50.3s
# [CV] rf__n_estimators=330, rf__max_features=18 .......................
# [CV]  rf__n_estimators=330, rf__max_features=18, score=0.986, total= 1.5min
# [CV] rf__n_estimators=315, rf__max_features=11 .......................
# [CV]  rf__n_estimators=315, rf__max_features=11, score=0.987, total= 1.1min
# [CV] rf__n_estimators=410, rf__max_features=None .....................
# [CV]  rf__n_estimators=410, rf__max_features=None, score=0.984, total= 2.6min
# [CV] rf__n_estimators=380, rf__max_features=13 .......................
# [CV]  rf__n_estimators=380, rf__max_features=13, score=0.987, total= 1.4min
# [CV] rf__n_estimators=190, rf__max_features=15 .......................
# [CV]  rf__n_estimators=190, rf__max_features=15, score=0.987, total=  58.8s
# [CV] rf__n_estimators=445, rf__max_features=1 ........................
# [CV]  rf__n_estimators=445, rf__max_features=1, score=0.982, total=  35.6s
# [CV] rf__n_estimators=495, rf__max_features=13 .......................
# [CV]  rf__n_estimators=495, rf__max_features=13, score=0.987, total= 1.6min
# [CV] rf__n_estimators=230, rf__max_features=None .....................
# [CV]  rf__n_estimators=230, rf__max_features=None, score=0.982, total= 1.7min
# [CV] rf__n_estimators=245, rf__max_features=5 ........................
# [CV]  rf__n_estimators=245, rf__max_features=5, score=0.988, total=  41.5s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 21.7min finished
# {'rf__n_estimators': 360, 'rf__max_features': 10}
# [0.988833904326862, 0.9889054010370315]
# [[1657    0    0    0]
#  [   0 1642    5   12]
#  [   0   16 1623   20]
#  [   0   19   16 2871]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV] ann__pooling=4, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=32
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 481, 128)          4224
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 120, 128)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 89, 128)           524416
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 22, 128)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 2816)              0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 11268
# =================================================================
# Total params: 539,908
# Trainable params: 539,908
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=32, score=0.998, total=  38.5s
# [CV] ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=16
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   38.5s remaining:    0.0s
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 497, 128)          2176
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 248, 128)          0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 233, 128)          262272
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 116, 128)          0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 101, 128)          262272
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 50, 128)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 35, 128)           262272
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 17, 128)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2176)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 8708
# =================================================================
# Total params: 797,700
# Trainable params: 797,700
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=16, score=0.987, total= 1.1min
# [CV] ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=32, ann__kernel_size=32
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.7min remaining:    0.0s
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 481, 32)           1056
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 120, 32)           0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 89, 32)            32800
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 22, 32)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 704)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 2820
# =================================================================
# Total params: 36,676
# Trainable params: 36,676
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=32, ann__kernel_size=32, score=0.998, total=  30.3s
# [CV] ann__pooling=6, ann__n_hidden_layers=4, ann__n_filters=64, ann__kernel_size=48
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_8 (Conv1D)            (None, 465, 64)           3136
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 77, 64)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4928)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 19716
# =================================================================
# Total params: 22,852
# Trainable params: 22,852
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=4, ann__n_filters=64, ann__kernel_size=48, score=0.982, total=  24.9s
# [CV] ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=32
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_9 (Conv1D)            (None, 481, 64)           2112
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 240, 64)           0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 209, 64)           131136
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 104, 64)           0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 73, 64)            131136
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 36, 64)            0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 5, 64)             131136
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 2, 64)             0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 396,036
# Trainable params: 396,036
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=32, score=0.960, total=  21.1s
# [CV] ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=64, ann__kernel_size=64
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_13 (Conv1D)           (None, 449, 64)           4160
# _________________________________________________________________
# max_pooling1d_13 (MaxPooling (None, 56, 64)            0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 3584)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 14340
# =================================================================
# Total params: 18,500
# Trainable params: 18,500
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=64, ann__kernel_size=64, score=0.983, total=  49.9s
# [CV] ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=16
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_14 (Conv1D)           (None, 497, 128)          2176
# _________________________________________________________________
# max_pooling1d_14 (MaxPooling (None, 62, 128)           0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 7936)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 4)                 31748
# =================================================================
# Total params: 33,924
# Trainable params: 33,924
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=16, score=0.928, total=  50.5s
# [CV] ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=32
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_15 (Conv1D)           (None, 481, 128)          4224
# _________________________________________________________________
# max_pooling1d_15 (MaxPooling (None, 240, 128)          0
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 209, 128)          524416
# _________________________________________________________________
# max_pooling1d_16 (MaxPooling (None, 104, 128)          0
# _________________________________________________________________
# conv1d_17 (Conv1D)           (None, 73, 128)           524416
# _________________________________________________________________
# max_pooling1d_17 (MaxPooling (None, 36, 128)           0
# _________________________________________________________________
# conv1d_18 (Conv1D)           (None, 5, 128)            524416
# _________________________________________________________________
# max_pooling1d_18 (MaxPooling (None, 2, 128)            0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 1,578,500
# Trainable params: 1,578,500
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=32, score=0.958, total=  24.5s
# [CV] ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=16
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_19 (Conv1D)           (None, 497, 32)           544
# _________________________________________________________________
# max_pooling1d_19 (MaxPooling (None, 82, 32)            0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 2624)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 10500
# =================================================================
# Total params: 11,044
# Trainable params: 11,044
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=16, score=0.961, total= 1.2min
# [CV] ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=32
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_20 (Conv1D)           (None, 481, 96)           3168
# _________________________________________________________________
# max_pooling1d_20 (MaxPooling (None, 80, 96)            0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 7680)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 4)                 30724
# =================================================================
# Total params: 33,892
# Trainable params: 33,892
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=32, score=0.951, total=  31.2s
# [CV] ann__pooling=8, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=64
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_21 (Conv1D)           (None, 449, 128)          8320
# _________________________________________________________________
# max_pooling1d_21 (MaxPooling (None, 56, 128)           0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 7168)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 4)                 28676
# =================================================================
# Total params: 36,996
# Trainable params: 36,996
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=64, score=0.983, total=  31.6s
# [CV] ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=48
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_22 (Conv1D)           (None, 465, 128)          6272
# _________________________________________________________________
# max_pooling1d_22 (MaxPooling (None, 232, 128)          0
# _________________________________________________________________
# conv1d_23 (Conv1D)           (None, 185, 128)          786560
# _________________________________________________________________
# max_pooling1d_23 (MaxPooling (None, 92, 128)           0
# _________________________________________________________________
# conv1d_24 (Conv1D)           (None, 45, 128)           786560
# _________________________________________________________________
# max_pooling1d_24 (MaxPooling (None, 22, 128)           0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 2816)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 4)                 11268
# =================================================================
# Total params: 1,590,660
# Trainable params: 1,590,660
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=48, score=0.968, total=  50.3s
# [CV] ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=16
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_25 (Conv1D)           (None, 497, 32)           544
# _________________________________________________________________
# max_pooling1d_25 (MaxPooling (None, 124, 32)           0
# _________________________________________________________________
# conv1d_26 (Conv1D)           (None, 109, 32)           16416
# _________________________________________________________________
# max_pooling1d_26 (MaxPooling (None, 27, 32)            0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 864)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 4)                 3460
# =================================================================
# Total params: 20,420
# Trainable params: 20,420
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=16, score=0.986, total=  40.5s
# [CV] ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=64
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_27 (Conv1D)           (None, 449, 96)           6240
# _________________________________________________________________
# max_pooling1d_27 (MaxPooling (None, 74, 96)            0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 7104)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 4)                 28420
# =================================================================
# Total params: 34,660
# Trainable params: 34,660
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=64, score=0.986, total=  36.7s
# [CV] ann__pooling=4, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=32
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_28 (Conv1D)           (None, 481, 96)           3168
# _________________________________________________________________
# max_pooling1d_28 (MaxPooling (None, 120, 96)           0
# _________________________________________________________________
# conv1d_29 (Conv1D)           (None, 89, 96)            295008
# _________________________________________________________________
# max_pooling1d_29 (MaxPooling (None, 22, 96)            0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 2112)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 4)                 8452
# =================================================================
# Total params: 306,628
# Trainable params: 306,628
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=32, score=0.998, total=  20.3s
# [CV] ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=48
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_30 (Conv1D)           (None, 465, 96)           4704
# _________________________________________________________________
# max_pooling1d_30 (MaxPooling (None, 58, 96)            0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 5568)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 4)                 22276
# =================================================================
# Total params: 26,980
# Trainable params: 26,980
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=48, score=0.995, total= 1.1min
# [CV] ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=48
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_31 (Conv1D)           (None, 465, 128)          6272
# _________________________________________________________________
# max_pooling1d_31 (MaxPooling (None, 232, 128)          0
# _________________________________________________________________
# conv1d_32 (Conv1D)           (None, 185, 128)          786560
# _________________________________________________________________
# max_pooling1d_32 (MaxPooling (None, 92, 128)           0
# _________________________________________________________________
# conv1d_33 (Conv1D)           (None, 45, 128)           786560
# _________________________________________________________________
# max_pooling1d_33 (MaxPooling (None, 22, 128)           0
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 2816)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 4)                 11268
# =================================================================
# Total params: 1,590,660
# Trainable params: 1,590,660
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=48, score=0.993, total=  41.2s
# [CV] ann__pooling=8, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=32
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_34 (Conv1D)           (None, 481, 32)           1056
# _________________________________________________________________
# max_pooling1d_34 (MaxPooling (None, 60, 32)            0
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 1920)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 4)                 7684
# =================================================================
# Total params: 8,740
# Trainable params: 8,740
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=32, score=0.936, total=  57.9s
# [CV] ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=64
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_35 (Conv1D)           (None, 449, 96)           6240
# _________________________________________________________________
# max_pooling1d_35 (MaxPooling (None, 56, 96)            0
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 5376)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 4)                 21508
# =================================================================
# Total params: 27,748
# Trainable params: 27,748
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=64, score=0.987, total=  44.3s
# [CV] ann__pooling=2, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=48
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_36 (Conv1D)           (None, 465, 128)          6272
# _________________________________________________________________
# max_pooling1d_36 (MaxPooling (None, 232, 128)          0
# _________________________________________________________________
# conv1d_37 (Conv1D)           (None, 185, 128)          786560
# _________________________________________________________________
# max_pooling1d_37 (MaxPooling (None, 92, 128)           0
# _________________________________________________________________
# conv1d_38 (Conv1D)           (None, 45, 128)           786560
# _________________________________________________________________
# max_pooling1d_38 (MaxPooling (None, 22, 128)           0
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 2816)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 4)                 11268
# =================================================================
# Total params: 1,590,660
# Trainable params: 1,590,660
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=48, score=0.979, total=  22.7s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 13.6min finished
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_39 (Conv1D)           (None, 481, 128)          4224
# _________________________________________________________________
# max_pooling1d_39 (MaxPooling (None, 120, 128)          0
# _________________________________________________________________
# conv1d_40 (Conv1D)           (None, 89, 128)           524416
# _________________________________________________________________
# max_pooling1d_40 (MaxPooling (None, 22, 128)           0
# _________________________________________________________________
# flatten_20 (Flatten)         (None, 2816)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 4)                 11268
# =================================================================
# Total params: 539,908
# Trainable params: 539,908
# Non-trainable params: 0
# _________________________________________________________________
# None
# {'ann__pooling': 4, 'ann__n_hidden_layers': 5, 'ann__n_filters': 128, 'ann__kernel_size': 32}
# [0.9212028930338789, 0.9253492601711285]
# [[1657    0    0    0]
#  [   0 1427    0  232]
#  [   0   14 1422  223]
#  [   0  151    1 2754]]
# Confusion matrix, without normalization
# 2/4 x 1/1
# K-NNeighbors:	[0.974114960030453, 0.9734238897988385]
# [[1657    0    0    0]
#  [   0 1627   15   17]
#  [   5   54 1556   44]
#  [   0   38   31 2837]]
# Confusion matrix, without normalization
# RandomForest:	Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV] rf__n_estimators=215, rf__max_features=11 .......................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  rf__n_estimators=215, rf__max_features=11, score=0.984, total=  54.6s
# [CV] rf__n_estimators=280, rf__max_features=9 ........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   54.6s remaining:    0.0s
# [CV]  rf__n_estimators=280, rf__max_features=9, score=0.986, total=  55.9s
# [CV] rf__n_estimators=345, rf__max_features=7 ........................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.8min remaining:    0.0s
# [CV]  rf__n_estimators=345, rf__max_features=7, score=0.986, total=  55.1s
# [CV] rf__n_estimators=225, rf__max_features=18 .......................
# [CV]  rf__n_estimators=225, rf__max_features=18, score=0.984, total= 1.2min
# [CV] rf__n_estimators=250, rf__max_features=15 .......................
# [CV]  rf__n_estimators=250, rf__max_features=15, score=0.984, total= 1.2min
# [CV] rf__n_estimators=450, rf__max_features=None .....................
# [CV]  rf__n_estimators=450, rf__max_features=None, score=0.982, total= 2.8min
# [CV] rf__n_estimators=200, rf__max_features=14 .......................
# [CV]  rf__n_estimators=200, rf__max_features=14, score=0.984, total=  59.3s
# [CV] rf__n_estimators=445, rf__max_features=2 ........................
# [CV]  rf__n_estimators=445, rf__max_features=2, score=0.979, total=  39.7s
# [CV] rf__n_estimators=35, rf__max_features=None ......................
# [CV]  rf__n_estimators=35, rf__max_features=None, score=0.980, total=  39.6s
# [CV] rf__n_estimators=185, rf__max_features=3 ........................
# [CV]  rf__n_estimators=185, rf__max_features=3, score=0.981, total=  35.0s
# [CV] rf__n_estimators=370, rf__max_features=19 .......................
# [CV]  rf__n_estimators=370, rf__max_features=19, score=0.984, total= 1.7min
# [CV] rf__n_estimators=355, rf__max_features=2 ........................
# [CV]  rf__n_estimators=355, rf__max_features=2, score=0.980, total=  37.5s
# [CV] rf__n_estimators=185, rf__max_features=15 .......................
# [CV]  rf__n_estimators=185, rf__max_features=15, score=0.985, total=  58.5s
# [CV] rf__n_estimators=100, rf__max_features=15 .......................
# [CV]  rf__n_estimators=100, rf__max_features=15, score=0.984, total=  44.8s
# [CV] rf__n_estimators=100, rf__max_features=7 ........................
# [CV]  rf__n_estimators=100, rf__max_features=7, score=0.984, total=  36.2s
# [CV] rf__n_estimators=110, rf__max_features=13 .......................
# [CV]  rf__n_estimators=110, rf__max_features=13, score=0.985, total=  43.9s
# [CV] rf__n_estimators=370, rf__max_features=4 ........................
# [CV]  rf__n_estimators=370, rf__max_features=4, score=0.984, total=  45.2s
# [CV] rf__n_estimators=440, rf__max_features=12 .......................
# [CV]  rf__n_estimators=440, rf__max_features=12, score=0.985, total= 1.4min
# [CV] rf__n_estimators=20, rf__max_features=14 ........................
# [CV]  rf__n_estimators=20, rf__max_features=14, score=0.982, total=  31.4s
# [CV] rf__n_estimators=465, rf__max_features=18 .......................
# [CV]  rf__n_estimators=465, rf__max_features=18, score=0.984, total= 2.0min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 21.0min finished
# {'rf__n_estimators': 345, 'rf__max_features': 7}
# [0.9893414541301865, 0.9895279721254784]
# [[1657    0    0    0]
#  [   0 1643    5   11]
#  [   0   11 1620   28]
#  [   0   13   16 2877]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV] ann__pooling=2, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=16
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_41 (Conv1D)           (None, 497, 64)           1088
# _________________________________________________________________
# max_pooling1d_41 (MaxPooling (None, 248, 64)           0
# _________________________________________________________________
# conv1d_42 (Conv1D)           (None, 233, 64)           65600
# _________________________________________________________________
# max_pooling1d_42 (MaxPooling (None, 116, 64)           0
# _________________________________________________________________
# conv1d_43 (Conv1D)           (None, 101, 64)           65600
# _________________________________________________________________
# max_pooling1d_43 (MaxPooling (None, 50, 64)            0
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 3200)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 4)                 12804
# =================================================================
# Total params: 145,092
# Trainable params: 145,092
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=16, score=0.987, total=  47.5s
# [CV] ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=48
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   47.5s remaining:    0.0s
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_44 (Conv1D)           (None, 465, 96)           4704
# _________________________________________________________________
# max_pooling1d_44 (MaxPooling (None, 232, 96)           0
# _________________________________________________________________
# conv1d_45 (Conv1D)           (None, 185, 96)           442464
# _________________________________________________________________
# max_pooling1d_45 (MaxPooling (None, 92, 96)            0
# _________________________________________________________________
# conv1d_46 (Conv1D)           (None, 45, 96)            442464
# _________________________________________________________________
# max_pooling1d_46 (MaxPooling (None, 22, 96)            0
# _________________________________________________________________
# flatten_22 (Flatten)         (None, 2112)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 4)                 8452
# =================================================================
# Total params: 898,084
# Trainable params: 898,084
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=48, score=0.984, total=  26.0s
# [CV] ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=48
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.2min remaining:    0.0s
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_47 (Conv1D)           (None, 465, 96)           4704
# _________________________________________________________________
# max_pooling1d_47 (MaxPooling (None, 77, 96)            0
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 7392)              0
# _________________________________________________________________
# dense_23 (Dense)             (None, 4)                 29572
# =================================================================
# Total params: 34,276
# Trainable params: 34,276
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=48, score=0.952, total=  33.1s
# [CV] ann__pooling=2, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=16
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_48 (Conv1D)           (None, 497, 32)           544
# _________________________________________________________________
# max_pooling1d_48 (MaxPooling (None, 248, 32)           0
# _________________________________________________________________
# conv1d_49 (Conv1D)           (None, 233, 32)           16416
# _________________________________________________________________
# max_pooling1d_49 (MaxPooling (None, 116, 32)           0
# _________________________________________________________________
# conv1d_50 (Conv1D)           (None, 101, 32)           16416
# _________________________________________________________________
# max_pooling1d_50 (MaxPooling (None, 50, 32)            0
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 1600)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 4)                 6404
# =================================================================
# Total params: 39,780
# Trainable params: 39,780
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=16, score=0.997, total=  32.0s
# [CV] ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=64
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_51 (Conv1D)           (None, 449, 128)          8320
# _________________________________________________________________
# max_pooling1d_51 (MaxPooling (None, 224, 128)          0
# _________________________________________________________________
# conv1d_52 (Conv1D)           (None, 161, 128)          1048704
# _________________________________________________________________
# max_pooling1d_52 (MaxPooling (None, 80, 128)           0
# _________________________________________________________________
# conv1d_53 (Conv1D)           (None, 17, 128)           1048704
# _________________________________________________________________
# max_pooling1d_53 (MaxPooling (None, 8, 128)            0
# _________________________________________________________________
# flatten_25 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 4)                 4100
# =================================================================
# Total params: 2,109,828
# Trainable params: 2,109,828
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=64, score=0.933, total=  44.8s
# [CV] ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=48
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_54 (Conv1D)           (None, 465, 128)          6272
# _________________________________________________________________
# max_pooling1d_54 (MaxPooling (None, 77, 128)           0
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 9856)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 4)                 39428
# =================================================================
# Total params: 45,700
# Trainable params: 45,700
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=48, score=0.940, total=  35.2s
# [CV] ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=16
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_55 (Conv1D)           (None, 497, 96)           1632
# _________________________________________________________________
# max_pooling1d_55 (MaxPooling (None, 248, 96)           0
# _________________________________________________________________
# conv1d_56 (Conv1D)           (None, 233, 96)           147552
# _________________________________________________________________
# max_pooling1d_56 (MaxPooling (None, 116, 96)           0
# _________________________________________________________________
# conv1d_57 (Conv1D)           (None, 101, 96)           147552
# _________________________________________________________________
# max_pooling1d_57 (MaxPooling (None, 50, 96)            0
# _________________________________________________________________
# conv1d_58 (Conv1D)           (None, 35, 96)            147552
# _________________________________________________________________
# max_pooling1d_58 (MaxPooling (None, 17, 96)            0
# _________________________________________________________________
# flatten_27 (Flatten)         (None, 1632)              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 4)                 6532
# =================================================================
# Total params: 450,820
# Trainable params: 450,820
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=16, score=0.992, total=  40.5s
# [CV] ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=32
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_59 (Conv1D)           (None, 481, 128)          4224
# _________________________________________________________________
# max_pooling1d_59 (MaxPooling (None, 120, 128)          0
# _________________________________________________________________
# conv1d_60 (Conv1D)           (None, 89, 128)           524416
# ...
# [CV] ann__pooling=6, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=48
# Model: "sequential_72"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_139 (Conv1D)          (None, 465, 96)           4704
# _________________________________________________________________
# max_pooling1d_139 (MaxPoolin (None, 77, 96)            0
# _________________________________________________________________
# flatten_72 (Flatten)         (None, 7392)              0
# _________________________________________________________________
# dense_72 (Dense)             (None, 4)                 29572
# =================================================================
# Total params: 34,276
# Trainable params: 34,276
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=48, score=0.953, total=  49.3s
# [CV] ann__pooling=8, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=48
# Model: "sequential_73"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_140 (Conv1D)          (None, 465, 96)           4704
# _________________________________________________________________
# max_pooling1d_140 (MaxPoolin (None, 58, 96)            0
# _________________________________________________________________
# flatten_73 (Flatten)         (None, 5568)              0
# _________________________________________________________________
# dense_73 (Dense)             (None, 4)                 22276
# =================================================================
# Total params: 26,980
# Trainable params: 26,980
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=48, score=0.988, total= 1.1min
# [CV] ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=16
# Model: "sequential_74"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_141 (Conv1D)          (None, 497, 96)           1632
# _________________________________________________________________
# max_pooling1d_141 (MaxPoolin (None, 124, 96)           0
# _________________________________________________________________
# conv1d_142 (Conv1D)          (None, 109, 96)           147552
# _________________________________________________________________
# max_pooling1d_142 (MaxPoolin (None, 27, 96)            0
# _________________________________________________________________
# flatten_74 (Flatten)         (None, 2592)              0
# _________________________________________________________________
# dense_74 (Dense)             (None, 4)                 10372
# =================================================================
# Total params: 159,556
# Trainable params: 159,556
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=16, score=0.924, total=  39.2s
# [CV] ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=32, ann__kernel_size=64
# Model: "sequential_75"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_143 (Conv1D)          (None, 449, 32)           2080
# _________________________________________________________________
# max_pooling1d_143 (MaxPoolin (None, 56, 32)            0
# _________________________________________________________________
# flatten_75 (Flatten)         (None, 1792)              0
# _________________________________________________________________
# dense_75 (Dense)             (None, 4)                 7172
# =================================================================
# Total params: 9,252
# Trainable params: 9,252
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=32, ann__kernel_size=64, score=0.985, total= 1.6min
# [CV] ann__pooling=8, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=16
# Model: "sequential_76"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_144 (Conv1D)          (None, 497, 128)          2176
# _________________________________________________________________
# max_pooling1d_144 (MaxPoolin (None, 62, 128)           0
# _________________________________________________________________
# flatten_76 (Flatten)         (None, 7936)              0
# _________________________________________________________________
# dense_76 (Dense)             (None, 4)                 31748
# =================================================================
# Total params: 33,924
# Trainable params: 33,924
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=16, score=0.935, total= 1.0min
# [CV] ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=32
# Model: "sequential_77"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_145 (Conv1D)          (None, 481, 128)          4224
# _________________________________________________________________
# max_pooling1d_145 (MaxPoolin (None, 120, 128)          0
# _________________________________________________________________
# conv1d_146 (Conv1D)          (None, 89, 128)           524416
# _________________________________________________________________
# max_pooling1d_146 (MaxPoolin (None, 22, 128)           0
# _________________________________________________________________
# flatten_77 (Flatten)         (None, 2816)              0
# _________________________________________________________________
# dense_77 (Dense)             (None, 4)                 11268
# =================================================================
# Total params: 539,908
# Trainable params: 539,908
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=32, score=0.997, total=  54.1s
# [CV] ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=32
# Model: "sequential_78"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_147 (Conv1D)          (None, 481, 64)           2112
# _________________________________________________________________
# max_pooling1d_147 (MaxPoolin (None, 240, 64)           0
# _________________________________________________________________
# conv1d_148 (Conv1D)          (None, 209, 64)           131136
# _________________________________________________________________
# max_pooling1d_148 (MaxPoolin (None, 104, 64)           0
# _________________________________________________________________
# conv1d_149 (Conv1D)          (None, 73, 64)            131136
# _________________________________________________________________
# max_pooling1d_149 (MaxPoolin (None, 36, 64)            0
# _________________________________________________________________
# conv1d_150 (Conv1D)          (None, 5, 64)             131136
# _________________________________________________________________
# max_pooling1d_150 (MaxPoolin (None, 2, 64)             0
# _________________________________________________________________
# flatten_78 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_78 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 396,036
# Trainable params: 396,036
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=32, score=0.896, total=  48.2s
# [CV] ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=32, ann__kernel_size=64
# Model: "sequential_79"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_151 (Conv1D)          (None, 449, 32)           2080
# _________________________________________________________________
# max_pooling1d_151 (MaxPoolin (None, 224, 32)           0
# _________________________________________________________________
# conv1d_152 (Conv1D)          (None, 161, 32)           65568
# _________________________________________________________________
# max_pooling1d_152 (MaxPoolin (None, 80, 32)            0
# _________________________________________________________________
# conv1d_153 (Conv1D)          (None, 17, 32)            65568
# _________________________________________________________________
# max_pooling1d_153 (MaxPoolin (None, 8, 32)             0
# _________________________________________________________________
# flatten_79 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_79 (Dense)             (None, 4)                 1028
# =================================================================
# Total params: 134,244
# Trainable params: 134,244
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=32, ann__kernel_size=64, score=0.995, total=  45.0s
# [CV] ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=48
# Model: "sequential_80"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_154 (Conv1D)          (None, 465, 32)           1568
# _________________________________________________________________
# max_pooling1d_154 (MaxPoolin (None, 116, 32)           0
# _________________________________________________________________
# flatten_80 (Flatten)         (None, 3712)              0
# _________________________________________________________________
# dense_80 (Dense)             (None, 4)                 14852
# =================================================================
# Total params: 16,420
# Trainable params: 16,420
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=48, score=0.985, total= 1.2min
# [CV] ann__pooling=4, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=48
# Model: "sequential_81"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_155 (Conv1D)          (None, 465, 32)           1568
# _________________________________________________________________
# max_pooling1d_155 (MaxPoolin (None, 116, 32)           0
# _________________________________________________________________
# flatten_81 (Flatten)         (None, 3712)              0
# _________________________________________________________________
# dense_81 (Dense)             (None, 4)                 14852
# =================================================================
# Total params: 16,420
# Trainable params: 16,420
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=48, score=0.983, total= 1.1min
# [CV] ann__pooling=4, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=48
# Model: "sequential_82"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_156 (Conv1D)          (None, 465, 64)           3136
# _________________________________________________________________
# max_pooling1d_156 (MaxPoolin (None, 116, 64)           0
# _________________________________________________________________
# flatten_82 (Flatten)         (None, 7424)              0
# _________________________________________________________________
# dense_82 (Dense)             (None, 4)                 29700
# =================================================================
# Total params: 32,836
# Trainable params: 32,836
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=48, score=0.951, total=  49.9s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 19.9min finished
# Model: "sequential_83"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_157 (Conv1D)          (None, 497, 128)          2176
# _________________________________________________________________
# max_pooling1d_157 (MaxPoolin (None, 124, 128)          0
# _________________________________________________________________
# conv1d_158 (Conv1D)          (None, 109, 128)          262272
# _________________________________________________________________
# max_pooling1d_158 (MaxPoolin (None, 27, 128)           0
# _________________________________________________________________
# flatten_83 (Flatten)         (None, 3456)              0
# _________________________________________________________________
# dense_83 (Dense)             (None, 4)                 13828
# =================================================================
# Total params: 278,276
# Trainable params: 278,276
# Non-trainable params: 0
# _________________________________________________________________
# None
# {'ann__pooling': 4, 'ann__n_hidden_layers': 4, 'ann__n_filters': 128, 'ann__kernel_size': 16}
# [0.9049251078954049, 0.910282067732463]
# [[1657    0    0    0]
#  [   0 1426    4  228]
#  [   1   16 1397  244]
#  [   0  233   23 2649]]
# Confusion matrix, without normalization
# [0.9735097236762793, 0.9729076007302336]
# [[ 6628     0     0     0]
#  [    0  6500    73    62]
#  [   19   197  6223   196]
#  [    0   151   137 11335]]
# Confusion matrix, without normalization
# [0.9881348941975191, 0.9882957315384737]
# [[ 6628     0     0     0]
#  [    0  6568    20    47]
#  [    0    57  6461   117]
#  [    0    61    72 11490]]
# Confusion matrix, without normalization
# [0.9051743282256274, 0.9095260500614701]
# [[ 6628     0     0     0]
#  [    0  5686     4   945]
#  [    1   184  5488   962]
#  [    0   868    25 10730]]
# Confusion matrix, without normalization

# %% [markdown]
# ## byload Experiments
# Usually seen in cross-domain researches.

# %%
from sklearn.utils import shuffle
x0,y0 = acquisitions_from_substr('_0',acquisitions,labels_dict)
x1,y1 = acquisitions_from_substr('_1',acquisitions,labels_dict)
x2,y2 = acquisitions_from_substr('_2',acquisitions,labels_dict)
x3,y3 = acquisitions_from_substr('_3',acquisitions,labels_dict)
results['byload'] = {}
models['byload'] = {}
y_test_round = None
y_pred_round = {}

print("By Load")
loads = list(range(4))
for j in range(nrounds):
  for i,fold in enumerate(loads):
    print("{}".format(fold), end=" x ")
    x_test,y_test = eval('x'+str(i)),eval('y'+str(i))
    if y_test_round is None:
      y_test_round = np.copy(y_test)
    else:
      y_test_round = np.concatenate((y_test_round,y_test))
    x_train,y_train = None,None  
    for tfold in loads[:i]+loads[i+1:]:
      x_train,y_train = concatenate_datasets(x_train,y_train,eval('x'+str(tfold)),eval('y'+str(tfold)))
    x_train,y_train = shuffle(x_train,y_train,random_state=36851234+j)
    print("{}/{}".format(j+1,nrounds))
    for clfname,model in clfs:
      print(clfname, end=":\t")
      if not clfname in results['byload']:
        results['byload'][clfname] = []
      history = model.fit(x_train ,y_train)
      if(hasattr(model,'best_params_')):
        print(model.best_params_)
      y_pred = model.predict(x_test)
      if not clfname in y_pred_round:
        y_pred_round[clfname] = None
      if y_pred_round[clfname] is None:
        y_pred_round[clfname] = np.copy(y_pred)
      else:
        y_pred_round[clfname] = np.concatenate((y_pred_round[clfname],y_pred))
      if not clfname+str(fold) in models['byload']:
        models['byload'][clfname+str(fold)] = model
      results['byload'][clfname].append([accuracy_score(y_test,y_pred),f1_score(y_test,y_pred,average='macro')])
      print(results['byload'][clfname][-1])
      if genconfmat:
        cnf_matrix = confusion_matrix(y_test, y_pred)
        print(cnf_matrix)
        plt.figure(figsize=(tamconfmat,tamconfmat))
        plot_confusion_matrix(cnf_matrix, classes=class_names, title=clfname+' - Fold '+str(fold)+' - Round '+str(j+1), normalize=False)
        plt.savefig('cnfmatrix_byload'+clfname+str(fold)+'round'+str(j)+'.png')
        plt.show()
    if debug:
      break
  if debug:
    break
  for clfname,model in clfs:
    print([accuracy_score(y_test_round, y_pred_round[clfname]),
            f1_score(y_test_round, y_pred_round[clfname],average='macro')])
    if genconfmat:
      cnf_matrix = confusion_matrix(y_test_round, y_pred_round[clfname])
      print(cnf_matrix)
      plt.figure(figsize=(tamconfmat,tamconfmat))
      plot_confusion_matrix(cnf_matrix, classes=class_names, title=clfname+' - Round '+str(j+1), normalize=False)
      plt.savefig('cnfmatrix_kfold'+clfname+'_round'+str(j+1)+'.png')
      plt.show()
    y_pred_round[clfname] = None
  y_test_round = None
# Out:
# 97.mat 97.mat 105.mat 118.mat 130.mat 144.mat 156.mat 169.mat 185.mat 197.mat 222.mat 270.mat 274.mat 282.mat 209.mat 234.mat 246.mat 258.mat 278.mat 286.mat 290.mat 294.mat 298.mat 302.mat 310.mat 313.mat 315.mat 3001.mat 3005.mat _0
# 98.mat 98.mat 106.mat 119.mat 131.mat 145.mat 158.mat 170.mat 186.mat 198.mat 223.mat 271.mat 275.mat 283.mat 210.mat 235.mat 247.mat 259.mat 279.mat 287.mat 291.mat 295.mat 299.mat 305.mat 309.mat 316.mat 3002.mat 3006.mat _1
# 99.mat 99.mat 107.mat 120.mat 132.mat 146.mat 159.mat 171.mat 187.mat 199.mat 224.mat 272.mat 276.mat 284.mat 211.mat 236.mat 248.mat 260.mat 280.mat 288.mat 292.mat 296.mat 300.mat 306.mat 311.mat 317.mat 3003.mat 3007.mat _2
# 100.mat 100.mat 108.mat 121.mat 133.mat 147.mat 160.mat 172.mat 188.mat 200.mat 225.mat 273.mat 277.mat 285.mat 212.mat 237.mat 249.mat 261.mat 281.mat 289.mat 293.mat 297.mat 301.mat 307.mat 312.mat 318.mat 3004.mat 3008.mat _3
# By Load
# 0 x 1/1
# K-NNeighbors:	[0.9417528579205225, 0.9472559383101014]
# [[ 952    0    0    0]
#  [   0 1567   39   50]
#  [   5   49 1536   70]
#  [   1   40  174 2865]]
# Confusion matrix, without normalization
# RandomForest:	Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV] rf__n_estimators=490, rf__max_features=18 .......................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  rf__n_estimators=490, rf__max_features=18, score=0.990, total= 2.1min
# [CV] rf__n_estimators=150, rf__max_features=4 ........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.1min remaining:    0.0s
# [CV]  rf__n_estimators=150, rf__max_features=4, score=0.990, total=  35.9s
# [CV] rf__n_estimators=385, rf__max_features=18 .......................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  2.7min remaining:    0.0s
# [CV]  rf__n_estimators=385, rf__max_features=18, score=0.990, total= 1.8min
# [CV] rf__n_estimators=80, rf__max_features=2 .........................
# [CV]  rf__n_estimators=80, rf__max_features=2, score=0.987, total=  31.0s
# [CV] rf__n_estimators=445, rf__max_features=8 ........................
# [CV]  rf__n_estimators=445, rf__max_features=8, score=0.992, total= 1.1min
# [CV] rf__n_estimators=425, rf__max_features=17 .......................
# [CV]  rf__n_estimators=425, rf__max_features=17, score=0.990, total= 1.8min
# [CV] rf__n_estimators=205, rf__max_features=2 ........................
# [CV]  rf__n_estimators=205, rf__max_features=2, score=0.987, total=  34.6s
# [CV] rf__n_estimators=30, rf__max_features=17 ........................
# [CV]  rf__n_estimators=30, rf__max_features=17, score=0.988, total=  34.6s
# [CV] rf__n_estimators=425, rf__max_features=16 .......................
# [CV]  rf__n_estimators=425, rf__max_features=16, score=0.990, total= 1.7min
# [CV] rf__n_estimators=225, rf__max_features=None .....................
# [CV]  rf__n_estimators=225, rf__max_features=None, score=0.990, total= 1.7min
# [CV] rf__n_estimators=330, rf__max_features=16 .......................
# [CV]  rf__n_estimators=330, rf__max_features=16, score=0.990, total= 1.5min
# [CV] rf__n_estimators=50, rf__max_features=None ......................
# [CV]  rf__n_estimators=50, rf__max_features=None, score=0.989, total=  45.3s
# [CV] rf__n_estimators=20, rf__max_features=13 ........................
# [CV]  rf__n_estimators=20, rf__max_features=13, score=0.989, total=  32.2s
# [CV] rf__n_estimators=350, rf__max_features=12 .......................
# [CV]  rf__n_estimators=350, rf__max_features=12, score=0.990, total= 1.3min
# [CV] rf__n_estimators=290, rf__max_features=3 ........................
# [CV]  rf__n_estimators=290, rf__max_features=3, score=0.989, total=  39.5s
# [CV] rf__n_estimators=265, rf__max_features=None .....................
# [CV]  rf__n_estimators=265, rf__max_features=None, score=0.989, total= 1.9min
# [CV] rf__n_estimators=300, rf__max_features=17 .......................
# [CV]  rf__n_estimators=300, rf__max_features=17, score=0.990, total= 1.4min
# [CV] rf__n_estimators=70, rf__max_features=5 .........................
# [CV]  rf__n_estimators=70, rf__max_features=5, score=0.990, total=  33.6s
# [CV] rf__n_estimators=300, rf__max_features=7 ........................
# [CV]  rf__n_estimators=300, rf__max_features=7, score=0.991, total=  52.1s
# [CV] rf__n_estimators=245, rf__max_features=7 ........................
# [CV]  rf__n_estimators=245, rf__max_features=7, score=0.992, total=  48.5s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 22.8min finished
# {'rf__n_estimators': 445, 'rf__max_features': 8}
# [0.9514153511159499, 0.9572406657747168]
# [[ 952    0    0    0]
#  [   0 1514   32  110]
#  [   0   11 1592   57]
#  [   0    5  142 2933]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV] ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=32, ann__kernel_size=64
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Model: "sequential_84"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_159 (Conv1D)          (None, 449, 32)           2080
# _________________________________________________________________
# max_pooling1d_159 (MaxPoolin (None, 56, 32)            0
# _________________________________________________________________
# flatten_84 (Flatten)         (None, 1792)              0
# _________________________________________________________________
# dense_84 (Dense)             (None, 4)                 7172
# =================================================================
# Total params: 9,252
# Trainable params: 9,252
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=32, ann__kernel_size=64, score=0.997, total= 1.1min
# [CV] ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=48
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.1min remaining:    0.0s
# Model: "sequential_85"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_160 (Conv1D)          (None, 465, 64)           3136
# _________________________________________________________________
# max_pooling1d_160 (MaxPoolin (None, 77, 64)            0
# _________________________________________________________________
# flatten_85 (Flatten)         (None, 4928)              0
# _________________________________________________________________
# dense_85 (Dense)             (None, 4)                 19716
# =================================================================
# Total params: 22,852
# Trainable params: 22,852
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=48, score=0.996, total= 1.1min
# [CV] ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=64
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  2.2min remaining:    0.0s
# Model: "sequential_86"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_161 (Conv1D)          (None, 449, 128)          8320
# _________________________________________________________________
# max_pooling1d_161 (MaxPoolin (None, 112, 128)          0
# _________________________________________________________________
# flatten_86 (Flatten)         (None, 14336)             0
# _________________________________________________________________
# dense_86 (Dense)             (None, 4)                 57348
# =================================================================
# Total params: 65,668
# Trainable params: 65,668
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=64, score=0.966, total=  46.8s
# [CV] ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=64, ann__kernel_size=16
# Model: "sequential_87"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_162 (Conv1D)          (None, 497, 64)           1088
# _________________________________________________________________
# max_pooling1d_162 (MaxPoolin (None, 62, 64)            0
# _________________________________________________________________
# flatten_87 (Flatten)         (None, 3968)              0
# _________________________________________________________________
# dense_87 (Dense)             (None, 4)                 15876
# =================================================================
# Total params: 16,964
# Trainable params: 16,964
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=64, ann__kernel_size=16, score=0.941, total= 1.1min
# [CV] ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=48
# Model: "sequential_88"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_163 (Conv1D)          (None, 465, 96)           4704
# _________________________________________________________________
# max_pooling1d_163 (MaxPoolin (None, 58, 96)            0
# _________________________________________________________________
# flatten_88 (Flatten)         (None, 5568)              0
# _________________________________________________________________
# dense_88 (Dense)             (None, 4)                 22276
# =================================================================
# Total params: 26,980
# Trainable params: 26,980
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=48, score=0.964, total= 1.2min
# [CV] ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=64
# Model: "sequential_89"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_164 (Conv1D)          (None, 449, 64)           4160
# _________________________________________________________________
# max_pooling1d_164 (MaxPoolin (None, 74, 64)            0
# _________________________________________________________________
# flatten_89 (Flatten)         (None, 4736)              0
# _________________________________________________________________
# dense_89 (Dense)             (None, 4)                 18948
# =================================================================
# Total params: 23,108
# Trainable params: 23,108
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=64, score=0.993, total=  42.8s
# [CV] ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=64
# Model: "sequential_90"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_165 (Conv1D)          (None, 449, 128)          8320
# _________________________________________________________________
# max_pooling1d_165 (MaxPoolin (None, 112, 128)          0
# _________________________________________________________________
# flatten_90 (Flatten)         (None, 14336)             0
# _________________________________________________________________
# dense_90 (Dense)             (None, 4)                 57348
# =================================================================
# Total params: 65,668
# Trainable params: 65,668
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=64, score=0.955, total=  44.4s
# [CV] ann__pooling=6, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=32
# Model: "sequential_91"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_166 (Conv1D)          (None, 481, 32)           1056
# _________________________________________________________________
# max_pooling1d_166 (MaxPoolin (None, 80, 32)            0
# _________________________________________________________________
# flatten_91 (Flatten)         (None, 2560)              0
# _________________________________________________________________
# dense_91 (Dense)             (None, 4)                 10244
# =================================================================
# Total params: 11,300
# Trainable params: 11,300
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=32, score=0.983, total= 1.1min
# [CV] ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=32
# Model: "sequential_92"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_167 (Conv1D)          (None, 481, 128)          4224
# _________________________________________________________________
# max_pooling1d_167 (MaxPoolin (None, 240, 128)          0
# _________________________________________________________________
# conv1d_168 (Conv1D)          (None, 209, 128)          524416
# _________________________________________________________________
# max_pooling1d_168 (MaxPoolin (None, 104, 128)          0
# _________________________________________________________________
# conv1d_169 (Conv1D)          (None, 73, 128)           524416
# _________________________________________________________________
# max_pooling1d_169 (MaxPoolin (None, 36, 128)           0
# _________________________________________________________________
# conv1d_170 (Conv1D)          (None, 5, 128)            524416
# _________________________________________________________________
# max_pooling1d_170 (MaxPoolin (None, 2, 128)            0
# _________________________________________________________________
# flatten_92 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_92 (Dense)             (None, 4)                 1028
# =================================================================
# Total params: 1,578,500
# Trainable params: 1,578,500
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=32, score=0.938, total=  51.9s
# [CV] ann__pooling=2, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=16
# Model: "sequential_93"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_171 (Conv1D)          (None, 497, 64)           1088
# _________________________________________________________________
# max_pooling1d_171 (MaxPoolin (None, 248, 64)           0
# _________________________________________________________________
# conv1d_172 (Conv1D)          (None, 233, 64)           65600
# _________________________________________________________________
# max_pooling1d_172 (MaxPoolin (None, 116, 64)           0
# _________________________________________________________________
# conv1d_173 (Conv1D)          (None, 101, 64)           65600
# _________________________________________________________________
# max_pooling1d_173 (MaxPoolin (None, 50, 64)            0
# _________________________________________________________________
# flatten_93 (Flatten)         (None, 3200)              0
# _________________________________________________________________
# dense_93 (Dense)             (None, 4)                 12804
# =================================================================
# Total params: 145,092
# Trainable params: 145,092
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=16, score=0.998, total= 1.1min
# [CV] ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=16
# Model: "sequential_94"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_174 (Conv1D)          (None, 497, 32)           544
# _________________________________________________________________
# max_pooling1d_174 (MaxPoolin (None, 124, 32)           0
# _________________________________________________________________
# conv1d_175 (Conv1D)          (None, 109, 32)           16416
# _________________________________________________________________
# max_pooling1d_175 (MaxPoolin (None, 27, 32)            0
# _________________________________________________________________
# flatten_94 (Flatten)         (None, 864)               0
# _________________________________________________________________
# dense_94 (Dense)             (None, 4)                 3460
# =================================================================
# Total params: 20,420
# Trainable params: 20,420
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=16, score=0.999, total= 1.1min
# [CV] ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=32
# Model: "sequential_95"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_176 (Conv1D)          (None, 481, 128)          4224
# _________________________________________________________________
# max_pooling1d_176 (MaxPoolin (None, 60, 128)           0
# _________________________________________________________________
# flatten_95 (Flatten)         (None, 7680)              0
# _________________________________________________________________
# dense_95 (Dense)             (None, 4)                 30724
# =================================================================
# Total params: 34,948
# Trainable params: 34,948
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=32, score=0.974, total=  45.6s
# [CV] ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=32, ann__kernel_size=32
# Model: "sequential_96"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_177 (Conv1D)          (None, 481, 32)           1056
# _________________________________________________________________
# max_pooling1d_177 (MaxPoolin (None, 240, 32)           0
# _________________________________________________________________
# conv1d_178 (Conv1D)          (None, 209, 32)           32800
# _________________________________________________________________
# max_pooling1d_178 (MaxPoolin (None, 104, 32)           0
# _________________________________________________________________
# conv1d_179 (Conv1D)          (None, 73, 32)            32800
# _________________________________________________________________
# max_pooling1d_179 (MaxPoolin (None, 36, 32)            0
# _________________________________________________________________
# conv1d_180 (Conv1D)          (None, 5, 32)             32800
# _________________________________________________________________
# max_pooling1d_180 (MaxPoolin (None, 2, 32)             0
# _________________________________________________________________
# flatten_96 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dense_96 (Dense)             (None, 4)                 260
# =================================================================
# Total params: 99,716
# Trainable params: 99,716
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=32, ann__kernel_size=32, score=0.997, total=  48.9s
# [CV] ann__pooling=6, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=16
# Model: "sequential_97"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_181 (Conv1D)          (None, 497, 64)           1088
# _________________________________________________________________
# max_pooling1d_181 (MaxPoolin (None, 82, 64)            0
# _________________________________________________________________
# flatten_97 (Flatten)         (None, 5248)              0
# _________________________________________________________________
# dense_97 (Dense)             (None, 4)                 20996
# =================================================================
# Total params: 22,084
# Trainable params: 22,084
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=16, score=0.840, total= 1.2min
# [CV] ann__pooling=4, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=48
# Model: "sequential_98"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_182 (Conv1D)          (None, 465, 32)           1568
# _________________________________________________________________
# max_pooling1d_182 (MaxPoolin (None, 116, 32)           0
# _________________________________________________________________
# flatten_98 (Flatten)         (None, 3712)              0
# _________________________________________________________________
# dense_98 (Dense)             (None, 4)                 14852
# =================================================================
# Total params: 16,420
# Trainable params: 16,420
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=48, score=0.993, total=  52.4s
# [CV] ann__pooling=4, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=64
# Model: "sequential_99"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_183 (Conv1D)          (None, 449, 32)           2080
# _________________________________________________________________
# max_pooling1d_183 (MaxPoolin (None, 112, 32)           0
# _________________________________________________________________
# flatten_99 (Flatten)         (None, 3584)              0
# _________________________________________________________________
# dense_99 (Dense)             (None, 4)                 14340
# =================================================================
# Total params: 16,420
# Trainable params: 16,420
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=64, score=0.993, total= 1.1min
# [CV] ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=32
# Model: "sequential_100"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_184 (Conv1D)          (None, 481, 96)           3168
# _________________________________________________________________
# max_pooling1d_184 (MaxPoolin (None, 120, 96)           0
# _________________________________________________________________
# conv1d_185 (Conv1D)          (None, 89, 96)            295008
# _________________________________________________________________
# max_pooling1d_185 (MaxPoolin (None, 22, 96)            0
# _________________________________________________________________
# flatten_100 (Flatten)        (None, 2112)              0
# _________________________________________________________________
# dense_100 (Dense)            (None, 4)                 8452
# =================================================================
# Total params: 306,628
# Trainable params: 306,628
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=32, score=0.963, total=  52.1s
# [CV] ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=48
# Model: "sequential_101"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_186 (Conv1D)          (None, 465, 96)           4704
# _________________________________________________________________
# max_pooling1d_186 (MaxPoolin (None, 58, 96)            0
# _________________________________________________________________
# flatten_101 (Flatten)        (None, 5568)              0
# _________________________________________________________________
# dense_101 (Dense)            (None, 4)                 22276
# =================================================================
# Total params: 26,980
# Trainable params: 26,980
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=48, score=0.996, total=  49.0s
# [CV] ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=64, ann__kernel_size=32
# Model: "sequential_102"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_187 (Conv1D)          (None, 481, 64)           2112
# _________________________________________________________________
# max_pooling1d_187 (MaxPoolin (None, 60, 64)            0
# _________________________________________________________________
# flatten_102 (Flatten)        (None, 3840)              0
# _________________________________________________________________
# dense_102 (Dense)            (None, 4)                 15364
# =================================================================
# Total params: 17,476
# Trainable params: 17,476
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=64, ann__kernel_size=32, score=0.956, total=  46.6s
# [CV] ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=64
# Model: "sequential_103"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_188 (Conv1D)          (None, 449, 96)           6240
# _________________________________________________________________
# max_pooling1d_188 (MaxPoolin (None, 112, 96)           0
# _________________________________________________________________
# flatten_103 (Flatten)        (None, 10752)             0
# _________________________________________________________________
# dense_103 (Dense)            (None, 4)                 43012
# =================================================================
# Total params: 49,252
# Trainable params: 49,252
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=64, score=0.967, total= 1.2min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 19.3min finished
# Model: "sequential_104"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_189 (Conv1D)          (None, 497, 32)           544
# _________________________________________________________________
# max_pooling1d_189 (MaxPoolin (None, 124, 32)           0
# _________________________________________________________________
# conv1d_190 (Conv1D)          (None, 109, 32)           16416
# _________________________________________________________________
# max_pooling1d_190 (MaxPoolin (None, 27, 32)            0
# _________________________________________________________________
# flatten_104 (Flatten)        (None, 864)               0
# _________________________________________________________________
# dense_104 (Dense)            (None, 4)                 3460
# =================================================================
# Total params: 20,420
# Trainable params: 20,420
# Non-trainable params: 0
# _________________________________________________________________
# None
# {'ann__pooling': 4, 'ann__n_hidden_layers': 3, 'ann__n_filters': 32, 'ann__kernel_size': 16}
# [0.8946652150244965, 0.909960142204715]
# [[ 952    0    0    0]
#  [   1 1594   41   20]
#  [   4   42 1598   16]
#  [  30  594   26 2430]]
# Confusion matrix, without normalization
# 1 x 1/1
# K-NNeighbors:	[0.9611373230692823, 0.9596461704079974]
# [[1890    0    0    0]
#  [   0 1638   12    9]
#  [   7   76 1491   84]
#  [   0   84   41 2722]]
# Confusion matrix, without normalization
# RandomForest:	Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV] rf__n_estimators=325, rf__max_features=10 .......................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  rf__n_estimators=325, rf__max_features=10, score=0.988, total= 1.0min
# [CV] rf__n_estimators=440, rf__max_features=1 ........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.0min remaining:    0.0s
# [CV]  rf__n_estimators=440, rf__max_features=1, score=0.978, total=  35.7s
# [CV] rf__n_estimators=40, rf__max_features=14 ........................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.6min remaining:    0.0s
# [CV]  rf__n_estimators=40, rf__max_features=14, score=0.985, total=  34.0s
# [CV] rf__n_estimators=425, rf__max_features=10 .......................
# [CV]  rf__n_estimators=425, rf__max_features=10, score=0.988, total= 1.2min
# [CV] rf__n_estimators=140, rf__max_features=None .....................
# [CV]  rf__n_estimators=140, rf__max_features=None, score=0.985, total= 1.2min
# [CV] rf__n_estimators=250, rf__max_features=10 .......................
# [CV]  rf__n_estimators=250, rf__max_features=10, score=0.988, total=  54.9s
# [CV] rf__n_estimators=210, rf__max_features=4 ........................
# [CV]  rf__n_estimators=210, rf__max_features=4, score=0.988, total=  37.9s
# [CV] rf__n_estimators=290, rf__max_features=18 .......................
# [CV]  rf__n_estimators=290, rf__max_features=18, score=0.986, total= 1.4min
# [CV] rf__n_estimators=210, rf__max_features=8 ........................
# [CV]  rf__n_estimators=210, rf__max_features=8, score=0.987, total=  46.0s
# [CV] rf__n_estimators=170, rf__max_features=5 ........................
# [CV]  rf__n_estimators=170, rf__max_features=5, score=0.988, total=  37.9s
# [CV] rf__n_estimators=220, rf__max_features=15 .......................
# [CV]  rf__n_estimators=220, rf__max_features=15, score=0.988, total= 1.1min
# [CV] rf__n_estimators=460, rf__max_features=4 ........................
# [CV]  rf__n_estimators=460, rf__max_features=4, score=0.988, total=  49.3s
# [CV] rf__n_estimators=155, rf__max_features=7 ........................
# [CV]  rf__n_estimators=155, rf__max_features=7, score=0.989, total=  39.7s
# [CV] rf__n_estimators=385, rf__max_features=2 ........................
# [CV]  rf__n_estimators=385, rf__max_features=2, score=0.986, total=  38.4s
# [CV] rf__n_estimators=365, rf__max_features=8 ........................
# [CV]  rf__n_estimators=365, rf__max_features=8, score=0.988, total=  59.5s
# [CV] rf__n_estimators=35, rf__max_features=8 .........................
# [CV]  rf__n_estimators=35, rf__max_features=8, score=0.985, total=  31.3s
# [CV] rf__n_estimators=135, rf__max_features=13 .......................
# [CV]  rf__n_estimators=135, rf__max_features=13, score=0.988, total=  46.9s
# [CV] rf__n_estimators=155, rf__max_features=13 .......................
# [CV]  rf__n_estimators=155, rf__max_features=13, score=0.986, total=  49.5s
# [CV] rf__n_estimators=370, rf__max_features=17 .......................
# [CV]  rf__n_estimators=370, rf__max_features=17, score=0.987, total= 1.6min
# [CV] rf__n_estimators=295, rf__max_features=14 .......................
# [CV]  rf__n_estimators=295, rf__max_features=14, score=0.987, total= 1.2min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 18.0min finished
# {'rf__n_estimators': 155, 'rf__max_features': 7}
# [0.9807549043953315, 0.98119227445298]
# [[1890    0    0    0]
#  [   0 1654    3    2]
#  [   2    9 1613   34]
#  [   0   90   15 2742]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV] ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=16
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Model: "sequential_105"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_191 (Conv1D)          (None, 497, 96)           1632
# _________________________________________________________________
# max_pooling1d_191 (MaxPoolin (None, 248, 96)           0
# _________________________________________________________________
# conv1d_192 (Conv1D)          (None, 233, 96)           147552
# _________________________________________________________________
# max_pooling1d_192 (MaxPoolin (None, 116, 96)           0
# _________________________________________________________________
# conv1d_193 (Conv1D)          (None, 101, 96)           147552
# _________________________________________________________________
# max_pooling1d_193 (MaxPoolin (None, 50, 96)            0
# _________________________________________________________________
# conv1d_194 (Conv1D)          (None, 35, 96)            147552
# _________________________________________________________________
# max_pooling1d_194 (MaxPoolin (None, 17, 96)            0
# _________________________________________________________________
# flatten_105 (Flatten)        (None, 1632)              0
# _________________________________________________________________
# dense_105 (Dense)            (None, 4)                 6532
# =================================================================
# Total params: 450,820
# Trainable params: 450,820
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=16, score=0.952, total=  51.1s
# [CV] ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=64
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   51.1s remaining:    0.0s
# Model: "sequential_106"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_195 (Conv1D)          (None, 449, 32)           2080
# _________________________________________________________________
# max_pooling1d_195 (MaxPoolin (None, 112, 32)           0
# _________________________________________________________________
# flatten_106 (Flatten)        (None, 3584)              0
# _________________________________________________________________
# dense_106 (Dense)            (None, 4)                 14340
# =================================================================
# Total params: 16,420
# Trainable params: 16,420
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=64, score=0.996, total= 1.4min
# [CV] ann__pooling=6, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=16
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  2.3min remaining:    0.0s
# Model: "sequential_107"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_196 (Conv1D)          (None, 497, 128)          2176
# _________________________________________________________________
# max_pooling1d_196 (MaxPoolin (None, 82, 128)           0
# _________________________________________________________________
# flatten_107 (Flatten)        (None, 10496)             0
# _________________________________________________________________
# dense_107 (Dense)            (None, 4)                 41988
# =================================================================
# Total params: 44,164
# Trainable params: 44,164
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=16, score=0.950, total= 1.3min
# [CV] ann__pooling=6, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=32
# Model: "sequential_108"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_197 (Conv1D)          (None, 481, 128)          4224
# _________________________________________________________________
# max_pooling1d_197 (MaxPoolin (None, 80, 128)           0
# _________________________________________________________________
# flatten_108 (Flatten)        (None, 10240)             0
# _________________________________________________________________
# dense_108 (Dense)            (None, 4)                 40964
# =================================================================
# Total params: 45,188
# Trainable params: 45,188
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=32, score=0.964, total= 1.6min
# [CV] ann__pooling=6, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=48
# Model: "sequential_109"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_198 (Conv1D)          (None, 465, 96)           4704
# _________________________________________________________________
# max_pooling1d_198 (MaxPoolin (None, 77, 96)            0
# _________________________________________________________________
# flatten_109 (Flatten)        (None, 7392)              0
# _________________________________________________________________
# dense_109 (Dense)            (None, 4)                 29572
# =================================================================
# Total params: 34,276
# Trainable params: 34,276
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=48, score=0.963, total= 1.2min
# [CV] ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=32
# Model: "sequential_110"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_199 (Conv1D)          (None, 481, 128)          4224
# _________________________________________________________________
# max_pooling1d_199 (MaxPoolin (None, 80, 128)           0
# _________________________________________________________________
# flatten_110 (Flatten)        (None, 10240)             0
# _________________________________________________________________
# dense_110 (Dense)            (None, 4)                 40964
# =================================================================
# Total params: 45,188
# Trainable params: 45,188
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=32, score=0.994, total= 1.3min
# [CV] ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=64, ann__kernel_size=32
# Model: "sequential_111"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_200 (Conv1D)          (None, 481, 64)           2112
# _________________________________________________________________
# max_pooling1d_200 (MaxPoolin (None, 120, 64)           0
# _________________________________________________________________
# conv1d_201 (Conv1D)          (None, 89, 64)            131136
# _________________________________________________________________
# max_pooling1d_201 (MaxPoolin (None, 22, 64)            0
# _________________________________________________________________
# flatten_111 (Flatten)        (None, 1408)              0
# _________________________________________________________________
# dense_111 (Dense)            (None, 4)                 5636
# =================================================================
# Total params: 138,884
# Trainable params: 138,884
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=64, ann__kernel_size=32, score=0.997, total=  51.4s
# [CV] ann__pooling=6, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=64
# Model: "sequential_112"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_202 (Conv1D)          (None, 449, 128)          8320
# _________________________________________________________________
# max_pooling1d_202 (MaxPoolin (None, 74, 128)           0
# _________________________________________________________________
# flatten_112 (Flatten)        (None, 9472)              0
# _________________________________________________________________
# dense_112 (Dense)            (None, 4)                 37892
# =================================================================
# Total params: 46,212
# Trainable params: 46,212
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=64, score=0.995, total=  57.8s
# [CV] ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=32
# Model: "sequential_113"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_203 (Conv1D)          (None, 481, 128)          4224
# _________________________________________________________________
# max_pooling1d_203 (MaxPoolin (None, 240, 128)          0
# _________________________________________________________________
# conv1d_204 (Conv1D)          (None, 209, 128)          524416
# _________________________________________________________________
# max_pooling1d_204 (MaxPoolin (None, 104, 128)          0
# _________________________________________________________________
# conv1d_205 (Conv1D)          (None, 73, 128)           524416
# _________________________________________________________________
# max_pooling1d_205 (MaxPoolin (None, 36, 128)           0
# _________________________________________________________________
# conv1d_206 (Conv1D)          (None, 5, 128)            524416
# _________________________________________________________________
# max_pooling1d_206 (MaxPoolin (None, 2, 128)            0
# _________________________________________________________________
# flatten_113 (Flatten)        (None, 256)               0
# _________________________________________________________________
# dense_113 (Dense)            (None, 4)                 1028
# =================================================================
# Total params: 1,578,500
# Trainable params: 1,578,500
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=32, score=0.979, total= 1.0min
# [CV] ann__pooling=2, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=16
# Model: "sequential_114"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_207 (Conv1D)          (None, 497, 64)           1088
# _________________________________________________________________
# max_pooling1d_207 (MaxPoolin (None, 248, 64)           0
# _________________________________________________________________
# conv1d_208 (Conv1D)          (None, 233, 64)           65600
# _________________________________________________________________
# max_pooling1d_208 (MaxPoolin (None, 116, 64)           0
# _________________________________________________________________
# conv1d_209 (Conv1D)          (None, 101, 64)           65600
# _________________________________________________________________
# max_pooling1d_209 (MaxPoolin (None, 50, 64)            0
# _________________________________________________________________
# flatten_114 (Flatten)        (None, 3200)              0
# _________________________________________________________________
# dense_114 (Dense)            (None, 4)                 12804
# =================================================================
# Total params: 145,092
# ...
# dense_156 (Dense)            (None, 4)                 30724
# =================================================================
# Total params: 34,948
# Trainable params: 34,948
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=32, score=0.994, total= 2.0min
# [CV] ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=32
# Model: "sequential_157"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_276 (Conv1D)          (None, 481, 96)           3168
# _________________________________________________________________
# max_pooling1d_276 (MaxPoolin (None, 60, 96)            0
# _________________________________________________________________
# flatten_157 (Flatten)        (None, 5760)              0
# _________________________________________________________________
# dense_157 (Dense)            (None, 4)                 23044
# =================================================================
# Total params: 26,212
# Trainable params: 26,212
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=32, score=0.952, total= 1.5min
# [CV] ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=32
# Model: "sequential_158"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_277 (Conv1D)          (None, 481, 96)           3168
# _________________________________________________________________
# max_pooling1d_277 (MaxPoolin (None, 240, 96)           0
# _________________________________________________________________
# conv1d_278 (Conv1D)          (None, 209, 96)           295008
# _________________________________________________________________
# max_pooling1d_278 (MaxPoolin (None, 104, 96)           0
# _________________________________________________________________
# conv1d_279 (Conv1D)          (None, 73, 96)            295008
# _________________________________________________________________
# max_pooling1d_279 (MaxPoolin (None, 36, 96)            0
# _________________________________________________________________
# conv1d_280 (Conv1D)          (None, 5, 96)             295008
# _________________________________________________________________
# max_pooling1d_280 (MaxPoolin (None, 2, 96)             0
# _________________________________________________________________
# flatten_158 (Flatten)        (None, 192)               0
# _________________________________________________________________
# dense_158 (Dense)            (None, 4)                 772
# =================================================================
# Total params: 888,964
# Trainable params: 888,964
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=32, score=0.977, total= 1.2min
# [CV] ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=64
# Model: "sequential_159"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_281 (Conv1D)          (None, 449, 96)           6240
# _________________________________________________________________
# max_pooling1d_281 (MaxPoolin (None, 224, 96)           0
# _________________________________________________________________
# conv1d_282 (Conv1D)          (None, 161, 96)           589920
# _________________________________________________________________
# max_pooling1d_282 (MaxPoolin (None, 80, 96)            0
# _________________________________________________________________
# conv1d_283 (Conv1D)          (None, 17, 96)            589920
# _________________________________________________________________
# max_pooling1d_283 (MaxPoolin (None, 8, 96)             0
# _________________________________________________________________
# flatten_159 (Flatten)        (None, 768)               0
# _________________________________________________________________
# dense_159 (Dense)            (None, 4)                 3076
# =================================================================
# Total params: 1,189,156
# Trainable params: 1,189,156
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=64, score=0.949, total=  59.0s
# [CV] ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=32
# Model: "sequential_160"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_284 (Conv1D)          (None, 481, 96)           3168
# _________________________________________________________________
# max_pooling1d_284 (MaxPoolin (None, 240, 96)           0
# _________________________________________________________________
# conv1d_285 (Conv1D)          (None, 209, 96)           295008
# _________________________________________________________________
# max_pooling1d_285 (MaxPoolin (None, 104, 96)           0
# _________________________________________________________________
# conv1d_286 (Conv1D)          (None, 73, 96)            295008
# _________________________________________________________________
# max_pooling1d_286 (MaxPoolin (None, 36, 96)            0
# _________________________________________________________________
# conv1d_287 (Conv1D)          (None, 5, 96)             295008
# _________________________________________________________________
# max_pooling1d_287 (MaxPoolin (None, 2, 96)             0
# _________________________________________________________________
# flatten_160 (Flatten)        (None, 192)               0
# _________________________________________________________________
# dense_160 (Dense)            (None, 4)                 772
# =================================================================
# Total params: 888,964
# Trainable params: 888,964
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=32, score=0.983, total= 1.1min
# [CV] ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=48
# Model: "sequential_161"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_288 (Conv1D)          (None, 465, 128)          6272
# _________________________________________________________________
# max_pooling1d_288 (MaxPoolin (None, 77, 128)           0
# _________________________________________________________________
# flatten_161 (Flatten)        (None, 9856)              0
# _________________________________________________________________
# dense_161 (Dense)            (None, 4)                 39428
# =================================================================
# Total params: 45,700
# Trainable params: 45,700
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=48, score=0.967, total= 1.9min
# [CV] ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=16
# Model: "sequential_162"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_289 (Conv1D)          (None, 497, 128)          2176
# _________________________________________________________________
# max_pooling1d_289 (MaxPoolin (None, 82, 128)           0
# _________________________________________________________________
# flatten_162 (Flatten)        (None, 10496)             0
# _________________________________________________________________
# dense_162 (Dense)            (None, 4)                 41988
# =================================================================
# Total params: 44,164
# Trainable params: 44,164
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=16, score=0.959, total= 1.5min
# [CV] ann__pooling=6, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=64
# Model: "sequential_163"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_290 (Conv1D)          (None, 449, 96)           6240
# _________________________________________________________________
# max_pooling1d_290 (MaxPoolin (None, 74, 96)            0
# _________________________________________________________________
# flatten_163 (Flatten)        (None, 7104)              0
# _________________________________________________________________
# dense_163 (Dense)            (None, 4)                 28420
# =================================================================
# Total params: 34,660
# Trainable params: 34,660
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=64, score=0.963, total= 1.1min
# [CV] ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=48
# Model: "sequential_164"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_291 (Conv1D)          (None, 465, 32)           1568
# _________________________________________________________________
# max_pooling1d_291 (MaxPoolin (None, 77, 32)            0
# _________________________________________________________________
# flatten_164 (Flatten)        (None, 2464)              0
# _________________________________________________________________
# dense_164 (Dense)            (None, 4)                 9860
# =================================================================
# Total params: 11,428
# Trainable params: 11,428
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=48, score=0.984, total= 1.6min
# [CV] ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=64
# Model: "sequential_165"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_292 (Conv1D)          (None, 449, 64)           4160
# _________________________________________________________________
# max_pooling1d_292 (MaxPoolin (None, 112, 64)           0
# _________________________________________________________________
# flatten_165 (Flatten)        (None, 7168)              0
# _________________________________________________________________
# dense_165 (Dense)            (None, 4)                 28676
# =================================================================
# Total params: 32,836
# Trainable params: 32,836
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=64, score=0.950, total= 1.2min
# [CV] ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=48
# Model: "sequential_166"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_293 (Conv1D)          (None, 465, 64)           3136
# _________________________________________________________________
# max_pooling1d_293 (MaxPoolin (None, 232, 64)           0
# _________________________________________________________________
# conv1d_294 (Conv1D)          (None, 185, 64)           196672
# _________________________________________________________________
# max_pooling1d_294 (MaxPoolin (None, 92, 64)            0
# _________________________________________________________________
# conv1d_295 (Conv1D)          (None, 45, 64)            196672
# _________________________________________________________________
# max_pooling1d_295 (MaxPoolin (None, 22, 64)            0
# _________________________________________________________________
# flatten_166 (Flatten)        (None, 1408)              0
# _________________________________________________________________
# dense_166 (Dense)            (None, 4)                 5636
# =================================================================
# Total params: 402,116
# Trainable params: 402,116
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=48, score=0.991, total= 1.3min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 27.5min finished
# Model: "sequential_167"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_296 (Conv1D)          (None, 481, 64)           2112
# _________________________________________________________________
# max_pooling1d_296 (MaxPoolin (None, 120, 64)           0
# _________________________________________________________________
# conv1d_297 (Conv1D)          (None, 89, 64)            131136
# _________________________________________________________________
# max_pooling1d_297 (MaxPoolin (None, 22, 64)            0
# _________________________________________________________________
# flatten_167 (Flatten)        (None, 1408)              0
# _________________________________________________________________
# dense_167 (Dense)            (None, 4)                 5636
# =================================================================
# Total params: 138,884
# Trainable params: 138,884
# Non-trainable params: 0
# _________________________________________________________________
# None
# {'ann__pooling': 4, 'ann__n_hidden_layers': 3, 'ann__n_filters': 64, 'ann__kernel_size': 32}
# [0.9864814585142007, 0.986222012069224]
# [[1896    0    0    0]
#  [   0 1622   26   13]
#  [   0    1 1649    6]
#  [   0   12   51 2787]]
# Confusion matrix, without normalization
# [0.9468925478252593, 0.9470067709653485]
# [[ 6627     0     1     0]
#  [    0  6366   127   142]
#  [   29   232  5842   532]
#  [    1   280   330 11012]]
# Confusion matrix, without normalization
# [0.9591066273278132, 0.960513007160874]
# [[ 6628     0     0     0]
#  [    0  6329    70   236]
#  [    2    76  6104   453]
#  [    0   151   301 11171]]
# Confusion matrix, without normalization
# [0.9691634148662797, 0.9703345228312621]
# [[ 6628     0     0     0]
#  [    1  6481    98    55]
#  [   10    45  6550    30]
#  [   30   610    93 10890]]
# Confusion matrix, without normalization

# %% [markdown]
# ##byseverity Experiments
# Proposed method.

# %%
from sklearn.utils import shuffle
results['byseverity'] = {}
models['byseverity'] = {}
y_test_round = None
y_pred_round = {}

print("By Severity")
for j in range(nrounds):
  for i,fold in enumerate(severities):
    print("{}".format(fold), end=" x ")
    x_test,y_test = eval('xn_'+str((i+len(severities)+j)%4)),eval('yn_'+str((i+len(severities)+j)%4))
    x_test,y_test = concatenate_datasets(x_test,y_test,eval('x'+str(fold)),eval('y'+str(fold)))
    if y_test_round is None:
      y_test_round = np.copy(y_test)
    else:
      y_test_round = np.concatenate((y_test_round,y_test))
    x_train,y_train = None,None  
    for ni in list(range(0,4)):
      if ni != (i+len(severities)+j)%4:
        x_train,y_train = concatenate_datasets(x_train,y_train,eval('xn_'+str(ni)),eval('yn_'+str(ni)))
    for tfold in severities[:i]+severities[i+1:]:
      x_train,y_train = concatenate_datasets(x_train,y_train,eval('x'+str(tfold)),eval('y'+str(tfold)))
    x_train,y_train = shuffle(x_train,y_train,random_state=36851234+j)
    print("{}/{}".format(j+1,nrounds))
    for clfname,model in clfs:
      print(clfname, end=":\t")
      if not clfname in results['byseverity']:
        results['byseverity'][clfname] = []
      history = model.fit(x_train ,y_train)
      if(hasattr(model,'best_params_')):
        print(model.best_params_)
      y_pred = model.predict(x_test)
      if not clfname in y_pred_round:
        y_pred_round[clfname] = None
      if y_pred_round[clfname] is None:
        y_pred_round[clfname] = np.copy(y_pred)
      else:
        y_pred_round[clfname] = np.concatenate((y_pred_round[clfname],y_pred))
      if not clfname+str(fold) in models['byseverity']:
        models['byseverity'][clfname+str(fold)] = model
      results['byseverity'][clfname].append([accuracy_score(y_test,y_pred),f1_score(y_test,y_pred,average='macro')])
      print(results['byseverity'][clfname][-1])
      if genconfmat:
        cnf_matrix = confusion_matrix(y_test, y_pred)
        print(cnf_matrix)
        plt.figure(figsize=(tamconfmat,tamconfmat))
        plot_confusion_matrix(cnf_matrix, classes=class_names, title=clfname+' - Fold '+str(fold)+' - Round '+str(j+1), normalize=False)
        plt.savefig('cnfmatrix_byseverity'+clfname+str(fold)+'round'+str(j)+'.png')
        plt.show()
  if debug:
    break
  for clfname,model in clfs:
    print([accuracy_score(y_test_round, y_pred_round[clfname]),
            f1_score(y_test_round, y_pred_round[clfname],average='macro')])
    if genconfmat:
      cnf_matrix = confusion_matrix(y_test_round, y_pred_round[clfname])
      print(cnf_matrix)
      plt.figure(figsize=(tamconfmat,tamconfmat))
      plot_confusion_matrix(cnf_matrix, classes=class_names, title=clfname+' - Round '+str(j+1), normalize=False)
      plt.savefig('cnfmatrix_kfold'+clfname+'_round'+str(j+1)+'.png')
      plt.show()
    y_pred_round[clfname] = None
  y_test_round = None
# Out:
# By Severity
# 007 x 1/1
# K-NNeighbors:	[0.5728927203065134, 0.6340583389954915]
# [[ 952    0    0    0]
#  [   0  752    1 1147]
#  [  13   69 1765   47]
#  [   1  936 2245 2512]]
# Confusion matrix, without normalization
# RandomForest:	Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV] rf__n_estimators=320, rf__max_features=14 .......................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  rf__n_estimators=320, rf__max_features=14, score=0.990, total= 1.1min
# [CV] rf__n_estimators=230, rf__max_features=16 .......................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.1min remaining:    0.0s
# [CV]  rf__n_estimators=230, rf__max_features=16, score=0.990, total=  57.6s
# [CV] rf__n_estimators=240, rf__max_features=8 ........................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  2.0min remaining:    0.0s
# [CV]  rf__n_estimators=240, rf__max_features=8, score=0.991, total=  43.4s
# [CV] rf__n_estimators=395, rf__max_features=19 .......................
# [CV]  rf__n_estimators=395, rf__max_features=19, score=0.990, total= 1.5min
# [CV] rf__n_estimators=375, rf__max_features=19 .......................
# [CV]  rf__n_estimators=375, rf__max_features=19, score=0.989, total= 1.5min
# [CV] rf__n_estimators=55, rf__max_features=7 .........................
# [CV]  rf__n_estimators=55, rf__max_features=7, score=0.989, total=  29.9s
# [CV] rf__n_estimators=190, rf__max_features=13 .......................
# [CV]  rf__n_estimators=190, rf__max_features=13, score=0.991, total=  48.4s
# [CV] rf__n_estimators=120, rf__max_features=7 ........................
# [CV]  rf__n_estimators=120, rf__max_features=7, score=0.991, total=  33.9s
# [CV] rf__n_estimators=175, rf__max_features=17 .......................
# [CV]  rf__n_estimators=175, rf__max_features=17, score=0.990, total=  52.7s
# [CV] rf__n_estimators=420, rf__max_features=17 .......................
# [CV]  rf__n_estimators=420, rf__max_features=17, score=0.990, total= 1.5min
# [CV] rf__n_estimators=490, rf__max_features=6 ........................
# [CV]  rf__n_estimators=490, rf__max_features=6, score=0.991, total=  54.3s
# [CV] rf__n_estimators=225, rf__max_features=9 ........................
# [CV]  rf__n_estimators=225, rf__max_features=9, score=0.990, total=  44.7s
# [CV] rf__n_estimators=255, rf__max_features=4 ........................
# [CV]  rf__n_estimators=255, rf__max_features=4, score=0.991, total=  36.6s
# [CV] rf__n_estimators=205, rf__max_features=None .....................
# [CV]  rf__n_estimators=205, rf__max_features=None, score=0.986, total= 1.4min
# [CV] rf__n_estimators=415, rf__max_features=8 ........................
# [CV]  rf__n_estimators=415, rf__max_features=8, score=0.991, total=  56.2s
# [CV] rf__n_estimators=330, rf__max_features=16 .......................
# [CV]  rf__n_estimators=330, rf__max_features=16, score=0.991, total= 1.2min
# [CV] rf__n_estimators=255, rf__max_features=7 ........................
# [CV]  rf__n_estimators=255, rf__max_features=7, score=0.991, total=  41.2s
# [CV] rf__n_estimators=280, rf__max_features=1 ........................
# [CV]  rf__n_estimators=280, rf__max_features=1, score=0.986, total=  29.4s
# [CV] rf__n_estimators=190, rf__max_features=6 ........................
# [CV]  rf__n_estimators=190, rf__max_features=6, score=0.991, total=  35.9s
# [CV] rf__n_estimators=490, rf__max_features=12 .......................
# [CV]  rf__n_estimators=490, rf__max_features=12, score=0.991, total= 1.2min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 18.8min finished
# {'rf__n_estimators': 415, 'rf__max_features': 8}
# [0.5473180076628352, 0.550858782302801]
# [[ 952    0    0    0]
#  [   0   29    0 1871]
#  [   2   50 1631  211]
#  [   0  798 1794 3102]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV] ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=16
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Model: "sequential_168"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_298 (Conv1D)          (None, 497, 128)          2176
# _________________________________________________________________
# max_pooling1d_298 (MaxPoolin (None, 62, 128)           0
# _________________________________________________________________
# flatten_168 (Flatten)        (None, 7936)              0
# _________________________________________________________________
# dense_168 (Dense)            (None, 4)                 31748
# =================================================================
# Total params: 33,924
# Trainable params: 33,924
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=16, score=0.987, total= 1.3min
# [CV] ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=32
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.3min remaining:    0.0s
# Model: "sequential_169"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_299 (Conv1D)          (None, 481, 64)           2112
# _________________________________________________________________
# max_pooling1d_299 (MaxPoolin (None, 240, 64)           0
# _________________________________________________________________
# conv1d_300 (Conv1D)          (None, 209, 64)           131136
# _________________________________________________________________
# max_pooling1d_300 (MaxPoolin (None, 104, 64)           0
# _________________________________________________________________
# conv1d_301 (Conv1D)          (None, 73, 64)            131136
# _________________________________________________________________
# max_pooling1d_301 (MaxPoolin (None, 36, 64)            0
# _________________________________________________________________
# conv1d_302 (Conv1D)          (None, 5, 64)             131136
# _________________________________________________________________
# max_pooling1d_302 (MaxPoolin (None, 2, 64)             0
# _________________________________________________________________
# flatten_169 (Flatten)        (None, 128)               0
# _________________________________________________________________
# dense_169 (Dense)            (None, 4)                 516
# =================================================================
# Total params: 396,036
# Trainable params: 396,036
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=32, score=0.993, total= 1.5min
# [CV] ann__pooling=8, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=32
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  2.9min remaining:    0.0s
# Model: "sequential_170"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_303 (Conv1D)          (None, 481, 64)           2112
# _________________________________________________________________
# max_pooling1d_303 (MaxPoolin (None, 60, 64)            0
# _________________________________________________________________
# flatten_170 (Flatten)        (None, 3840)              0
# _________________________________________________________________
# dense_170 (Dense)            (None, 4)                 15364
# =================================================================
# Total params: 17,476
# Trainable params: 17,476
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=32, score=0.996, total= 1.3min
# [CV] ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=64
# Model: "sequential_171"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_304 (Conv1D)          (None, 449, 96)           6240
# _________________________________________________________________
# max_pooling1d_304 (MaxPoolin (None, 224, 96)           0
# _________________________________________________________________
# conv1d_305 (Conv1D)          (None, 161, 96)           589920
# _________________________________________________________________
# max_pooling1d_305 (MaxPoolin (None, 80, 96)            0
# _________________________________________________________________
# conv1d_306 (Conv1D)          (None, 17, 96)            589920
# _________________________________________________________________
# max_pooling1d_306 (MaxPoolin (None, 8, 96)             0
# _________________________________________________________________
# flatten_171 (Flatten)        (None, 768)               0
# _________________________________________________________________
# dense_171 (Dense)            (None, 4)                 3076
# =================================================================
# Total params: 1,189,156
# Trainable params: 1,189,156
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=64, score=0.985, total= 1.3min
# [CV] ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=64
# Model: "sequential_172"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_307 (Conv1D)          (None, 449, 128)          8320
# _________________________________________________________________
# max_pooling1d_307 (MaxPoolin (None, 224, 128)          0
# _________________________________________________________________
# conv1d_308 (Conv1D)          (None, 161, 128)          1048704
# _________________________________________________________________
# max_pooling1d_308 (MaxPoolin (None, 80, 128)           0
# _________________________________________________________________
# conv1d_309 (Conv1D)          (None, 17, 128)           1048704
# _________________________________________________________________
# max_pooling1d_309 (MaxPoolin (None, 8, 128)            0
# _________________________________________________________________
# flatten_172 (Flatten)        (None, 1024)              0
# _________________________________________________________________
# dense_172 (Dense)            (None, 4)                 4100
# =================================================================
# Total params: 2,109,828
# Trainable params: 2,109,828
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=64, score=0.828, total= 1.5min
# [CV] ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=64
# Model: "sequential_173"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_310 (Conv1D)          (None, 449, 128)          8320
# _________________________________________________________________
# max_pooling1d_310 (MaxPoolin (None, 224, 128)          0
# _________________________________________________________________
# conv1d_311 (Conv1D)          (None, 161, 128)          1048704
# _________________________________________________________________
# max_pooling1d_311 (MaxPoolin (None, 80, 128)           0
# _________________________________________________________________
# conv1d_312 (Conv1D)          (None, 17, 128)           1048704
# _________________________________________________________________
# max_pooling1d_312 (MaxPoolin (None, 8, 128)            0
# _________________________________________________________________
# flatten_173 (Flatten)        (None, 1024)              0
# _________________________________________________________________
# dense_173 (Dense)            (None, 4)                 4100
# =================================================================
# Total params: 2,109,828
# Trainable params: 2,109,828
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=64, score=0.948, total=  57.9s
# [CV] ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=64
# Model: "sequential_174"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_313 (Conv1D)          (None, 449, 64)           4160
# _________________________________________________________________
# max_pooling1d_313 (MaxPoolin (None, 224, 64)           0
# _________________________________________________________________
# conv1d_314 (Conv1D)          (None, 161, 64)           262208
# _________________________________________________________________
# max_pooling1d_314 (MaxPoolin (None, 80, 64)            0
# _________________________________________________________________
# conv1d_315 (Conv1D)          (None, 17, 64)            262208
# _________________________________________________________________
# max_pooling1d_315 (MaxPoolin (None, 8, 64)             0
# _________________________________________________________________
# flatten_174 (Flatten)        (None, 512)               0
# _________________________________________________________________
# dense_174 (Dense)            (None, 4)                 2052
# =================================================================
# Total params: 530,628
# Trainable params: 530,628
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=64, ann__kernel_size=64, score=0.970, total=  51.5s
# [CV] ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=16
# Model: "sequential_175"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_316 (Conv1D)          (None, 497, 64)           1088
# _________________________________________________________________
# max_pooling1d_316 (MaxPoolin (None, 124, 64)           0
# _________________________________________________________________
# conv1d_317 (Conv1D)          (None, 109, 64)           65600
# _________________________________________________________________
# max_pooling1d_317 (MaxPoolin (None, 27, 64)            0
# _________________________________________________________________
# flatten_175 (Flatten)        (None, 1728)              0
# _________________________________________________________________
# dense_175 (Dense)            (None, 4)                 6916
# =================================================================
# Total params: 73,604
# Trainable params: 73,604
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=16, score=0.997, total= 1.0min
# [CV] ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=16
# Model: "sequential_176"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_318 (Conv1D)          (None, 497, 128)          2176
# _________________________________________________________________
# max_pooling1d_318 (MaxPoolin (None, 62, 128)           0
# _________________________________________________________________
# flatten_176 (Flatten)        (None, 7936)              0
# _________________________________________________________________
# dense_176 (Dense)            (None, 4)                 31748
# =================================================================
# Total params: 33,924
# Trainable params: 33,924
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=16, score=0.995, total= 1.5min
# [CV] ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=48
# Model: "sequential_177"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_319 (Conv1D)          (None, 465, 128)          6272
# _________________________________________________________________
# max_pooling1d_319 (MaxPoolin (None, 232, 128)          0
# _________________________________________________________________
# conv1d_320 (Conv1D)          (None, 185, 128)          786560
# _________________________________________________________________
# max_pooling1d_320 (MaxPoolin (None, 92, 128)           0
# _________________________________________________________________
# conv1d_321 (Conv1D)          (None, 45, 128)           786560
# _________________________________________________________________
# max_pooling1d_321 (MaxPoolin (None, 22, 128)           0
# _________________________________________________________________
# flatten_177 (Flatten)        (None, 2816)              0
# _________________________________________________________________
# dense_177 (Dense)            (None, 4)                 11268
# =================================================================
# Total params: 1,590,660
# Trainable params: 1,590,660
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=48, score=0.964, total= 1.0min
# [CV] ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=32
# Model: "sequential_178"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_322 (Conv1D)          (None, 481, 96)           3168
# _________________________________________________________________
# max_pooling1d_322 (MaxPoolin (None, 120, 96)           0
# _________________________________________________________________
# conv1d_323 (Conv1D)          (None, 89, 96)            295008
# _________________________________________________________________
# max_pooling1d_323 (MaxPoolin (None, 22, 96)            0
# _________________________________________________________________
# flatten_178 (Flatten)        (None, 2112)              0
# _________________________________________________________________
# dense_178 (Dense)            (None, 4)                 8452
# =================================================================
# Total params: 306,628
# Trainable params: 306,628
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=32, score=0.998, total= 1.4min
# [CV] ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=64
# Model: "sequential_179"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_324 (Conv1D)          (None, 449, 128)          8320
# _________________________________________________________________
# max_pooling1d_324 (MaxPoolin (None, 112, 128)          0
# _________________________________________________________________
# flatten_179 (Flatten)        (None, 14336)             0
# _________________________________________________________________
# dense_179 (Dense)            (None, 4)                 57348
# =================================================================
# Total params: 65,668
# Trainable params: 65,668
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=64, score=0.993, total= 1.1min
# [CV] ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=16
# Model: "sequential_180"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_325 (Conv1D)          (None, 497, 96)           1632
# _________________________________________________________________
# max_pooling1d_325 (MaxPoolin (None, 124, 96)           0
# _________________________________________________________________
# conv1d_326 (Conv1D)          (None, 109, 96)           147552
# _________________________________________________________________
# max_pooling1d_326 (MaxPoolin (None, 27, 96)            0
# _________________________________________________________________
# flatten_180 (Flatten)        (None, 2592)              0
# _________________________________________________________________
# dense_180 (Dense)            (None, 4)                 10372
# =================================================================
# Total params: 159,556
# Trainable params: 159,556
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=16, score=0.998, total= 1.5min
# [CV] ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=64
# Model: "sequential_181"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_327 (Conv1D)          (None, 449, 96)           6240
# _________________________________________________________________
# max_pooling1d_327 (MaxPoolin (None, 74, 96)            0
# _________________________________________________________________
# flatten_181 (Flatten)        (None, 7104)              0
# _________________________________________________________________
# dense_181 (Dense)            (None, 4)                 28420
# =================================================================
# Total params: 34,660
# Trainable params: 34,660
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=64, score=0.999, total= 1.5min
# [CV] ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=16
# Model: "sequential_182"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_328 (Conv1D)          (None, 497, 32)           544
# _________________________________________________________________
# max_pooling1d_328 (MaxPoolin (None, 124, 32)           0
# _________________________________________________________________
# conv1d_329 (Conv1D)          (None, 109, 32)           16416
# _________________________________________________________________
# max_pooling1d_329 (MaxPoolin (None, 27, 32)            0
# _________________________________________________________________
# flatten_182 (Flatten)        (None, 864)               0
# _________________________________________________________________
# dense_182 (Dense)            (None, 4)                 3460
# =================================================================
# Total params: 20,420
# Trainable params: 20,420
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=16, score=0.999, total= 1.4min
# [CV] ann__pooling=4, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=64
# Model: "sequential_183"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_330 (Conv1D)          (None, 449, 32)           2080
# _________________________________________________________________
# max_pooling1d_330 (MaxPoolin (None, 112, 32)           0
# _________________________________________________________________
# flatten_183 (Flatten)        (None, 3584)              0
# _________________________________________________________________
# dense_183 (Dense)            (None, 4)                 14340
# =================================================================
# Total params: 16,420
# Trainable params: 16,420
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=64, score=0.997, total= 1.3min
# [CV] ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=32
# Model: "sequential_184"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_331 (Conv1D)          (None, 481, 128)          4224
# _________________________________________________________________
# max_pooling1d_331 (MaxPoolin (None, 80, 128)           0
# _________________________________________________________________
# flatten_184 (Flatten)        (None, 10240)             0
# _________________________________________________________________
# dense_184 (Dense)            (None, 4)                 40964
# =================================================================
# Total params: 45,188
# Trainable params: 45,188
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=32, score=0.996, total= 1.3min
# [CV] ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=32
# Model: "sequential_185"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_332 (Conv1D)          (None, 481, 32)           1056
# _________________________________________________________________
# max_pooling1d_332 (MaxPoolin (None, 120, 32)           0
# _________________________________________________________________
# conv1d_333 (Conv1D)          (None, 89, 32)            32800
# _________________________________________________________________
# max_pooling1d_333 (MaxPoolin (None, 22, 32)            0
# _________________________________________________________________
# flatten_185 (Flatten)        (None, 704)               0
# _________________________________________________________________
# dense_185 (Dense)            (None, 4)                 2820
# =================================================================
# Total params: 36,676
# Trainable params: 36,676
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=32, score=0.983, total= 1.0min
# [CV] ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=32, ann__kernel_size=16
# Model: "sequential_186"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_334 (Conv1D)          (None, 497, 32)           544
# _________________________________________________________________
# max_pooling1d_334 (MaxPoolin (None, 124, 32)           0
# _________________________________________________________________
# conv1d_335 (Conv1D)          (None, 109, 32)           16416
# _________________________________________________________________
# max_pooling1d_335 (MaxPoolin (None, 27, 32)            0
# _________________________________________________________________
# flatten_186 (Flatten)        (None, 864)               0
# _________________________________________________________________
# dense_186 (Dense)            (None, 4)                 3460
# =================================================================
# Total params: 20,420
# Trainable params: 20,420
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=32, ann__kernel_size=16, score=0.997, total= 1.3min
# [CV] ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=32
# Model: "sequential_187"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_336 (Conv1D)          (None, 481, 128)          4224
# _________________________________________________________________
# max_pooling1d_336 (MaxPoolin (None, 120, 128)          0
# _________________________________________________________________
# conv1d_337 (Conv1D)          (None, 89, 128)           524416
# _________________________________________________________________
# max_pooling1d_337 (MaxPoolin (None, 22, 128)           0
# _________________________________________________________________
# flatten_187 (Flatten)        (None, 2816)              0
# _________________________________________________________________
# dense_187 (Dense)            (None, 4)                 11268
# =================================================================
# Total params: 539,908
# Trainable params: 539,908
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=32, score=0.996, total= 1.2min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 25.2min finished
# Model: "sequential_188"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_338 (Conv1D)          (None, 497, 32)           544
# _________________________________________________________________
# max_pooling1d_338 (MaxPoolin (None, 124, 32)           0
# _________________________________________________________________
# conv1d_339 (Conv1D)          (None, 109, 32)           16416
# _________________________________________________________________
# max_pooling1d_339 (MaxPoolin (None, 27, 32)            0
# _________________________________________________________________
# flatten_188 (Flatten)        (None, 864)               0
# _________________________________________________________________
# dense_188 (Dense)            (None, 4)                 3460
# =================================================================
# Total params: 20,420
# Trainable params: 20,420
# Non-trainable params: 0
# _________________________________________________________________
# None
# {'ann__pooling': 4, 'ann__n_hidden_layers': 3, 'ann__n_filters': 32, 'ann__kernel_size': 16}
# [0.6394636015325671, 0.68801767695693]
# [[ 952    0    0    0]
#  [   0  738    0 1162]
#  [   6  175 1410  303]
#  [   0 1732  386 3576]]
# Confusion matrix, without normalization
# 014 x 1/1
# K-NNeighbors:	[0.4732599795291709, 0.4253133750548309]
# [[1890    0    0    0]
#  [   6   31  165 1693]
#  [ 176  231  414 1079]
#  [   0  364  403 1364]]
# Confusion matrix, without normalization
# RandomForest:	Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV] rf__n_estimators=160, rf__max_features=1 ........................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  rf__n_estimators=160, rf__max_features=1, score=0.983, total=  31.8s
# [CV] rf__n_estimators=175, rf__max_features=12 .......................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   31.8s remaining:    0.0s
# [CV]  rf__n_estimators=175, rf__max_features=12, score=0.989, total=  51.6s
# [CV] rf__n_estimators=430, rf__max_features=8 ........................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.4min remaining:    0.0s
# [CV]  rf__n_estimators=430, rf__max_features=8, score=0.991, total= 1.1min
# [CV] rf__n_estimators=65, rf__max_features=None ......................
# [CV]  rf__n_estimators=65, rf__max_features=None, score=0.984, total=  50.4s
# [CV] rf__n_estimators=215, rf__max_features=1 ........................
# [CV]  rf__n_estimators=215, rf__max_features=1, score=0.983, total=  32.6s
# [CV] rf__n_estimators=465, rf__max_features=12 .......................
# [CV]  rf__n_estimators=465, rf__max_features=12, score=0.989, total= 1.5min
# [CV] rf__n_estimators=405, rf__max_features=8 ........................
# [CV]  rf__n_estimators=405, rf__max_features=8, score=0.990, total= 1.1min
# [CV] rf__n_estimators=400, rf__max_features=7 ........................
# [CV]  rf__n_estimators=400, rf__max_features=7, score=0.990, total=  59.1s
# [CV] rf__n_estimators=30, rf__max_features=14 ........................
# [CV]  rf__n_estimators=30, rf__max_features=14, score=0.989, total=  33.9s
# [CV] rf__n_estimators=340, rf__max_features=1 ........................
# [CV]  rf__n_estimators=340, rf__max_features=1, score=0.983, total=  33.9s
# [CV] rf__n_estimators=270, rf__max_features=12 .......................
# [CV]  rf__n_estimators=270, rf__max_features=12, score=0.989, total= 1.1min
# [CV] rf__n_estimators=265, rf__max_features=17 .......................
# [CV]  rf__n_estimators=265, rf__max_features=17, score=0.988, total= 1.3min
# [CV] rf__n_estimators=140, rf__max_features=14 .......................
# [CV]  rf__n_estimators=140, rf__max_features=14, score=0.988, total=  50.8s
# [CV] rf__n_estimators=180, rf__max_features=6 ........................
# [CV]  rf__n_estimators=180, rf__max_features=6, score=0.989, total=  40.4s
# [CV] rf__n_estimators=40, rf__max_features=19 ........................
# [CV]  rf__n_estimators=40, rf__max_features=19, score=0.987, total=  37.1s
# [CV] rf__n_estimators=285, rf__max_features=2 ........................
# [CV]  rf__n_estimators=285, rf__max_features=2, score=0.987, total=  35.9s
# [CV] rf__n_estimators=120, rf__max_features=2 ........................
# [CV]  rf__n_estimators=120, rf__max_features=2, score=0.986, total=  32.5s
# [CV] rf__n_estimators=85, rf__max_features=16 ........................
# [CV]  rf__n_estimators=85, rf__max_features=16, score=0.988, total=  43.7s
# [CV] rf__n_estimators=415, rf__max_features=10 .......................
# [CV]  rf__n_estimators=415, rf__max_features=10, score=0.989, total= 1.2min
# [CV] rf__n_estimators=355, rf__max_features=14 .......................
# [CV]  rf__n_estimators=355, rf__max_features=14, score=0.988, total= 1.4min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 17.6min finished
# {'rf__n_estimators': 430, 'rf__max_features': 8}
# [0.5446519959058342, 0.51309578233757]
# [[1890    0    0    0]
#  [   0   27  164 1704]
#  [   0  232 1216  452]
#  [   0  334  673 1124]]
# Confusion matrix, without normalization
# ANN-Conv1d:	Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV] ann__pooling=6, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=64
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Model: "sequential_189"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_340 (Conv1D)          (None, 449, 32)           2080
# _________________________________________________________________
# max_pooling1d_340 (MaxPoolin (None, 74, 32)            0
# _________________________________________________________________
# flatten_189 (Flatten)        (None, 2368)              0
# _________________________________________________________________
# dense_189 (Dense)            (None, 4)                 9476
# =================================================================
# Total params: 11,556
# Trainable params: 11,556
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=64, score=0.946, total= 1.5min
# [CV] ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=64, ann__kernel_size=64
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.5min remaining:    0.0s
# Model: "sequential_190"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_341 (Conv1D)          (None, 449, 64)           4160
# _________________________________________________________________
# max_pooling1d_341 (MaxPoolin (None, 112, 64)           0
# _________________________________________________________________
# flatten_190 (Flatten)        (None, 7168)              0
# _________________________________________________________________
# dense_190 (Dense)            (None, 4)                 28676
# =================================================================
# Total params: 32,836
# Trainable params: 32,836
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=64, ann__kernel_size=64, score=0.947, total= 1.2min
# [CV] ann__pooling=6, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=32
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  2.7min remaining:    0.0s
# Model: "sequential_191"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_342 (Conv1D)          (None, 481, 32)           1056
# _________________________________________________________________
# max_pooling1d_342 (MaxPoolin (None, 80, 32)            0
# _________________________________________________________________
# flatten_191 (Flatten)        (None, 2560)              0
# _________________________________________________________________
# dense_191 (Dense)            (None, 4)                 10244
# =================================================================
# Total params: 11,300
# Trainable params: 11,300
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=5, ann__n_filters=32, ann__kernel_size=32, score=0.940, total= 1.3min
# [CV] ann__pooling=6, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=48
# Model: "sequential_192"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_343 (Conv1D)          (None, 465, 96)           4704
# _________________________________________________________________
# max_pooling1d_343 (MaxPoolin (None, 77, 96)            0
# _________________________________________________________________
# flatten_192 (Flatten)        (None, 7392)              0
# _________________________________________________________________
# dense_192 (Dense)            (None, 4)                 29572
# =================================================================
# Total params: 34,276
# Trainable params: 34,276
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=48, score=0.945, total= 1.5min
# [CV] ann__pooling=6, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=64
# Model: "sequential_193"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_344 (Conv1D)          (None, 449, 128)          8320
# _________________________________________________________________
# max_pooling1d_344 (MaxPoolin (None, 74, 128)           0
# _________________________________________________________________
# flatten_193 (Flatten)        (None, 9472)              0
# _________________________________________________________________
# dense_193 (Dense)            (None, 4)                 37892
# =================================================================
# Total params: 46,212
# Trainable params: 46,212
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=64, score=0.946, total= 1.3min
# [CV] ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=16
# Model: "sequential_194"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_345 (Conv1D)          (None, 497, 64)           1088
# _________________________________________________________________
# max_pooling1d_345 (MaxPoolin (None, 124, 64)           0
# _________________________________________________________________
# conv1d_346 (Conv1D)          (None, 109, 64)           65600
# _________________________________________________________________
# max_pooling1d_346 (MaxPoolin (None, 27, 64)            0
# _________________________________________________________________
# flatten_194 (Flatten)        (None, 1728)              0
# _________________________________________________________________
# dense_194 (Dense)            (None, 4)                 6916
# =================================================================
# Total params: 73,604
# Trainable params: 73,604
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=16, score=0.999, total= 1.5min
# [CV] ann__pooling=2, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=48
# Model: "sequential_195"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_347 (Conv1D)          (None, 465, 64)           3136
# _________________________________________________________________
# max_pooling1d_347 (MaxPoolin (None, 232, 64)           0
# _________________________________________________________________
# conv1d_348 (Conv1D)          (None, 185, 64)           196672
# _________________________________________________________________
# max_pooling1d_348 (MaxPoolin (None, 92, 64)            0
# _________________________________________________________________
# conv1d_349 (Conv1D)          (None, 45, 64)            196672
# _________________________________________________________________
# max_pooling1d_349 (MaxPoolin (None, 22, 64)            0
# _________________________________________________________________
# flatten_195 (Flatten)        (None, 1408)              0
# _________________________________________________________________
# dense_195 (Dense)            (None, 4)                 5636
# =================================================================
# Total params: 402,116
# Trainable params: 402,116
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=48, score=0.996, total= 1.4min
# [CV] ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=32
# Model: "sequential_196"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_350 (Conv1D)          (None, 481, 128)          4224
# _________________________________________________________________
# max_pooling1d_350 (MaxPoolin (None, 240, 128)          0
# _________________________________________________________________
# conv1d_351 (Conv1D)          (None, 209, 128)          524416
# _________________________________________________________________
# max_pooling1d_351 (MaxPoolin (None, 104, 128)          0
# _________________________________________________________________
# conv1d_352 (Conv1D)          (None, 73, 128)           524416
# _________________________________________________________________
# max_pooling1d_352 (MaxPoolin (None, 36, 128)           0
# _________________________________________________________________
# conv1d_353 (Conv1D)          (None, 5, 128)            524416
# _________________________________________________________________
# max_pooling1d_353 (MaxPoolin (None, 2, 128)            0
# _________________________________________________________________
# flatten_196 (Flatten)        (None, 256)               0
# _________________________________________________________________
# dense_196 (Dense)            (None, 4)                 1028
# =================================================================
# Total params: 1,578,500
# Trainable params: 1,578,500
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=32, score=0.976, total= 1.4min
# [CV] ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=64
# Model: "sequential_197"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_354 (Conv1D)          (None, 449, 128)          8320
# _________________________________________________________________
# max_pooling1d_354 (MaxPoolin (None, 112, 128)          0
# _________________________________________________________________
# flatten_197 (Flatten)        (None, 14336)             0
# _________________________________________________________________
# dense_197 (Dense)            (None, 4)                 57348
# =================================================================
# Total params: 65,668
# Trainable params: 65,668
# Non-trainable params: 0
# _________________________________________________________________
# None
# ...
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_436 (Conv1D)          (None, 481, 96)           3168
# _________________________________________________________________
# max_pooling1d_436 (MaxPoolin (None, 240, 96)           0
# _________________________________________________________________
# conv1d_437 (Conv1D)          (None, 209, 96)           295008
# _________________________________________________________________
# max_pooling1d_437 (MaxPoolin (None, 104, 96)           0
# _________________________________________________________________
# conv1d_438 (Conv1D)          (None, 73, 96)            295008
# _________________________________________________________________
# max_pooling1d_438 (MaxPoolin (None, 36, 96)            0
# _________________________________________________________________
# conv1d_439 (Conv1D)          (None, 5, 96)             295008
# _________________________________________________________________
# max_pooling1d_439 (MaxPoolin (None, 2, 96)             0
# _________________________________________________________________
# flatten_240 (Flatten)        (None, 192)               0
# _________________________________________________________________
# dense_240 (Dense)            (None, 4)                 772
# =================================================================
# Total params: 888,964
# Trainable params: 888,964
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=32, score=0.975, total= 1.6min
# [CV] ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=16
# Model: "sequential_241"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_440 (Conv1D)          (None, 497, 64)           1088
# _________________________________________________________________
# max_pooling1d_440 (MaxPoolin (None, 62, 64)            0
# _________________________________________________________________
# flatten_241 (Flatten)        (None, 3968)              0
# _________________________________________________________________
# dense_241 (Dense)            (None, 4)                 15876
# =================================================================
# Total params: 16,964
# Trainable params: 16,964
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=64, ann__kernel_size=16, score=0.984, total= 3.1min
# [CV] ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=16
# Model: "sequential_242"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_441 (Conv1D)          (None, 497, 128)          2176
# _________________________________________________________________
# max_pooling1d_441 (MaxPoolin (None, 124, 128)          0
# _________________________________________________________________
# conv1d_442 (Conv1D)          (None, 109, 128)          262272
# _________________________________________________________________
# max_pooling1d_442 (MaxPoolin (None, 27, 128)           0
# _________________________________________________________________
# flatten_242 (Flatten)        (None, 3456)              0
# _________________________________________________________________
# dense_242 (Dense)            (None, 4)                 13828
# =================================================================
# Total params: 278,276
# Trainable params: 278,276
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=128, ann__kernel_size=16, score=0.998, total= 2.0min
# [CV] ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=32
# Model: "sequential_243"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_443 (Conv1D)          (None, 481, 128)          4224
# _________________________________________________________________
# max_pooling1d_443 (MaxPoolin (None, 240, 128)          0
# _________________________________________________________________
# conv1d_444 (Conv1D)          (None, 209, 128)          524416
# _________________________________________________________________
# max_pooling1d_444 (MaxPoolin (None, 104, 128)          0
# _________________________________________________________________
# conv1d_445 (Conv1D)          (None, 73, 128)           524416
# _________________________________________________________________
# max_pooling1d_445 (MaxPoolin (None, 36, 128)           0
# _________________________________________________________________
# conv1d_446 (Conv1D)          (None, 5, 128)            524416
# _________________________________________________________________
# max_pooling1d_446 (MaxPoolin (None, 2, 128)            0
# _________________________________________________________________
# flatten_243 (Flatten)        (None, 256)               0
# _________________________________________________________________
# dense_243 (Dense)            (None, 4)                 1028
# =================================================================
# Total params: 1,578,500
# Trainable params: 1,578,500
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=2, ann__n_hidden_layers=5, ann__n_filters=128, ann__kernel_size=32, score=0.985, total= 2.4min
# [CV] ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=48
# Model: "sequential_244"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_447 (Conv1D)          (None, 465, 32)           1568
# _________________________________________________________________
# max_pooling1d_447 (MaxPoolin (None, 58, 32)            0
# _________________________________________________________________
# flatten_244 (Flatten)        (None, 1856)              0
# _________________________________________________________________
# dense_244 (Dense)            (None, 4)                 7428
# =================================================================
# Total params: 8,996
# Trainable params: 8,996
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=48, score=0.984, total= 2.4min
# [CV] ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=32
# Model: "sequential_245"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_448 (Conv1D)          (None, 481, 32)           1056
# _________________________________________________________________
# max_pooling1d_448 (MaxPoolin (None, 60, 32)            0
# _________________________________________________________________
# flatten_245 (Flatten)        (None, 1920)              0
# _________________________________________________________________
# dense_245 (Dense)            (None, 4)                 7684
# =================================================================
# Total params: 8,740
# Trainable params: 8,740
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=32, score=0.988, total= 2.8min
# [CV] ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=64
# Model: "sequential_246"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_449 (Conv1D)          (None, 449, 128)          8320
# _________________________________________________________________
# max_pooling1d_449 (MaxPoolin (None, 56, 128)           0
# _________________________________________________________________
# flatten_246 (Flatten)        (None, 7168)              0
# _________________________________________________________________
# dense_246 (Dense)            (None, 4)                 28676
# =================================================================
# Total params: 36,996
# Trainable params: 36,996
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=3, ann__n_filters=128, ann__kernel_size=64, score=0.989, total= 1.5min
# [CV] ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=16
# Model: "sequential_247"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_450 (Conv1D)          (None, 497, 96)           1632
# _________________________________________________________________
# max_pooling1d_450 (MaxPoolin (None, 124, 96)           0
# _________________________________________________________________
# conv1d_451 (Conv1D)          (None, 109, 96)           147552
# _________________________________________________________________
# max_pooling1d_451 (MaxPoolin (None, 27, 96)            0
# _________________________________________________________________
# flatten_247 (Flatten)        (None, 2592)              0
# _________________________________________________________________
# dense_247 (Dense)            (None, 4)                 10372
# =================================================================
# Total params: 159,556
# Trainable params: 159,556
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=4, ann__n_hidden_layers=4, ann__n_filters=96, ann__kernel_size=16, score=0.998, total= 2.7min
# [CV] ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=16
# Model: "sequential_248"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_452 (Conv1D)          (None, 497, 32)           544
# _________________________________________________________________
# max_pooling1d_452 (MaxPoolin (None, 82, 32)            0
# _________________________________________________________________
# flatten_248 (Flatten)        (None, 2624)              0
# _________________________________________________________________
# dense_248 (Dense)            (None, 4)                 10500
# =================================================================
# Total params: 11,044
# Trainable params: 11,044
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=32, ann__kernel_size=16, score=0.979, total= 3.1min
# [CV] ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=32
# Model: "sequential_249"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_453 (Conv1D)          (None, 481, 96)           3168
# _________________________________________________________________
# max_pooling1d_453 (MaxPoolin (None, 80, 96)            0
# _________________________________________________________________
# flatten_249 (Flatten)        (None, 7680)              0
# _________________________________________________________________
# dense_249 (Dense)            (None, 4)                 30724
# =================================================================
# Total params: 33,892
# Trainable params: 33,892
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=6, ann__n_hidden_layers=3, ann__n_filters=96, ann__kernel_size=32, score=0.977, total= 1.5min
# [CV] ann__pooling=8, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=16
# Model: "sequential_250"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_454 (Conv1D)          (None, 497, 96)           1632
# _________________________________________________________________
# max_pooling1d_454 (MaxPoolin (None, 62, 96)            0
# _________________________________________________________________
# flatten_250 (Flatten)        (None, 5952)              0
# _________________________________________________________________
# dense_250 (Dense)            (None, 4)                 23812
# =================================================================
# Total params: 25,444
# Trainable params: 25,444
# Non-trainable params: 0
# _________________________________________________________________
# None
# [CV]  ann__pooling=8, ann__n_hidden_layers=5, ann__n_filters=96, ann__kernel_size=16, score=0.972, total= 2.6min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 46.5min finished
# Model: "sequential_251"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_455 (Conv1D)          (None, 481, 32)           1056
# _________________________________________________________________
# max_pooling1d_455 (MaxPoolin (None, 120, 32)           0
# _________________________________________________________________
# conv1d_456 (Conv1D)          (None, 89, 32)            32800
# _________________________________________________________________
# max_pooling1d_456 (MaxPoolin (None, 22, 32)            0
# _________________________________________________________________
# flatten_251 (Flatten)        (None, 704)               0
# _________________________________________________________________
# dense_251 (Dense)            (None, 4)                 2820
# =================================================================
# Total params: 36,676
# Trainable params: 36,676
# Non-trainable params: 0
# _________________________________________________________________
# None
# {'ann__pooling': 4, 'ann__n_hidden_layers': 4, 'ann__n_filters': 32, 'ann__kernel_size': 32}
# [0.5932382461701003, 0.38503086419753085]
# [[1896    0    0    0]
#  [   0    0    2  944]
#  [   0    1  350  593]
#  [   0    0    0    0]]
# Confusion matrix, without normalization
# [0.5253957679007646, 0.5281119561946942]
# [[6627    0    1    0]
#  [   6 1225  693 4711]
#  [ 189  392 3064 2990]
#  [   3 2927 3048 5645]]
# Confusion matrix, without normalization
# [0.5442403477047048, 0.5192083494881136]
# [[6628    0    0    0]
#  [   0   58  261 6316]
#  [   2  289 3949 2395]
#  [   0 2305 2798 6520]]
# Confusion matrix, without normalization
# [0.5604517623171854, 0.5693676087993637]
# [[6628    0    0    0]
#  [   0  743  593 5299]
#  [  31  778 4494 1332]
#  [  21 4301 1500 5801]]
# Confusion matrix, without normalization

# %% [markdown]
# #Results Summary
# Comparison of the evaluation methods.

# %%
for evaluation in results.keys():
  print("\n"+30*"#"+"\n"+evaluation+"\n"+30*"#")
  for clfname,model in clfs:
    print("\n\t"+clfname+" Results\nFold\tAccuracy\tF1-Score")
    for i,r in enumerate(results[evaluation][clfname]):
      print("{}\t".format(i+1),end="")
      print(r)
    print("Average\tAccuracy\tF1-Score\n\t",end="")
    print(np.mean(results[evaluation][clfname],axis=0))
    print("StdDev\tAccuracy\tF1-Score\n\t",end="")
    print(np.std(results[evaluation][clfname],axis=0))
# Out:
# ##############################
# kfold
# ##############################
#
# 	K-NNeighbors Results
# Fold	Accuracy	F1-Score
# 1	[0.9748762847354396, 0.9743713107647791]
# 2	[0.974114960030453, 0.9734238897988385]
# 3	[0.9725923106204797, 0.9721665807170512]
# 4	[0.9724549378014724, 0.9716548414970871]
# Average	Accuracy	F1-Score
# 	[0.97350962 0.97290416]
# StdDev	Accuracy	F1-Score
# 	[0.00102323 0.00106389]
#
# 	RandomForest Results
# Fold	Accuracy	F1-Score
# 1	[0.988833904326862, 0.9889054010370315]
# 2	[0.9893414541301865, 0.9895279721254784]
# 3	[0.9879456921710443, 0.9881562161384733]
# 4	[0.9864178725564864, 0.9865917505980597]
# Average	Accuracy	F1-Score
# 	[0.98813473 0.98829533]
# StdDev	Accuracy	F1-Score
# 	[0.00111    0.00109694]
#
# 	ANN-Conv1d Results
# Fold	Accuracy	F1-Score
# 1	[0.9212028930338789, 0.9253492601711285]
# 2	[0.8946834158101764, 0.8971026926194251]
# 3	[0.899885801294252, 0.905250927091249]
# 4	[0.9049251078954049, 0.910282067732463]
# Average	Accuracy	F1-Score
# 	[0.9051743  0.90949624]
# StdDev	Accuracy	F1-Score
# 	[0.00993736 0.01029027]
#
# ##############################
# byload
# ##############################
#
# 	K-NNeighbors Results
# Fold	Accuracy	F1-Score
# 1	[0.9417528579205225, 0.9472559383101014]
# 2	[0.9611373230692823, 0.9596461704079974]
# 3	[0.9430238331678252, 0.9417543023485089]
# 4	[0.9412129480342304, 0.9392638193958291]
# Average	Accuracy	F1-Score
# 	[0.94678174 0.94698006]
# StdDev	Accuracy	F1-Score
# 	[0.00831423 0.00786377]
#
# 	RandomForest Results
# Fold	Accuracy	F1-Score
# 1	[0.9514153511159499, 0.9572406657747168]
# 2	[0.9807549043953315, 0.98119227445298]
# 3	[0.9683465739821251, 0.9683183635665897]
# 4	[0.9352598288478234, 0.9344717725780841]
# Average	Accuracy	F1-Score
# 	[0.95894416 0.96030577]
# StdDev	Accuracy	F1-Score
# 	[0.01718826 0.01715545]
#
# 	ANN-Conv1d Results
# Fold	Accuracy	F1-Score
# 1	[0.8946652150244965, 0.909960142204715]
# 2	[0.9911845045939905, 0.9905791915044793]
# 3	[0.9977656405163853, 0.9976320049636324]
# 4	[0.9864814585142007, 0.986222012069224]
# Average	Accuracy	F1-Score
# 	[0.9675242  0.97109834]
# StdDev	Accuracy	F1-Score
# 	[0.04225566 0.03553218]
#
# ##############################
# byseverity
# ##############################
#
# 	K-NNeighbors Results
# Fold	Accuracy	F1-Score
# 1	[0.5728927203065134, 0.6340583389954915]
# 2	[0.4732599795291709, 0.4253133750548309]
# 3	[0.5248443928684461, 0.541617687679397]
# 4	[0.503433703116746, 0.2556811807760061]
# Average	Accuracy	F1-Score
# 	[0.5186077  0.46416765]
# StdDev	Accuracy	F1-Score
# 	[0.03630574 0.14127776]
#
# 	RandomForest Results
# Fold	Accuracy	F1-Score
# 1	[0.5473180076628352, 0.550858782302801]
# 2	[0.5446519959058342, 0.51309578233757]
# 3	[0.5578647536659985, 0.5433261427970046]
# 4	[0.5007923930269413, 0.25]
# Average	Accuracy	F1-Score
# 	[0.53765679 0.46432018]
# StdDev	Accuracy	F1-Score
# 	[0.02184959 0.12454223]
#
# 	ANN-Conv1d Results
# Fold	Accuracy	F1-Score
# 1	[0.6394636015325671, 0.68801767695693]
# 2	[0.6406090071647902, 0.5853541402817402]
# 3	[0.394239898723494, 0.4374545549524511]
# 4	[0.5932382461701003, 0.38503086419753085]
# Average	Accuracy	F1-Score
# 	[0.56688769 0.52396431]
# StdDev	Accuracy	F1-Score
# 	[0.10149348 0.11986311]
